# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb
import numpy as np

# %%
census_2012_veg1 = pd.read_csv('../data/census_2012_veg1.csv')
census_2012_veg2 = pd.read_csv('../data/census_2012_veg2.csv')
veg_2012 = pd.concat([census_2012_veg1, census_2012_veg2], ignore_index = True)

# %%
veg_2012.head()
# Out:
#   Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0  CENSUS  2012   YEAR          NaN     STATE  ALABAMA           1
# 1  CENSUS  2012   YEAR          NaN     STATE  ALABAMA           1
# 2  CENSUS  2012   YEAR          NaN     STATE  ALABAMA           1
# 3  CENSUS  2012   YEAR          NaN     STATE  ALABAMA           1
# 4  CENSUS  2012   YEAR          NaN     STATE  ALABAMA           1
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity  \
# 0               0        NaN      BEANS
# 1               0        NaN      BEANS
# 2               0        NaN      BEANS
# 3               0        NaN      BEANS
# 4               0        NaN      BEANS
#
#                                            Data Item         Domain  \
# 0               BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1  BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2  BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3  BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                      BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
#
#                          Domain Category Value CV (%)
# 0                          NOT SPECIFIED   154   64.1
# 1                          NOT SPECIFIED    30   16.4
# 2                          NOT SPECIFIED   154   64.1
# 3                          NOT SPECIFIED    30   16.4
# 4  AREA OPERATED: (1,000 TO 1,999 ACRES)    27   14.6
#
# [5 rows x 21 columns]

# %%
veg_2012['State'] = veg_2012['State'].str.title()

# %%
veg_2012
# Out:
#       Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 1      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 2      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 3      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 4      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# ...       ...   ...    ...          ...       ...      ...         ...
# 84825  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 84826  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 84827  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 84828  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 84829  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
#
#        Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0              NaN               NaN     NaN  ...       NaN     NaN
# 1              NaN               NaN     NaN  ...       NaN     NaN
# 2              NaN               NaN     NaN  ...       NaN     NaN
# 3              NaN               NaN     NaN  ...       NaN     NaN
# 4              NaN               NaN     NaN  ...       NaN     NaN
# ...            ...               ...     ...  ...       ...     ...
# 84825          NaN               NaN     NaN  ...       NaN     NaN
# 84826          NaN               NaN     NaN  ...       NaN     NaN
# 84827          NaN               NaN     NaN  ...       NaN     NaN
# 84828          NaN               NaN     NaN  ...       NaN     NaN
# 84829          NaN               NaN     NaN  ...       NaN     NaN
#
#        watershed_code  Watershed          Commodity  \
# 0                   0        NaN              BEANS
# 1                   0        NaN              BEANS
# 2                   0        NaN              BEANS
# 3                   0        NaN              BEANS
# 4                   0        NaN              BEANS
# ...               ...        ...                ...
# 84825               0        NaN   VEGETABLE TOTALS
# 84826               0        NaN  VEGETABLES, OTHER
# 84827               0        NaN  VEGETABLES, OTHER
# 84828               0        NaN  VEGETABLES, OTHER
# 84829               0        NaN  VEGETABLES, OTHER
#
#                                                Data Item         Domain  \
# 0                   BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1      BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2      BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3      BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                          BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# ...                                                  ...            ...
# 84825  VEGETABLE TOTALS, PRODUCTION CONTRACT - OPERAT...          TOTAL
# 84826                VEGETABLES, OTHER - ACRES HARVESTED          TOTAL
# 84827  VEGETABLES, OTHER - OPERATIONS WITH AREA HARVE...          TOTAL
# 84828  VEGETABLES, OTHER, FRESH MARKET - ACRES HARVESTED          TOTAL
# 84829  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...          TOTAL
#
#                              Domain Category Value CV (%)
# 0                              NOT SPECIFIED   154   64.1
# 1                              NOT SPECIFIED    30   16.4
# 2                              NOT SPECIFIED   154   64.1
# 3                              NOT SPECIFIED    30   16.4
# 4      AREA OPERATED: (1,000 TO 1,999 ACRES)    27   14.6
# ...                                      ...   ...    ...
# 84825                          NOT SPECIFIED     2   87.5
# 84826                          NOT SPECIFIED     1    (H)
# 84827                          NOT SPECIFIED     3   63.2
# 84828                          NOT SPECIFIED     1    (H)
# 84829                          NOT SPECIFIED     3   63.2
#
# [84830 rows x 21 columns]

# %%
veg_2012 = veg_2012.drop(columns = ['Week Ending', 'Ag District', 'Ag District Code', 'County',
       'County ANSI', 'Zip Code', 'Region', 'watershed_code', 'Watershed'])

# %%
veg_2012
# Out:
#       Program  Year Period Geo Level    State  State ANSI          Commodity  \
# 0      CENSUS  2012   YEAR     STATE  Alabama           1              BEANS
# 1      CENSUS  2012   YEAR     STATE  Alabama           1              BEANS
# 2      CENSUS  2012   YEAR     STATE  Alabama           1              BEANS
# 3      CENSUS  2012   YEAR     STATE  Alabama           1              BEANS
# 4      CENSUS  2012   YEAR     STATE  Alabama           1              BEANS
# ...       ...   ...    ...       ...      ...         ...                ...
# 84825  CENSUS  2012   YEAR     STATE  Wyoming          56   VEGETABLE TOTALS
# 84826  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
# 84827  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
# 84828  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
# 84829  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
#
#                                                Data Item         Domain  \
# 0                   BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1      BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2      BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3      BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                          BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# ...                                                  ...            ...
# 84825  VEGETABLE TOTALS, PRODUCTION CONTRACT - OPERAT...          TOTAL
# 84826                VEGETABLES, OTHER - ACRES HARVESTED          TOTAL
# 84827  VEGETABLES, OTHER - OPERATIONS WITH AREA HARVE...          TOTAL
# 84828  VEGETABLES, OTHER, FRESH MARKET - ACRES HARVESTED          TOTAL
# 84829  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...          TOTAL
#
#                              Domain Category Value CV (%)
# 0                              NOT SPECIFIED   154   64.1
# 1                              NOT SPECIFIED    30   16.4
# 2                              NOT SPECIFIED   154   64.1
# 3                              NOT SPECIFIED    30   16.4
# 4      AREA OPERATED: (1,000 TO 1,999 ACRES)    27   14.6
# ...                                      ...   ...    ...
# 84825                          NOT SPECIFIED     2   87.5
# 84826                          NOT SPECIFIED     1    (H)
# 84827                          NOT SPECIFIED     3   63.2
# 84828                          NOT SPECIFIED     1    (H)
# 84829                          NOT SPECIFIED     3   63.2
#
# [84830 rows x 12 columns]

# %%
veg_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84830 entries, 0 to 84829
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Program          84830 non-null  object
#  1   Year             84830 non-null  int64
#  2   Period           84830 non-null  object
#  3   Geo Level        84830 non-null  object
#  4   State            84830 non-null  object
#  5   State ANSI       84830 non-null  int64
#  6   Commodity        84830 non-null  object
#  7   Data Item        84830 non-null  object
#  8   Domain           84830 non-null  object
#  9   Domain Category  84830 non-null  object
#  10  Value            84830 non-null  object
#  11  CV (%)           84830 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 7.8+ MB

# %%
veg_2012.dtypes
# Out:
# Program            object
# Year                int64
# Period             object
# Geo Level          object
# State              object
# State ANSI          int64
# Commodity          object
# Data Item          object
# Domain             object
# Domain Category    object
# Value              object
# CV (%)             object
# dtype: object

# %%
census_2017_veg1 = pd.read_csv('../data/census_2017_veg1.csv')
census_2017_veg_take2 = pd.read_csv('../data/census_2017_veg_take2.csv')
veg_2017 = pd.concat([census_2017_veg1, census_2017_veg_take2], ignore_index = True)

# %%
veg_2017.head(1)
# Out:
#   Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0  CENSUS  2017   YEAR          NaN     STATE  ALABAMA           1
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity                             Data Item  \
# 0               0        NaN      BEANS  BEANS, GREEN, LIMA - ACRES HARVESTED
#
#   Domain Domain Category Value CV (%)
# 0  TOTAL   NOT SPECIFIED    80   27.9
#
# [1 rows x 21 columns]

# %%
veg_2017['State'] = veg_2017['State'].str.title()

# %%
veg_2017
# Out:
#       Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 1      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 2      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 3      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 4      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# ...       ...   ...    ...          ...       ...      ...         ...
# 88627  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 88628  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 88629  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 88630  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 88631  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
#
#        Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0              NaN               NaN     NaN  ...       NaN     NaN
# 1              NaN               NaN     NaN  ...       NaN     NaN
# 2              NaN               NaN     NaN  ...       NaN     NaN
# 3              NaN               NaN     NaN  ...       NaN     NaN
# 4              NaN               NaN     NaN  ...       NaN     NaN
# ...            ...               ...     ...  ...       ...     ...
# 88627          NaN               NaN     NaN  ...       NaN     NaN
# 88628          NaN               NaN     NaN  ...       NaN     NaN
# 88629          NaN               NaN     NaN  ...       NaN     NaN
# 88630          NaN               NaN     NaN  ...       NaN     NaN
# 88631          NaN               NaN     NaN  ...       NaN     NaN
#
#        watershed_code  Watershed          Commodity  \
# 0                   0        NaN              BEANS
# 1                   0        NaN              BEANS
# 2                   0        NaN              BEANS
# 3                   0        NaN              BEANS
# 4                   0        NaN              BEANS
# ...               ...        ...                ...
# 88627               0        NaN  VEGETABLES, OTHER
# 88628               0        NaN         WATERCRESS
# 88629               0        NaN         WATERCRESS
# 88630               0        NaN         WATERCRESS
# 88631               0        NaN         WATERCRESS
#
#                                                Data Item         Domain  \
# 0                   BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1      BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2      BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3      BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                          BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# ...                                                  ...            ...
# 88627  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...          TOTAL
# 88628                       WATERCRESS - ACRES HARVESTED          TOTAL
# 88629        WATERCRESS - OPERATIONS WITH AREA HARVESTED          TOTAL
# 88630         WATERCRESS, FRESH MARKET - ACRES HARVESTED          TOTAL
# 88631  WATERCRESS, FRESH MARKET - OPERATIONS WITH ARE...          TOTAL
#
#                              Domain Category Value CV (%)
# 0                              NOT SPECIFIED    80   27.9
# 1                              NOT SPECIFIED    66   65.9
# 2                              NOT SPECIFIED    80   27.9
# 3                              NOT SPECIFIED    66   65.9
# 4      AREA OPERATED: (1,000 TO 1,999 ACRES)   (D)    (D)
# ...                                      ...   ...    ...
# 88627                          NOT SPECIFIED    13    (H)
# 88628                          NOT SPECIFIED   (D)    (D)
# 88629                          NOT SPECIFIED     2   93.4
# 88630                          NOT SPECIFIED   (D)    (D)
# 88631                          NOT SPECIFIED     2   93.4
#
# [88632 rows x 21 columns]

# %%
veg_2017 = veg_2017.drop(columns = ['Week Ending', 'Ag District', 'Ag District Code', 'County',
       'County ANSI', 'Zip Code', 'Region', 'watershed_code', 'Watershed'])

# %%
veg_2017
# Out:
#       Program  Year Period Geo Level    State  State ANSI          Commodity  \
# 0      CENSUS  2017   YEAR     STATE  Alabama           1              BEANS
# 1      CENSUS  2017   YEAR     STATE  Alabama           1              BEANS
# 2      CENSUS  2017   YEAR     STATE  Alabama           1              BEANS
# 3      CENSUS  2017   YEAR     STATE  Alabama           1              BEANS
# 4      CENSUS  2017   YEAR     STATE  Alabama           1              BEANS
# ...       ...   ...    ...       ...      ...         ...                ...
# 88627  CENSUS  2017   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
# 88628  CENSUS  2017   YEAR     STATE  Wyoming          56         WATERCRESS
# 88629  CENSUS  2017   YEAR     STATE  Wyoming          56         WATERCRESS
# 88630  CENSUS  2017   YEAR     STATE  Wyoming          56         WATERCRESS
# 88631  CENSUS  2017   YEAR     STATE  Wyoming          56         WATERCRESS
#
#                                                Data Item         Domain  \
# 0                   BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1      BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2      BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3      BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                          BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# ...                                                  ...            ...
# 88627  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...          TOTAL
# 88628                       WATERCRESS - ACRES HARVESTED          TOTAL
# 88629        WATERCRESS - OPERATIONS WITH AREA HARVESTED          TOTAL
# 88630         WATERCRESS, FRESH MARKET - ACRES HARVESTED          TOTAL
# 88631  WATERCRESS, FRESH MARKET - OPERATIONS WITH ARE...          TOTAL
#
#                              Domain Category Value CV (%)
# 0                              NOT SPECIFIED    80   27.9
# 1                              NOT SPECIFIED    66   65.9
# 2                              NOT SPECIFIED    80   27.9
# 3                              NOT SPECIFIED    66   65.9
# 4      AREA OPERATED: (1,000 TO 1,999 ACRES)   (D)    (D)
# ...                                      ...   ...    ...
# 88627                          NOT SPECIFIED    13    (H)
# 88628                          NOT SPECIFIED   (D)    (D)
# 88629                          NOT SPECIFIED     2   93.4
# 88630                          NOT SPECIFIED   (D)    (D)
# 88631                          NOT SPECIFIED     2   93.4
#
# [88632 rows x 12 columns]

# %%
veg_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88632 entries, 0 to 88631
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Program          88632 non-null  object
#  1   Year             88632 non-null  int64
#  2   Period           88632 non-null  object
#  3   Geo Level        88632 non-null  object
#  4   State            88632 non-null  object
#  5   State ANSI       88632 non-null  int64
#  6   Commodity        88632 non-null  object
#  7   Data Item        88632 non-null  object
#  8   Domain           88632 non-null  object
#  9   Domain Category  88632 non-null  object
#  10  Value            88632 non-null  object
#  11  CV (%)           88632 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 8.1+ MB

# %%
veg_2017.dtypes
# Out:
# Program            object
# Year                int64
# Period             object
# Geo Level          object
# State              object
# State ANSI          int64
# Commodity          object
# Data Item          object
# Domain             object
# Domain Category    object
# Value              object
# CV (%)             object
# dtype: object

# %%
census_2022_veg1 = pd.read_csv('../data/census_2022_veg1.csv')
census_2022_veg_take2 = pd.read_csv('../data/census_2022_veg_take2.csv')
veg_2022 = pd.concat([census_2022_veg1, census_2022_veg_take2], ignore_index = True)

# %%
veg_2022.head(1)
# Out:
#   Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0  CENSUS  2022   YEAR          NaN     STATE  ALABAMA           1
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity                             Data Item  \
# 0               0        NaN      BEANS  BEANS, GREEN, LIMA - ACRES HARVESTED
#
#   Domain Domain Category Value CV (%)
# 0  TOTAL   NOT SPECIFIED    44     22
#
# [1 rows x 21 columns]

# %%
veg_2022['State'] = veg_2022['State'].str.title()
veg_2022
# Out:
#       Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 1      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 2      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 3      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 4      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# ...       ...   ...    ...          ...       ...      ...         ...
# 97543  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 97544  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 97545  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 97546  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 97547  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
#
#        Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0              NaN               NaN     NaN  ...       NaN     NaN
# 1              NaN               NaN     NaN  ...       NaN     NaN
# 2              NaN               NaN     NaN  ...       NaN     NaN
# 3              NaN               NaN     NaN  ...       NaN     NaN
# 4              NaN               NaN     NaN  ...       NaN     NaN
# ...            ...               ...     ...  ...       ...     ...
# 97543          NaN               NaN     NaN  ...       NaN     NaN
# 97544          NaN               NaN     NaN  ...       NaN     NaN
# 97545          NaN               NaN     NaN  ...       NaN     NaN
# 97546          NaN               NaN     NaN  ...       NaN     NaN
# 97547          NaN               NaN     NaN  ...       NaN     NaN
#
#        watershed_code  Watershed          Commodity  \
# 0                   0        NaN              BEANS
# 1                   0        NaN              BEANS
# 2                   0        NaN              BEANS
# 3                   0        NaN              BEANS
# 4                   0        NaN              BEANS
# ...               ...        ...                ...
# 97543               0        NaN   VEGETABLE TOTALS
# 97544               0        NaN  VEGETABLES, OTHER
# 97545               0        NaN  VEGETABLES, OTHER
# 97546               0        NaN  VEGETABLES, OTHER
# 97547               0        NaN  VEGETABLES, OTHER
#
#                                                Data Item Domain  \
# 0                   BEANS, GREEN, LIMA - ACRES HARVESTED  TOTAL
# 1      BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...  TOTAL
# 2      BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...  TOTAL
# 3      BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...  TOTAL
# 4       BEANS, GREEN, LIMA, PROCESSING - ACRES HARVESTED  TOTAL
# ...                                                  ...    ...
# 97543  VEGETABLE TOTALS, INCL SEEDS & TRANSPLANTS, IN...  TOTAL
# 97544                VEGETABLES, OTHER - ACRES HARVESTED  TOTAL
# 97545  VEGETABLES, OTHER - OPERATIONS WITH AREA HARVE...  TOTAL
# 97546  VEGETABLES, OTHER, FRESH MARKET - ACRES HARVESTED  TOTAL
# 97547  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...  TOTAL
#
#       Domain Category Value CV (%)
# 0       NOT SPECIFIED    44     22
# 1       NOT SPECIFIED    66   33.7
# 2       NOT SPECIFIED    42   22.7
# 3       NOT SPECIFIED    63   35.4
# 4       NOT SPECIFIED     2   31.6
# ...               ...   ...    ...
# 97543   NOT SPECIFIED   0.5    5.8
# 97544   NOT SPECIFIED   (D)    (D)
# 97545   NOT SPECIFIED    12   26.2
# 97546   NOT SPECIFIED   (D)    (D)
# 97547   NOT SPECIFIED    12   26.2
#
# [97548 rows x 21 columns]

# %%
veg_2022 = veg_2022.drop(columns = ['Week Ending', 'Ag District', 'Ag District Code', 'County',
       'County ANSI', 'Zip Code', 'Region', 'watershed_code', 'Watershed'])

# %%
veg_2022
# Out:
#       Program  Year Period Geo Level    State  State ANSI          Commodity  \
# 0      CENSUS  2022   YEAR     STATE  Alabama           1              BEANS
# 1      CENSUS  2022   YEAR     STATE  Alabama           1              BEANS
# 2      CENSUS  2022   YEAR     STATE  Alabama           1              BEANS
# 3      CENSUS  2022   YEAR     STATE  Alabama           1              BEANS
# 4      CENSUS  2022   YEAR     STATE  Alabama           1              BEANS
# ...       ...   ...    ...       ...      ...         ...                ...
# 97543  CENSUS  2022   YEAR     STATE  Wyoming          56   VEGETABLE TOTALS
# 97544  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
# 97545  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
# 97546  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
# 97547  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLES, OTHER
#
#                                                Data Item Domain  \
# 0                   BEANS, GREEN, LIMA - ACRES HARVESTED  TOTAL
# 1      BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...  TOTAL
# 2      BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...  TOTAL
# 3      BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...  TOTAL
# 4       BEANS, GREEN, LIMA, PROCESSING - ACRES HARVESTED  TOTAL
# ...                                                  ...    ...
# 97543  VEGETABLE TOTALS, INCL SEEDS & TRANSPLANTS, IN...  TOTAL
# 97544                VEGETABLES, OTHER - ACRES HARVESTED  TOTAL
# 97545  VEGETABLES, OTHER - OPERATIONS WITH AREA HARVE...  TOTAL
# 97546  VEGETABLES, OTHER, FRESH MARKET - ACRES HARVESTED  TOTAL
# 97547  VEGETABLES, OTHER, FRESH MARKET - OPERATIONS W...  TOTAL
#
#       Domain Category Value CV (%)
# 0       NOT SPECIFIED    44     22
# 1       NOT SPECIFIED    66   33.7
# 2       NOT SPECIFIED    42   22.7
# 3       NOT SPECIFIED    63   35.4
# 4       NOT SPECIFIED     2   31.6
# ...               ...   ...    ...
# 97543   NOT SPECIFIED   0.5    5.8
# 97544   NOT SPECIFIED   (D)    (D)
# 97545   NOT SPECIFIED    12   26.2
# 97546   NOT SPECIFIED   (D)    (D)
# 97547   NOT SPECIFIED    12   26.2
#
# [97548 rows x 12 columns]

# %%
veg_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97548 entries, 0 to 97547
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Program          97548 non-null  object
#  1   Year             97548 non-null  int64
#  2   Period           97548 non-null  object
#  3   Geo Level        97548 non-null  object
#  4   State            97548 non-null  object
#  5   State ANSI       97548 non-null  int64
#  6   Commodity        97548 non-null  object
#  7   Data Item        97548 non-null  object
#  8   Domain           97548 non-null  object
#  9   Domain Category  97548 non-null  object
#  10  Value            97548 non-null  object
#  11  CV (%)           97548 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 8.9+ MB

# %%
hort_2012 = pd.read_csv('../data/census_2012_hort.csv')
hort_2012.head(1)
# Out:
#   Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0  CENSUS  2012   YEAR          NaN     STATE  ALABAMA           1
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed       Commodity  \
# 0               0        NaN  AQUATIC PLANTS
#
#                                            Data Item Domain Domain Category  \
# 0  AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL   NOT SPECIFIED
#
#   Value CV (%)
# 0     7   54.2
#
# [1 rows x 21 columns]

# %%
hort_2012['State'] = hort_2012['State'].str.title()
hort_2012
# Out:
#       Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 1      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 2      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 3      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# 4      CENSUS  2012   YEAR          NaN     STATE  Alabama           1
# ...       ...   ...    ...          ...       ...      ...         ...
# 29357  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 29358  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 29359  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 29360  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
# 29361  CENSUS  2012   YEAR          NaN     STATE  Wyoming          56
#
#        Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0              NaN               NaN     NaN  ...       NaN     NaN
# 1              NaN               NaN     NaN  ...       NaN     NaN
# 2              NaN               NaN     NaN  ...       NaN     NaN
# 3              NaN               NaN     NaN  ...       NaN     NaN
# 4              NaN               NaN     NaN  ...       NaN     NaN
# ...            ...               ...     ...  ...       ...     ...
# 29357          NaN               NaN     NaN  ...       NaN     NaN
# 29358          NaN               NaN     NaN  ...       NaN     NaN
# 29359          NaN               NaN     NaN  ...       NaN     NaN
# 29360          NaN               NaN     NaN  ...       NaN     NaN
# 29361          NaN               NaN     NaN  ...       NaN     NaN
#
#        watershed_code  Watershed         Commodity  \
# 0                   0        NaN    AQUATIC PLANTS
# 1                   0        NaN    AQUATIC PLANTS
# 2                   0        NaN    AQUATIC PLANTS
# 3                   0        NaN    AQUATIC PLANTS
# 4                   0        NaN    AQUATIC PLANTS
# ...               ...        ...               ...
# 29357               0        NaN  VEGETABLE TOTALS
# 29358               0        NaN  VEGETABLE TOTALS
# 29359               0        NaN  VEGETABLE TOTALS
# 29360               0        NaN  VEGETABLE TOTALS
# 29361               0        NaN  VEGETABLE TOTALS
#
#                                                Data Item Domain  \
# 0      AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL
# 1                 AQUATIC PLANTS - OPERATIONS WITH SALES  TOTAL
# 2                  AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 3      AQUATIC PLANTS, IN THE OPEN - ACRES IN PRODUCTION  TOTAL
# 4      AQUATIC PLANTS, IN THE OPEN - OPERATIONS WITH ...  TOTAL
# ...                                                  ...    ...
# 29357  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...  TOTAL
# 29358  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 29359  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 29360  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 29361  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
#
#       Domain Category    Value CV (%)
# 0       NOT SPECIFIED        7   54.2
# 1       NOT SPECIFIED        7   54.2
# 2       NOT SPECIFIED   30,138     81
# 3       NOT SPECIFIED        2   62.6
# 4       NOT SPECIFIED        5   46.5
# ...               ...      ...    ...
# 29357   NOT SPECIFIED   66,532   53.5
# 29358   NOT SPECIFIED       33   32.3
# 29359   NOT SPECIFIED       33   32.3
# 29360   NOT SPECIFIED  236,517   29.2
# 29361   NOT SPECIFIED   98,028   42.3
#
# [29362 rows x 21 columns]

# %%
hort_2012.columns
# Out:
# Index(['Program', 'Year', 'Period', 'Week Ending', 'Geo Level', 'State',
#        'State ANSI', 'Ag District', 'Ag District Code', 'County',
#        'County ANSI', 'Zip Code', 'Region', 'watershed_code', 'Watershed',
#        'Commodity', 'Data Item', 'Domain', 'Domain Category', 'Value',
#        'CV (%)'],
#       dtype='object')

# %%
hort_2012 = hort_2012.drop(columns = ['Week Ending', 'Ag District', 'Ag District Code', 'County',
       'County ANSI', 'Zip Code', 'Region', 'watershed_code', 'Watershed'])

# %%
hort_2012
# Out:
#       Program  Year Period Geo Level    State  State ANSI         Commodity  \
# 0      CENSUS  2012   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 1      CENSUS  2012   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 2      CENSUS  2012   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 3      CENSUS  2012   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 4      CENSUS  2012   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# ...       ...   ...    ...       ...      ...         ...               ...
# 29357  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 29358  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 29359  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 29360  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 29361  CENSUS  2012   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
#
#                                                Data Item Domain  \
# 0      AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL
# 1                 AQUATIC PLANTS - OPERATIONS WITH SALES  TOTAL
# 2                  AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 3      AQUATIC PLANTS, IN THE OPEN - ACRES IN PRODUCTION  TOTAL
# 4      AQUATIC PLANTS, IN THE OPEN - OPERATIONS WITH ...  TOTAL
# ...                                                  ...    ...
# 29357  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...  TOTAL
# 29358  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 29359  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 29360  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 29361  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
#
#       Domain Category    Value CV (%)
# 0       NOT SPECIFIED        7   54.2
# 1       NOT SPECIFIED        7   54.2
# 2       NOT SPECIFIED   30,138     81
# 3       NOT SPECIFIED        2   62.6
# 4       NOT SPECIFIED        5   46.5
# ...               ...      ...    ...
# 29357   NOT SPECIFIED   66,532   53.5
# 29358   NOT SPECIFIED       33   32.3
# 29359   NOT SPECIFIED       33   32.3
# 29360   NOT SPECIFIED  236,517   29.2
# 29361   NOT SPECIFIED   98,028   42.3
#
# [29362 rows x 12 columns]

# %%
hort_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29362 entries, 0 to 29361
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Program          29362 non-null  object
#  1   Year             29362 non-null  int64
#  2   Period           29362 non-null  object
#  3   Geo Level        29362 non-null  object
#  4   State            29362 non-null  object
#  5   State ANSI       29362 non-null  int64
#  6   Commodity        29362 non-null  object
#  7   Data Item        29362 non-null  object
#  8   Domain           29362 non-null  object
#  9   Domain Category  29362 non-null  object
#  10  Value            29362 non-null  object
#  11  CV (%)           29362 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 2.7+ MB

# %%
hort_2012.dtypes
# Out:
# Program            object
# Year                int64
# Period             object
# Geo Level          object
# State              object
# State ANSI          int64
# Commodity          object
# Data Item          object
# Domain             object
# Domain Category    object
# Value              object
# CV (%)             object
# dtype: object

# %%
hort_2017 = pd.read_csv('../data/census_2017_hort.csv')
hort_2017.head(1)
# Out:
#   Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0  CENSUS  2017   YEAR          NaN     STATE  ALABAMA           1
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed       Commodity  \
# 0               0        NaN  AQUATIC PLANTS
#
#                                            Data Item Domain Domain Category  \
# 0  AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL   NOT SPECIFIED
#
#   Value CV (%)
# 0     5   92.9
#
# [1 rows x 21 columns]

# %%
hort_2017['State'] = hort_2017['State'].str.title()
hort_2017
# Out:
#       Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 1      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 2      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 3      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# 4      CENSUS  2017   YEAR          NaN     STATE  Alabama           1
# ...       ...   ...    ...          ...       ...      ...         ...
# 28774  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 28775  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 28776  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 28777  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
# 28778  CENSUS  2017   YEAR          NaN     STATE  Wyoming          56
#
#        Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0              NaN               NaN     NaN  ...       NaN     NaN
# 1              NaN               NaN     NaN  ...       NaN     NaN
# 2              NaN               NaN     NaN  ...       NaN     NaN
# 3              NaN               NaN     NaN  ...       NaN     NaN
# 4              NaN               NaN     NaN  ...       NaN     NaN
# ...            ...               ...     ...  ...       ...     ...
# 28774          NaN               NaN     NaN  ...       NaN     NaN
# 28775          NaN               NaN     NaN  ...       NaN     NaN
# 28776          NaN               NaN     NaN  ...       NaN     NaN
# 28777          NaN               NaN     NaN  ...       NaN     NaN
# 28778          NaN               NaN     NaN  ...       NaN     NaN
#
#        watershed_code  Watershed         Commodity  \
# 0                   0        NaN    AQUATIC PLANTS
# 1                   0        NaN    AQUATIC PLANTS
# 2                   0        NaN    AQUATIC PLANTS
# 3                   0        NaN    AQUATIC PLANTS
# 4                   0        NaN    AQUATIC PLANTS
# ...               ...        ...               ...
# 28774               0        NaN  VEGETABLE TOTALS
# 28775               0        NaN  VEGETABLE TOTALS
# 28776               0        NaN  VEGETABLE TOTALS
# 28777               0        NaN  VEGETABLE TOTALS
# 28778               0        NaN  VEGETABLE TOTALS
#
#                                                Data Item Domain  \
# 0      AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL
# 1                 AQUATIC PLANTS - OPERATIONS WITH SALES  TOTAL
# 2                  AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 3      AQUATIC PLANTS, IN THE OPEN - ACRES IN PRODUCTION  TOTAL
# 4      AQUATIC PLANTS, IN THE OPEN - OPERATIONS WITH ...  TOTAL
# ...                                                  ...    ...
# 28774  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...  TOTAL
# 28775  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28776  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28777  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28778  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
#
#       Domain Category      Value CV (%)
# 0       NOT SPECIFIED          5   92.9
# 1       NOT SPECIFIED          4    (H)
# 2       NOT SPECIFIED        (D)    (D)
# 3       NOT SPECIFIED          6   76.3
# 4       NOT SPECIFIED          5   92.9
# ...               ...        ...    ...
# 28774   NOT SPECIFIED     69,705   25.5
# 28775   NOT SPECIFIED         56     38
# 28776   NOT SPECIFIED         56     38
# 28777   NOT SPECIFIED  1,275,925    (H)
# 28778   NOT SPECIFIED    211,972    (H)
#
# [28779 rows x 21 columns]

# %%
hort_2017 = hort_2017.drop(columns = ['Week Ending', 'Ag District', 'Ag District Code', 'County',
       'County ANSI', 'Zip Code', 'Region', 'watershed_code', 'Watershed'])

# %%
hort_2017
# Out:
#       Program  Year Period Geo Level    State  State ANSI         Commodity  \
# 0      CENSUS  2017   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 1      CENSUS  2017   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 2      CENSUS  2017   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 3      CENSUS  2017   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 4      CENSUS  2017   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# ...       ...   ...    ...       ...      ...         ...               ...
# 28774  CENSUS  2017   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28775  CENSUS  2017   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28776  CENSUS  2017   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28777  CENSUS  2017   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28778  CENSUS  2017   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
#
#                                                Data Item Domain  \
# 0      AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL
# 1                 AQUATIC PLANTS - OPERATIONS WITH SALES  TOTAL
# 2                  AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 3      AQUATIC PLANTS, IN THE OPEN - ACRES IN PRODUCTION  TOTAL
# 4      AQUATIC PLANTS, IN THE OPEN - OPERATIONS WITH ...  TOTAL
# ...                                                  ...    ...
# 28774  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...  TOTAL
# 28775  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28776  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28777  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28778  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
#
#       Domain Category      Value CV (%)
# 0       NOT SPECIFIED          5   92.9
# 1       NOT SPECIFIED          4    (H)
# 2       NOT SPECIFIED        (D)    (D)
# 3       NOT SPECIFIED          6   76.3
# 4       NOT SPECIFIED          5   92.9
# ...               ...        ...    ...
# 28774   NOT SPECIFIED     69,705   25.5
# 28775   NOT SPECIFIED         56     38
# 28776   NOT SPECIFIED         56     38
# 28777   NOT SPECIFIED  1,275,925    (H)
# 28778   NOT SPECIFIED    211,972    (H)
#
# [28779 rows x 12 columns]

# %%
hort_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28779 entries, 0 to 28778
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Program          28779 non-null  object
#  1   Year             28779 non-null  int64
#  2   Period           28779 non-null  object
#  3   Geo Level        28779 non-null  object
#  4   State            28779 non-null  object
#  5   State ANSI       28779 non-null  int64
#  6   Commodity        28779 non-null  object
#  7   Data Item        28779 non-null  object
#  8   Domain           28779 non-null  object
#  9   Domain Category  28779 non-null  object
#  10  Value            28779 non-null  object
#  11  CV (%)           28779 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 2.6+ MB

# %%
hort_2022 = pd.read_csv('../data/census_2022_hort.csv')
hort_2022.head(1)
# Out:
#   Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0  CENSUS  2022   YEAR          NaN     STATE  ALABAMA           1
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed       Commodity  \
# 0               0        NaN  AQUATIC PLANTS
#
#                                            Data Item Domain Domain Category  \
# 0  AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL   NOT SPECIFIED
#
#   Value CV (%)
# 0    12   86.2
#
# [1 rows x 21 columns]

# %%
hort_2022['State'] = hort_2022['State'].str.title()
hort_2022
# Out:
#       Program  Year Period  Week Ending Geo Level    State  State ANSI  \
# 0      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 1      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 2      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 3      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# 4      CENSUS  2022   YEAR          NaN     STATE  Alabama           1
# ...       ...   ...    ...          ...       ...      ...         ...
# 28561  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 28562  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 28563  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 28564  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
# 28565  CENSUS  2022   YEAR          NaN     STATE  Wyoming          56
#
#        Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0              NaN               NaN     NaN  ...       NaN     NaN
# 1              NaN               NaN     NaN  ...       NaN     NaN
# 2              NaN               NaN     NaN  ...       NaN     NaN
# 3              NaN               NaN     NaN  ...       NaN     NaN
# 4              NaN               NaN     NaN  ...       NaN     NaN
# ...            ...               ...     ...  ...       ...     ...
# 28561          NaN               NaN     NaN  ...       NaN     NaN
# 28562          NaN               NaN     NaN  ...       NaN     NaN
# 28563          NaN               NaN     NaN  ...       NaN     NaN
# 28564          NaN               NaN     NaN  ...       NaN     NaN
# 28565          NaN               NaN     NaN  ...       NaN     NaN
#
#        watershed_code  Watershed         Commodity  \
# 0                   0        NaN    AQUATIC PLANTS
# 1                   0        NaN    AQUATIC PLANTS
# 2                   0        NaN    AQUATIC PLANTS
# 3                   0        NaN    AQUATIC PLANTS
# 4                   0        NaN    AQUATIC PLANTS
# ...               ...        ...               ...
# 28561               0        NaN  VEGETABLE TOTALS
# 28562               0        NaN  VEGETABLE TOTALS
# 28563               0        NaN  VEGETABLE TOTALS
# 28564               0        NaN  VEGETABLE TOTALS
# 28565               0        NaN  VEGETABLE TOTALS
#
#                                                Data Item Domain  \
# 0      AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL
# 1                 AQUATIC PLANTS - OPERATIONS WITH SALES  TOTAL
# 2                  AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 3      AQUATIC PLANTS, IN THE OPEN - ACRES IN PRODUCTION  TOTAL
# 4      AQUATIC PLANTS, IN THE OPEN - OPERATIONS WITH ...  TOTAL
# ...                                                  ...    ...
# 28561  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...  TOTAL
# 28562  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28563  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28564  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28565  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
#
#       Domain Category      Value CV (%)
# 0       NOT SPECIFIED         12   86.2
# 1       NOT SPECIFIED         12   86.2
# 2       NOT SPECIFIED  1,569,500   80.6
# 3       NOT SPECIFIED         94   65.3
# 4       NOT SPECIFIED         12   86.2
# ...               ...        ...    ...
# 28561   NOT SPECIFIED     42,526   60.2
# 28562   NOT SPECIFIED         52   18.9
# 28563   NOT SPECIFIED         52   18.9
# 28564   NOT SPECIFIED    449,063   64.9
# 28565   NOT SPECIFIED     77,105   44.1
#
# [28566 rows x 21 columns]

# %%
hort_2022 = hort_2022.drop(columns = ['Week Ending', 'Ag District', 'Ag District Code', 'County',
       'County ANSI', 'Zip Code', 'Region', 'watershed_code', 'Watershed'])

# %%
hort_2022
# Out:
#       Program  Year Period Geo Level    State  State ANSI         Commodity  \
# 0      CENSUS  2022   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 1      CENSUS  2022   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 2      CENSUS  2022   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 3      CENSUS  2022   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# 4      CENSUS  2022   YEAR     STATE  Alabama           1    AQUATIC PLANTS
# ...       ...   ...    ...       ...      ...         ...               ...
# 28561  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28562  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28563  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28564  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 28565  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
#
#                                                Data Item Domain  \
# 0      AQUATIC PLANTS - OPERATIONS WITH AREA IN PRODU...  TOTAL
# 1                 AQUATIC PLANTS - OPERATIONS WITH SALES  TOTAL
# 2                  AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 3      AQUATIC PLANTS, IN THE OPEN - ACRES IN PRODUCTION  TOTAL
# 4      AQUATIC PLANTS, IN THE OPEN - OPERATIONS WITH ...  TOTAL
# ...                                                  ...    ...
# 28561  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...  TOTAL
# 28562  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28563  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28564  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
# 28565  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...  TOTAL
#
#       Domain Category      Value CV (%)
# 0       NOT SPECIFIED         12   86.2
# 1       NOT SPECIFIED         12   86.2
# 2       NOT SPECIFIED  1,569,500   80.6
# 3       NOT SPECIFIED         94   65.3
# 4       NOT SPECIFIED         12   86.2
# ...               ...        ...    ...
# 28561   NOT SPECIFIED     42,526   60.2
# 28562   NOT SPECIFIED         52   18.9
# 28563   NOT SPECIFIED         52   18.9
# 28564   NOT SPECIFIED    449,063   64.9
# 28565   NOT SPECIFIED     77,105   44.1
#
# [28566 rows x 12 columns]

# %%
hort_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28566 entries, 0 to 28565
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Program          28566 non-null  object
#  1   Year             28566 non-null  int64
#  2   Period           28566 non-null  object
#  3   Geo Level        28566 non-null  object
#  4   State            28566 non-null  object
#  5   State ANSI       28566 non-null  int64
#  6   Commodity        28566 non-null  object
#  7   Data Item        28566 non-null  object
#  8   Domain           28566 non-null  object
#  9   Domain Category  28566 non-null  object
#  10  Value            28566 non-null  object
#  11  CV (%)           28566 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 2.6+ MB

# %%
census_2012_pop_final = pd.read_csv('../data/census_2012_pop_final.csv')
census_2012_pop_final.head()
# Out:
#   Label (Grouping)    Alabama   Alaska    Arizona   Arkansas  California  \
# 0        pop_total  4,822,023  731,449  6,553,255  2,949,131  38,041,430
# 1     age_male_pop     48.50%   52.10%     49.80%     49.10%      49.70%
# 2   age_female_pop     51.50%   47.90%     50.20%     50.90%      50.30%
# 3      age_under_5      6.30%    7.40%      6.70%      6.50%       6.70%
# 4    age_5 _to_ 17     17.10%   18.20%     18.00%     17.60%      17.60%
#
#     Colorado Connecticut Delaware District of Columbia  ... South Dakota  \
# 0  5,187,582   3,590,347  917,092              632,323  ...      833,354
# 1     50.10%      48.70%   48.50%               47.30%  ...       50.10%
# 2     49.90%      51.30%   51.50%               52.70%  ...       49.90%
# 3      6.50%       5.40%    6.10%                6.20%  ...        7.00%
# 4     17.20%      16.70%   16.20%               11.10%  ...       17.50%
#
#    Tennessee       Texas       Utah  Vermont   Virginia Washington  \
# 0  6,456,243  26,059,203  2,855,287  626,011  8,185,867  6,897,012
# 1     48.70%      49.70%     50.30%   49.40%     49.00%     49.90%
# 2     51.30%      50.30%     49.70%   50.60%     51.00%     50.10%
# 3      6.20%       7.40%      9.00%    5.00%      6.20%      6.40%
# 4     16.90%      19.40%     22.00%   14.80%     16.50%     16.60%
#
#   West Virginia  Wisconsin  Wyoming
# 0     1,855,413  5,726,398  576,412
# 1        49.10%     49.60%   50.80%
# 2        50.90%     50.40%   49.20%
# 3         5.70%      6.10%    6.60%
# 4        15.00%     16.90%   17.10%
#
# [5 rows x 52 columns]

# %%
census_2012_pop_final = census_2012_pop_final.T.reset_index()
census_2012_pop_final.head(3)
# Out:
#               index          0             1               2            3  \
# 0  Label (Grouping)  pop_total  age_male_pop  age_female_pop  age_under_5
# 1           Alabama  4,822,023        48.50%          51.50%        6.30%
# 2            Alaska    731,449        52.10%          47.90%        7.40%
#
#                4              5             6             7             8  \
# 0  age_5 _to_ 17  age_18_ to_24  age_25_to_34  age_35_to_44  age_45_to_54
# 1         17.10%         10.10%        12.60%        12.80%        13.90%
# 2         18.20%         10.90%        14.90%        13.10%        14.20%
#
#    ...                  110                    111                     112  \
# 0  ...  units_with_mortgage  mortgage_burden_lt_30  mortgage_burden_gte_30
# 1  ...              735,220                 71.70%                  28.30%
# 2  ...              103,780                 68.50%                  31.50%
#
#                   113                 114                       115  \
# 0  occupied_units_own  owner_median_value  occupied_units_with_rent
# 1           1,268,565             123,200                   493,033
# 2             159,427             245,100                    86,171
#
#                  116                 117                  118  \
# 0  rent_burden_lt_30  rent_burden_gte_30  occupied_units_rent
# 1             50.20%              49.80%              510,756
# 2             52.60%              47.40%               86,687
#
#                  119
# 0  gross_median_rent
# 1                689
# 2              1,120
#
# [3 rows x 121 columns]

# %%
census_2012_pop_final.columns = census_2012_pop_final.iloc[0]

# %%
census_2012_pop_final = census_2012_pop_final[1:]

# %%
census_2012_pop_final
# Out:
# 0       Label (Grouping)   pop_total age_male_pop age_female_pop age_under_5  \
# 1                Alabama   4,822,023       48.50%         51.50%       6.30%
# 2                 Alaska     731,449       52.10%         47.90%       7.40%
# 3                Arizona   6,553,255       49.80%         50.20%       6.70%
# 4               Arkansas   2,949,131       49.10%         50.90%       6.50%
# 5             California  38,041,430       49.70%         50.30%       6.70%
# 6               Colorado   5,187,582       50.10%         49.90%       6.50%
# 7            Connecticut   3,590,347       48.70%         51.30%       5.40%
# 8               Delaware     917,092       48.50%         51.50%       6.10%
# 9   District of Columbia     632,323       47.30%         52.70%       6.20%
# 10               Florida  19,317,568       48.90%         51.10%       5.50%
# 11               Georgia   9,919,945       48.90%         51.10%       6.80%
# 12                Hawaii   1,392,313       50.40%         49.60%       6.40%
# 13                 Idaho   1,595,728       50.10%         49.90%       7.10%
# 14              Illinois  12,875,255       49.10%         50.90%       6.30%
# 15               Indiana   6,537,334       49.20%         50.80%       6.50%
# 16                  Iowa   3,074,186       49.60%         50.40%       6.40%
# 17                Kansas   2,885,905       49.70%         50.30%       7.00%
# 18              Kentucky   4,380,415       49.20%         50.80%       6.30%
# 19             Louisiana   4,601,893       48.90%         51.10%       6.70%
# 20                 Maine   1,329,192       49.00%         51.00%       5.00%
# 21              Maryland   5,884,563       48.40%         51.60%       6.20%
# 22         Massachusetts   6,646,144       48.40%         51.60%       5.50%
# 23              Michigan   9,883,360       49.10%         50.90%       5.80%
# 24             Minnesota   5,379,139       49.60%         50.40%       6.50%
# 25           Mississippi   2,984,926       48.30%         51.70%       6.80%
# 26              Missouri   6,021,988       49.00%         51.00%       6.20%
# 27               Montana   1,005,141       50.10%         49.90%       5.90%
# 28              Nebraska   1,855,525       49.70%         50.30%       7.10%
# 29                Nevada   2,758,931       50.40%         49.60%       6.60%
# 30         New Hampshire   1,320,718       49.10%         50.90%       5.00%
# 31            New Jersey   8,864,590       48.70%         51.30%       5.90%
# 32            New Mexico   2,085,538       49.60%         50.40%       6.90%
# 33              New York  19,570,261       48.50%         51.50%       5.90%
# 34        North Carolina   9,752,073       48.70%         51.30%       6.30%
# 35          North Dakota     699,628       51.10%         48.90%       6.40%
# 36                  Ohio  11,544,225       48.90%         51.10%       6.00%
# 37              Oklahoma   3,814,820       49.50%         50.50%       6.90%
# 38                Oregon   3,899,353       49.60%         50.40%       6.00%
# 39          Pennsylvania  12,763,536       48.80%         51.20%       5.60%
# 40          Rhode Island   1,050,292       48.30%         51.70%       5.30%
# 41        South Carolina   4,723,723       48.60%         51.40%       6.20%
# 42          South Dakota     833,354       50.10%         49.90%       7.00%
# 43             Tennessee   6,456,243       48.70%         51.30%       6.20%
# 44                 Texas  26,059,203       49.70%         50.30%       7.40%
# 45                  Utah   2,855,287       50.30%         49.70%       9.00%
# 46               Vermont     626,011       49.40%         50.60%       5.00%
# 47              Virginia   8,185,867       49.00%         51.00%       6.20%
# 48            Washington   6,897,012       49.90%         50.10%       6.40%
# 49         West Virginia   1,855,413       49.10%         50.90%       5.70%
# 50             Wisconsin   5,726,398       49.60%         50.40%       6.10%
# 51               Wyoming     576,412       50.80%         49.20%       6.60%
#
# 0  age_5 _to_ 17 age_18_ to_24 age_25_to_34 age_35_to_44 age_45_to_54  ...  \
# 1         17.10%        10.10%       12.60%       12.80%       13.90%  ...
# 2         18.20%        10.90%       14.90%       13.10%       14.20%  ...
# 3         18.00%        10.00%       13.40%       12.70%       12.80%  ...
# 4         17.60%         9.80%       12.90%       12.50%       13.40%  ...
# 5         17.60%        10.60%       14.40%       13.60%       13.70%  ...
# 6         17.20%         9.90%       14.60%       13.70%       14.00%  ...
# 7         16.70%         9.50%       12.00%       12.80%       15.80%  ...
# 8         16.20%        10.20%       12.40%       12.20%       14.60%  ...
# 9         11.10%        13.20%       22.00%       13.50%       12.00%  ...
# 10        15.20%         9.40%       12.30%       12.50%       14.20%  ...
# 11        18.40%        10.30%       13.60%       14.00%       14.00%  ...
# 12        15.40%         9.90%       14.30%       12.60%       13.30%  ...
# 13        19.50%         9.90%       13.20%       12.30%       12.70%  ...
# 14        17.50%         9.70%       13.80%       13.20%       14.20%  ...
# 15        17.80%        10.20%       12.70%       12.60%       14.10%  ...
# 16        17.10%        10.20%       12.70%       11.70%       13.80%  ...
# 17        18.00%        10.40%       13.30%       12.00%       13.50%  ...
# 18        16.90%         9.70%       12.80%       13.00%       14.30%  ...
# 19        17.60%        10.30%       14.00%       12.30%       13.80%  ...
# 20        15.00%         8.70%       11.10%       12.20%       15.80%  ...
# 21        16.60%         9.70%       13.60%       13.20%       15.20%  ...
# 22        15.60%        10.40%       13.30%       12.90%       15.10%  ...
# 23        17.20%        10.10%       11.90%       12.40%       14.70%  ...
# 24        17.30%         9.30%       13.70%       12.50%       14.60%  ...
# 25        18.30%        10.90%       12.50%       12.60%       13.30%  ...
# 26        17.10%         9.90%       13.10%       12.10%       14.20%  ...
# 27        16.00%         9.80%       12.30%       11.40%       14.10%  ...
# 28        17.80%        10.00%       13.40%       12.00%       13.50%  ...
# 29        17.50%         9.20%       14.30%       13.80%       13.60%  ...
# 30        15.90%         9.50%       11.20%       12.80%       16.60%  ...
# 31        16.90%         8.90%       12.70%       13.50%       15.40%  ...
# 32        17.90%        10.00%       13.20%       11.90%       13.30%  ...
# 33        15.80%        10.20%       14.10%       13.00%       14.50%  ...
# 34        17.10%        10.00%       12.80%       13.60%       14.00%  ...
# 35        15.60%        12.50%       14.10%       11.10%       13.20%  ...
# 36        17.10%         9.60%       12.40%       12.40%       14.50%  ...
# 37        17.70%        10.30%       13.50%       12.30%       13.30%  ...
# 38        16.10%         9.40%       13.70%       13.00%       13.40%  ...
# 39        15.80%         9.90%       12.30%       12.20%       14.70%  ...
# 40        15.30%        11.50%       12.30%       12.40%       15.00%  ...
# 41        16.60%        10.40%       12.70%       12.70%       13.70%  ...
# 42        17.50%        10.20%       13.30%       11.30%       13.30%  ...
# 43        16.90%         9.70%       13.10%       13.10%       14.00%  ...
# 44        19.40%        10.30%       14.40%       13.70%       13.20%  ...
# 45        22.00%        11.40%       15.60%       12.50%       10.80%  ...
# 46        14.80%        10.70%       11.20%       11.70%       15.60%  ...
# 47        16.50%        10.10%       13.90%       13.50%       14.60%  ...
# 48        16.60%         9.70%       14.10%       13.30%       14.00%  ...
# 49        15.00%         9.40%       11.80%       12.40%       14.20%  ...
# 50        16.90%         9.70%       12.80%       12.20%       14.90%  ...
# 51        17.10%        10.20%       13.90%       12.00%       13.50%  ...
#
# 0  units_with_mortgage mortgage_burden_lt_30 mortgage_burden_gte_30  \
# 1              735,220                71.70%                 28.30%
# 2              103,780                68.50%                 31.50%
# 3              982,521                66.30%                 33.70%
# 4              434,135                74.60%                 25.40%
# 5            4,977,097                54.10%                 45.90%
# 6              939,945                67.70%                 32.30%
# 7              640,037                61.20%                 38.80%
# 8              167,313                66.70%                 33.30%
# 9               86,530                67.90%                 32.10%
# 10           2,865,266                56.80%                 43.20%
# 11           1,546,204                67.20%                 32.80%
# 12             171,847                51.80%                 48.20%
# 13             268,966                67.30%                 32.70%
# 14           2,144,528                64.70%                 35.30%
# 15           1,165,731                76.20%                 23.80%
# 16             544,132                77.70%                 22.30%
# 17             460,783                75.00%                 25.00%
# 18             693,575                73.80%                 26.20%
# 19             623,870                71.40%                 28.60%
# 20             252,345                65.50%                 34.50%
# 21           1,074,050                66.70%                 33.30%
# 22           1,117,315                64.80%                 35.20%
# 23           1,718,142                69.50%                 30.50%
# 24           1,033,382                73.00%                 27.00%
# 25             391,694                68.10%                 31.90%
# 26           1,016,448                72.20%                 27.80%
# 27             158,320                68.20%                 31.80%
# 28             305,979                75.70%                 24.30%
# 29             394,315                60.80%                 39.20%
# 30             251,496                62.10%                 37.90%
# 31           1,455,023                56.20%                 43.80%
# 32             300,212                66.40%                 33.60%
# 33           2,490,162                60.60%                 39.40%
# 34           1,601,475                69.50%                 30.50%
# 35             101,113                82.60%                 17.40%
# 36           1,985,634                72.70%                 27.30%
# 37             552,726                73.90%                 26.10%
# 38             634,931                61.90%                 38.10%
# 39           2,113,471                69.80%                 30.20%
# 40             176,302                62.00%                 38.00%
# 41             738,930                69.80%                 30.20%
# 42             124,002                76.70%                 23.30%
# 43           1,016,333                69.30%                 30.70%
# 44           3,393,399                70.80%                 29.20%
# 45             453,147                68.20%                 31.80%
# 46             120,111                64.10%                 35.90%
# 47           1,430,357                68.50%                 31.50%
# 48           1,158,318                63.30%                 36.70%
# 49             257,167                77.50%                 22.50%
# 50           1,019,494                70.10%                 29.90%
# 51              88,605                75.60%                 24.40%
#
# 0  occupied_units_own owner_median_value occupied_units_with_rent  \
# 1           1,268,565            123,200                  493,033
# 2             159,427            245,100                   86,171
# 3           1,496,650            151,500                  831,643
# 4             757,722            107,600                  336,178
# 5           6,781,817            349,400                5,475,993
# 6           1,278,158            234,900                  683,923
# 7             908,452            267,800                  420,584
# 8             241,050            226,900                   93,193
# 9             110,681            460,700                  148,310
# 10          4,724,428            148,200                2,286,475
# 11          2,248,702            142,300                1,155,452
# 12            254,770            496,600                  175,406
# 13            398,671            154,500                  169,381
# 14          3,177,104            170,600                1,474,649
# 15          1,720,780            122,700                  699,727
# 16            882,584            126,300                  318,135
# 17            739,191            130,100                  344,536
# 18          1,144,309            120,800                  497,224
# 19          1,130,134            139,500                  512,367
# 20            396,014            172,300                  144,448
# 21          1,433,937            279,900                  686,289
# 22          1,570,055            323,800                  901,567
# 23          2,713,964            115,700                1,013,088
# 24          1,508,810            178,400                  566,699
# 25            743,611             99,800                  289,207
# 26          1,591,686            135,000                  699,981
# 27            274,196            184,800                  121,081
# 28            486,642            128,300                  227,545
# 29            552,324            150,700                  430,727
# 30            367,863            236,000                  142,508
# 31          2,081,481            311,600                1,057,959
# 32            518,106            157,500                  220,926
# 33          3,883,893            280,900                3,162,481
# 34          2,441,626            150,100                1,164,743
# 35            189,193            142,500                   91,424
# 36          3,019,382            127,600                1,414,197
# 37            960,369            114,300                  431,500
# 38            933,775            223,900                  542,876
# 39          3,416,499            163,800                1,418,661
# 40            247,790            234,600                  156,177
# 41          1,217,692            135,500                  500,702
# 42            217,200            134,300                   95,865
# 43          1,654,001            137,800                  732,968
# 44          5,586,856            129,200                3,121,220
# 45            623,589            199,700                  254,419
# 46            183,563            216,900                   69,443
# 47          2,010,442            237,800                  949,813
# 48          1,643,637            243,000                  934,954
# 49            533,758            100,400                  167,993
# 50          1,539,778            165,200                  706,393
# 51            154,329            187,400                   61,737
#
# 0  rent_burden_lt_30 rent_burden_gte_30 occupied_units_rent gross_median_rent
# 1             50.20%             49.80%             510,756               689
# 2             52.60%             47.40%              86,687             1,120
# 3             48.60%             51.40%             856,506               888
# 4             51.10%             48.90%             347,234               640
# 5             42.40%             57.60%           5,593,677             1,200
# 6             49.00%             51.00%             693,762               934
# 7             47.00%             53.00%             430,621             1,019
# 8             51.40%             48.60%              95,026               960
# 9             51.90%             48.10%             152,845             1,235
# 10            41.40%             58.60%           2,353,001               954
# 11            46.90%             53.10%           1,199,599               837
# 12            44.70%             55.30%             179,409             1,379
# 13            50.10%             49.90%             172,082               702
# 14            49.30%             50.70%           1,519,883               868
# 15            50.80%             49.20%             719,233               715
# 16            55.10%             44.90%             323,489               661
# 17            55.50%             44.50%             350,761               711
# 18            51.70%             48.30%             509,045               636
# 19            47.40%             52.60%             527,568               747
# 20            48.20%             51.80%             146,751               744
# 21            49.40%             50.60%             699,266             1,170
# 22            50.60%             49.40%             919,291             1,036
# 23            45.70%             54.30%           1,044,542               748
# 24            51.80%             48.20%             574,365               813
# 25            45.70%             54.30%             298,549               666
# 26            49.10%             50.90%             715,241               706
# 27            52.90%             47.10%             122,509               681
# 28            57.20%             42.80%             231,912               692
# 29            48.80%             51.20%             438,537               944
# 30            51.10%             48.90%             144,882               967
# 31            45.80%             54.20%           1,080,817             1,148
# 32            48.60%             51.40%             228,984               753
# 33            46.60%             53.40%           3,238,859             1,079
# 34            50.30%             49.70%           1,194,189               756
# 35            64.70%             35.30%              93,671               644
# 36            50.70%             49.30%           1,454,504               700
# 37            52.20%             47.80%             442,579               686
# 38            46.30%             53.70%             555,909               862
# 39            50.10%             49.90%           1,452,194               798
# 40            49.40%             50.60%             160,588               878
# 41            47.40%             52.60%             516,387               754
# 42            59.20%             40.80%              96,921               651
# 43            49.00%             51.00%             754,900               730
# 44            51.80%             48.20%           3,193,169               831
# 45            50.40%             49.60%             259,174               851
# 46            49.30%             50.70%              69,963               860
# 47            49.80%             50.20%             969,687             1,068
# 48            49.30%             50.70%             954,331               954
# 49            51.90%             48.10%             174,700               607
# 50            51.30%             48.70%             718,608               743
# 51            56.50%             43.50%              62,166               742
#
# [51 rows x 121 columns]

# %%
census_2012_pop_final = census_2012_pop_final.rename(columns = {'Label (Grouping)': 'State'})

# %%
census_2012_pop_final['Year'] = 2012
census_2012_pop_final
# Out:
# 0                  State   pop_total age_male_pop age_female_pop age_under_5  \
# 1                Alabama   4,822,023       48.50%         51.50%       6.30%
# 2                 Alaska     731,449       52.10%         47.90%       7.40%
# 3                Arizona   6,553,255       49.80%         50.20%       6.70%
# 4               Arkansas   2,949,131       49.10%         50.90%       6.50%
# 5             California  38,041,430       49.70%         50.30%       6.70%
# 6               Colorado   5,187,582       50.10%         49.90%       6.50%
# 7            Connecticut   3,590,347       48.70%         51.30%       5.40%
# 8               Delaware     917,092       48.50%         51.50%       6.10%
# 9   District of Columbia     632,323       47.30%         52.70%       6.20%
# 10               Florida  19,317,568       48.90%         51.10%       5.50%
# 11               Georgia   9,919,945       48.90%         51.10%       6.80%
# 12                Hawaii   1,392,313       50.40%         49.60%       6.40%
# 13                 Idaho   1,595,728       50.10%         49.90%       7.10%
# 14              Illinois  12,875,255       49.10%         50.90%       6.30%
# 15               Indiana   6,537,334       49.20%         50.80%       6.50%
# 16                  Iowa   3,074,186       49.60%         50.40%       6.40%
# 17                Kansas   2,885,905       49.70%         50.30%       7.00%
# 18              Kentucky   4,380,415       49.20%         50.80%       6.30%
# 19             Louisiana   4,601,893       48.90%         51.10%       6.70%
# 20                 Maine   1,329,192       49.00%         51.00%       5.00%
# 21              Maryland   5,884,563       48.40%         51.60%       6.20%
# 22         Massachusetts   6,646,144       48.40%         51.60%       5.50%
# 23              Michigan   9,883,360       49.10%         50.90%       5.80%
# 24             Minnesota   5,379,139       49.60%         50.40%       6.50%
# 25           Mississippi   2,984,926       48.30%         51.70%       6.80%
# 26              Missouri   6,021,988       49.00%         51.00%       6.20%
# 27               Montana   1,005,141       50.10%         49.90%       5.90%
# 28              Nebraska   1,855,525       49.70%         50.30%       7.10%
# 29                Nevada   2,758,931       50.40%         49.60%       6.60%
# 30         New Hampshire   1,320,718       49.10%         50.90%       5.00%
# 31            New Jersey   8,864,590       48.70%         51.30%       5.90%
# 32            New Mexico   2,085,538       49.60%         50.40%       6.90%
# 33              New York  19,570,261       48.50%         51.50%       5.90%
# 34        North Carolina   9,752,073       48.70%         51.30%       6.30%
# 35          North Dakota     699,628       51.10%         48.90%       6.40%
# 36                  Ohio  11,544,225       48.90%         51.10%       6.00%
# 37              Oklahoma   3,814,820       49.50%         50.50%       6.90%
# 38                Oregon   3,899,353       49.60%         50.40%       6.00%
# 39          Pennsylvania  12,763,536       48.80%         51.20%       5.60%
# 40          Rhode Island   1,050,292       48.30%         51.70%       5.30%
# 41        South Carolina   4,723,723       48.60%         51.40%       6.20%
# 42          South Dakota     833,354       50.10%         49.90%       7.00%
# 43             Tennessee   6,456,243       48.70%         51.30%       6.20%
# 44                 Texas  26,059,203       49.70%         50.30%       7.40%
# 45                  Utah   2,855,287       50.30%         49.70%       9.00%
# 46               Vermont     626,011       49.40%         50.60%       5.00%
# 47              Virginia   8,185,867       49.00%         51.00%       6.20%
# 48            Washington   6,897,012       49.90%         50.10%       6.40%
# 49         West Virginia   1,855,413       49.10%         50.90%       5.70%
# 50             Wisconsin   5,726,398       49.60%         50.40%       6.10%
# 51               Wyoming     576,412       50.80%         49.20%       6.60%
#
# 0  age_5 _to_ 17 age_18_ to_24 age_25_to_34 age_35_to_44 age_45_to_54  ...  \
# 1         17.10%        10.10%       12.60%       12.80%       13.90%  ...
# 2         18.20%        10.90%       14.90%       13.10%       14.20%  ...
# 3         18.00%        10.00%       13.40%       12.70%       12.80%  ...
# 4         17.60%         9.80%       12.90%       12.50%       13.40%  ...
# 5         17.60%        10.60%       14.40%       13.60%       13.70%  ...
# 6         17.20%         9.90%       14.60%       13.70%       14.00%  ...
# 7         16.70%         9.50%       12.00%       12.80%       15.80%  ...
# 8         16.20%        10.20%       12.40%       12.20%       14.60%  ...
# 9         11.10%        13.20%       22.00%       13.50%       12.00%  ...
# 10        15.20%         9.40%       12.30%       12.50%       14.20%  ...
# 11        18.40%        10.30%       13.60%       14.00%       14.00%  ...
# 12        15.40%         9.90%       14.30%       12.60%       13.30%  ...
# 13        19.50%         9.90%       13.20%       12.30%       12.70%  ...
# 14        17.50%         9.70%       13.80%       13.20%       14.20%  ...
# 15        17.80%        10.20%       12.70%       12.60%       14.10%  ...
# 16        17.10%        10.20%       12.70%       11.70%       13.80%  ...
# 17        18.00%        10.40%       13.30%       12.00%       13.50%  ...
# 18        16.90%         9.70%       12.80%       13.00%       14.30%  ...
# 19        17.60%        10.30%       14.00%       12.30%       13.80%  ...
# 20        15.00%         8.70%       11.10%       12.20%       15.80%  ...
# 21        16.60%         9.70%       13.60%       13.20%       15.20%  ...
# 22        15.60%        10.40%       13.30%       12.90%       15.10%  ...
# 23        17.20%        10.10%       11.90%       12.40%       14.70%  ...
# 24        17.30%         9.30%       13.70%       12.50%       14.60%  ...
# 25        18.30%        10.90%       12.50%       12.60%       13.30%  ...
# 26        17.10%         9.90%       13.10%       12.10%       14.20%  ...
# 27        16.00%         9.80%       12.30%       11.40%       14.10%  ...
# 28        17.80%        10.00%       13.40%       12.00%       13.50%  ...
# 29        17.50%         9.20%       14.30%       13.80%       13.60%  ...
# 30        15.90%         9.50%       11.20%       12.80%       16.60%  ...
# 31        16.90%         8.90%       12.70%       13.50%       15.40%  ...
# 32        17.90%        10.00%       13.20%       11.90%       13.30%  ...
# 33        15.80%        10.20%       14.10%       13.00%       14.50%  ...
# 34        17.10%        10.00%       12.80%       13.60%       14.00%  ...
# 35        15.60%        12.50%       14.10%       11.10%       13.20%  ...
# 36        17.10%         9.60%       12.40%       12.40%       14.50%  ...
# 37        17.70%        10.30%       13.50%       12.30%       13.30%  ...
# 38        16.10%         9.40%       13.70%       13.00%       13.40%  ...
# 39        15.80%         9.90%       12.30%       12.20%       14.70%  ...
# 40        15.30%        11.50%       12.30%       12.40%       15.00%  ...
# 41        16.60%        10.40%       12.70%       12.70%       13.70%  ...
# 42        17.50%        10.20%       13.30%       11.30%       13.30%  ...
# 43        16.90%         9.70%       13.10%       13.10%       14.00%  ...
# 44        19.40%        10.30%       14.40%       13.70%       13.20%  ...
# 45        22.00%        11.40%       15.60%       12.50%       10.80%  ...
# 46        14.80%        10.70%       11.20%       11.70%       15.60%  ...
# 47        16.50%        10.10%       13.90%       13.50%       14.60%  ...
# 48        16.60%         9.70%       14.10%       13.30%       14.00%  ...
# 49        15.00%         9.40%       11.80%       12.40%       14.20%  ...
# 50        16.90%         9.70%       12.80%       12.20%       14.90%  ...
# 51        17.10%        10.20%       13.90%       12.00%       13.50%  ...
#
# 0  mortgage_burden_lt_30 mortgage_burden_gte_30 occupied_units_own  \
# 1                 71.70%                 28.30%          1,268,565
# 2                 68.50%                 31.50%            159,427
# 3                 66.30%                 33.70%          1,496,650
# 4                 74.60%                 25.40%            757,722
# 5                 54.10%                 45.90%          6,781,817
# 6                 67.70%                 32.30%          1,278,158
# 7                 61.20%                 38.80%            908,452
# 8                 66.70%                 33.30%            241,050
# 9                 67.90%                 32.10%            110,681
# 10                56.80%                 43.20%          4,724,428
# 11                67.20%                 32.80%          2,248,702
# 12                51.80%                 48.20%            254,770
# 13                67.30%                 32.70%            398,671
# 14                64.70%                 35.30%          3,177,104
# 15                76.20%                 23.80%          1,720,780
# 16                77.70%                 22.30%            882,584
# 17                75.00%                 25.00%            739,191
# 18                73.80%                 26.20%          1,144,309
# 19                71.40%                 28.60%          1,130,134
# 20                65.50%                 34.50%            396,014
# 21                66.70%                 33.30%          1,433,937
# 22                64.80%                 35.20%          1,570,055
# 23                69.50%                 30.50%          2,713,964
# 24                73.00%                 27.00%          1,508,810
# 25                68.10%                 31.90%            743,611
# 26                72.20%                 27.80%          1,591,686
# 27                68.20%                 31.80%            274,196
# 28                75.70%                 24.30%            486,642
# 29                60.80%                 39.20%            552,324
# 30                62.10%                 37.90%            367,863
# 31                56.20%                 43.80%          2,081,481
# 32                66.40%                 33.60%            518,106
# 33                60.60%                 39.40%          3,883,893
# 34                69.50%                 30.50%          2,441,626
# 35                82.60%                 17.40%            189,193
# 36                72.70%                 27.30%          3,019,382
# 37                73.90%                 26.10%            960,369
# 38                61.90%                 38.10%            933,775
# 39                69.80%                 30.20%          3,416,499
# 40                62.00%                 38.00%            247,790
# 41                69.80%                 30.20%          1,217,692
# 42                76.70%                 23.30%            217,200
# 43                69.30%                 30.70%          1,654,001
# 44                70.80%                 29.20%          5,586,856
# 45                68.20%                 31.80%            623,589
# 46                64.10%                 35.90%            183,563
# 47                68.50%                 31.50%          2,010,442
# 48                63.30%                 36.70%          1,643,637
# 49                77.50%                 22.50%            533,758
# 50                70.10%                 29.90%          1,539,778
# 51                75.60%                 24.40%            154,329
#
# 0  owner_median_value occupied_units_with_rent rent_burden_lt_30  \
# 1             123,200                  493,033            50.20%
# 2             245,100                   86,171            52.60%
# 3             151,500                  831,643            48.60%
# 4             107,600                  336,178            51.10%
# 5             349,400                5,475,993            42.40%
# 6             234,900                  683,923            49.00%
# 7             267,800                  420,584            47.00%
# 8             226,900                   93,193            51.40%
# 9             460,700                  148,310            51.90%
# 10            148,200                2,286,475            41.40%
# 11            142,300                1,155,452            46.90%
# 12            496,600                  175,406            44.70%
# 13            154,500                  169,381            50.10%
# 14            170,600                1,474,649            49.30%
# 15            122,700                  699,727            50.80%
# 16            126,300                  318,135            55.10%
# 17            130,100                  344,536            55.50%
# 18            120,800                  497,224            51.70%
# 19            139,500                  512,367            47.40%
# 20            172,300                  144,448            48.20%
# 21            279,900                  686,289            49.40%
# 22            323,800                  901,567            50.60%
# 23            115,700                1,013,088            45.70%
# 24            178,400                  566,699            51.80%
# 25             99,800                  289,207            45.70%
# 26            135,000                  699,981            49.10%
# 27            184,800                  121,081            52.90%
# 28            128,300                  227,545            57.20%
# 29            150,700                  430,727            48.80%
# 30            236,000                  142,508            51.10%
# 31            311,600                1,057,959            45.80%
# 32            157,500                  220,926            48.60%
# 33            280,900                3,162,481            46.60%
# 34            150,100                1,164,743            50.30%
# 35            142,500                   91,424            64.70%
# 36            127,600                1,414,197            50.70%
# 37            114,300                  431,500            52.20%
# 38            223,900                  542,876            46.30%
# 39            163,800                1,418,661            50.10%
# 40            234,600                  156,177            49.40%
# 41            135,500                  500,702            47.40%
# 42            134,300                   95,865            59.20%
# 43            137,800                  732,968            49.00%
# 44            129,200                3,121,220            51.80%
# 45            199,700                  254,419            50.40%
# 46            216,900                   69,443            49.30%
# 47            237,800                  949,813            49.80%
# 48            243,000                  934,954            49.30%
# 49            100,400                  167,993            51.90%
# 50            165,200                  706,393            51.30%
# 51            187,400                   61,737            56.50%
#
# 0  rent_burden_gte_30 occupied_units_rent gross_median_rent  Year
# 1              49.80%             510,756               689  2012
# 2              47.40%              86,687             1,120  2012
# 3              51.40%             856,506               888  2012
# 4              48.90%             347,234               640  2012
# 5              57.60%           5,593,677             1,200  2012
# 6              51.00%             693,762               934  2012
# 7              53.00%             430,621             1,019  2012
# 8              48.60%              95,026               960  2012
# 9              48.10%             152,845             1,235  2012
# 10             58.60%           2,353,001               954  2012
# 11             53.10%           1,199,599               837  2012
# 12             55.30%             179,409             1,379  2012
# 13             49.90%             172,082               702  2012
# 14             50.70%           1,519,883               868  2012
# 15             49.20%             719,233               715  2012
# 16             44.90%             323,489               661  2012
# 17             44.50%             350,761               711  2012
# 18             48.30%             509,045               636  2012
# 19             52.60%             527,568               747  2012
# 20             51.80%             146,751               744  2012
# 21             50.60%             699,266             1,170  2012
# 22             49.40%             919,291             1,036  2012
# 23             54.30%           1,044,542               748  2012
# 24             48.20%             574,365               813  2012
# 25             54.30%             298,549               666  2012
# 26             50.90%             715,241               706  2012
# 27             47.10%             122,509               681  2012
# 28             42.80%             231,912               692  2012
# 29             51.20%             438,537               944  2012
# 30             48.90%             144,882               967  2012
# 31             54.20%           1,080,817             1,148  2012
# 32             51.40%             228,984               753  2012
# 33             53.40%           3,238,859             1,079  2012
# 34             49.70%           1,194,189               756  2012
# 35             35.30%              93,671               644  2012
# 36             49.30%           1,454,504               700  2012
# 37             47.80%             442,579               686  2012
# 38             53.70%             555,909               862  2012
# 39             49.90%           1,452,194               798  2012
# 40             50.60%             160,588               878  2012
# 41             52.60%             516,387               754  2012
# 42             40.80%              96,921               651  2012
# 43             51.00%             754,900               730  2012
# 44             48.20%           3,193,169               831  2012
# 45             49.60%             259,174               851  2012
# 46             50.70%              69,963               860  2012
# 47             50.20%             969,687             1,068  2012
# 48             50.70%             954,331               954  2012
# 49             48.10%             174,700               607  2012
# 50             48.70%             718,608               743  2012
# 51             43.50%              62,166               742  2012
#
# [51 rows x 122 columns]

# %%
census_2012_pop_final.dtypes
# Out:
# 0
# State                  object
# pop_total              object
# age_male_pop           object
# age_female_pop         object
# age_under_5            object
#                         ...
# rent_burden_lt_30      object
# rent_burden_gte_30     object
# occupied_units_rent    object
# gross_median_rent      object
# Year                    int64
# Length: 122, dtype: object

# %%
census_2017_pop_final = pd.read_csv('../data/census_2017_pop_final.csv')
census_2017_pop_final.head()
# Out:
#   Label (Grouping)    Alabama   Alaska    Arizona   Arkansas  California  \
# 0        pop_total  4,874,747  739,795  7,016,270  3,004,279  39,536,653
# 1     age_male_pop     48.40%   52.10%     49.70%     49.30%      49.70%
# 2   age_female_pop     51.60%   47.90%     50.30%     50.70%      50.30%
# 3      age_under_5      5.90%    7.20%      6.20%      6.20%       6.20%
# 4    age_5 _to_ 17     16.50%   17.90%     17.10%     17.40%      16.70%
#
#     Colorado Connecticut Delaware District of Columbia  ... South Dakota  \
# 0  5,607,154   3,588,184  961,939              693,972  ...      869,666
# 1     50.30%      48.80%   48.40%               47.40%  ...       50.40%
# 2     49.70%      51.20%   51.60%               52.60%  ...       49.60%
# 3      5.90%       5.10%    5.70%                6.50%  ...        7.00%
# 4     16.60%      15.60%   15.50%               11.50%  ...       17.60%
#
#    Tennessee       Texas       Utah  Vermont   Virginia Washington  \
# 0  6,715,984  28,304,596  3,101,833  623,657  8,470,020  7,405,743
# 1     48.70%      49.70%     50.40%   49.40%     49.20%     49.90%
# 2     51.30%      50.30%     49.60%   50.60%     50.80%     50.10%
# 3      6.00%       7.10%      8.20%    4.80%      5.90%      6.10%
# 4     16.40%      18.90%     21.70%   14.10%     16.10%     16.10%
#
#   West Virginia  Wisconsin  Wyoming
# 0     1,815,857  5,795,483  579,315
# 1        49.40%     49.70%   51.10%
# 2        50.60%     50.30%   48.90%
# 3         5.40%      5.80%    6.50%
# 4        15.20%     16.30%   17.30%
#
# [5 rows x 52 columns]

# %%
census_2017_pop_final = census_2017_pop_final.T.reset_index()
census_2017_pop_final.head(3)
# Out:
#               index          0             1               2            3  \
# 0  Label (Grouping)  pop_total  age_male_pop  age_female_pop  age_under_5
# 1           Alabama  4,874,747        48.40%          51.60%        5.90%
# 2            Alaska    739,795        52.10%          47.90%        7.20%
#
#                4              5             6             7             8  \
# 0  age_5 _to_ 17  age_18 _to_24  age_25_to_34  age_35_to_44  age_45_to_54
# 1         16.50%          9.70%        12.90%        12.20%        12.90%
# 2         17.90%          9.90%        16.00%        13.10%        12.00%
#
#    ...                  110                    111                     112  \
# 0  ...  units_with_mortgage  mortgage_burden_lt_30  mortgage_burden_gte_30
# 1  ...              701,526                 76.80%                  23.20%
# 2  ...              101,910                 70.70%                  29.30%
#
#                   113                 114                       115  \
# 0  occupied_units_own  owner_median_value  occupied_units_with_rent
# 1           1,253,199             141,300                   506,671
# 2             159,344             273,100                    83,787
#
#                  116                 117                    118  \
# 0  rent_burden_lt_30  rent_burden_gte_30  occupied_units_rented
# 1             52.60%              47.40%                525,186
# 2             54.20%              45.80%                 84,396
#
#                  119
# 0  gross_rent_median
# 1                750
# 2              1,201
#
# [3 rows x 121 columns]

# %%
census_2017_pop_final.columns = census_2017_pop_final.iloc[0]

# %%
census_2017_pop_final = census_2017_pop_final[1:]

# %%
census_2017_pop_final
# Out:
# 0       Label (Grouping)   pop_total age_male_pop age_female_pop age_under_5  \
# 1                Alabama   4,874,747       48.40%         51.60%       5.90%
# 2                 Alaska     739,795       52.10%         47.90%       7.20%
# 3                Arizona   7,016,270       49.70%         50.30%       6.20%
# 4               Arkansas   3,004,279       49.30%         50.70%       6.20%
# 5             California  39,536,653       49.70%         50.30%       6.20%
# 6               Colorado   5,607,154       50.30%         49.70%       5.90%
# 7            Connecticut   3,588,184       48.80%         51.20%       5.10%
# 8               Delaware     961,939       48.40%         51.60%       5.70%
# 9   District of Columbia     693,972       47.40%         52.60%       6.50%
# 10               Florida  20,984,400       48.90%         51.10%       5.40%
# 11               Georgia  10,429,379       48.60%         51.40%       6.30%
# 12                Hawaii   1,427,538       50.20%         49.80%       6.30%
# 13                 Idaho   1,716,943       50.20%         49.80%       6.80%
# 14              Illinois  12,802,023       49.20%         50.80%       6.00%
# 15               Indiana   6,666,818       49.30%         50.70%       6.30%
# 16                  Iowa   3,145,711       49.70%         50.30%       6.30%
# 17                Kansas   2,913,123       49.90%         50.10%       6.60%
# 18              Kentucky   4,454,189       49.30%         50.70%       6.20%
# 19             Louisiana   4,684,333       48.90%         51.10%       6.50%
# 20                 Maine   1,335,907       49.00%         51.00%       4.80%
# 21              Maryland   6,052,177       48.50%         51.50%       6.00%
# 22         Massachusetts   6,859,819       48.60%         51.40%       5.30%
# 23              Michigan   9,962,311       49.30%         50.70%       5.70%
# 24             Minnesota   5,576,606       49.90%         50.10%       6.30%
# 25           Mississippi   2,984,100       48.50%         51.50%       6.10%
# 26              Missouri   6,113,532       49.10%         50.90%       6.10%
# 27               Montana   1,050,493       50.10%         49.90%       5.80%
# 28              Nebraska   1,920,076       50.00%         50.00%       6.90%
# 29                Nevada   2,998,039       50.20%         49.80%       6.10%
# 30         New Hampshire   1,342,795       49.60%         50.40%       4.70%
# 31            New Jersey   9,005,644       48.80%         51.20%       5.80%
# 32            New Mexico   2,088,070       49.50%         50.50%       6.10%
# 33              New York  19,849,399       48.60%         51.40%       5.80%
# 34        North Carolina  10,273,419       48.70%         51.30%       5.90%
# 35          North Dakota     755,393       51.40%         48.60%       7.00%
# 36                  Ohio  11,658,609       49.00%         51.00%       6.00%
# 37              Oklahoma   3,930,864       49.60%         50.40%       6.70%
# 38                Oregon   4,142,776       49.60%         50.40%       5.60%
# 39          Pennsylvania  12,805,537       49.00%         51.00%       5.50%
# 40          Rhode Island   1,059,639       48.40%         51.60%       5.20%
# 41        South Carolina   5,024,369       48.50%         51.50%       5.80%
# 42          South Dakota     869,666       50.40%         49.60%       7.00%
# 43             Tennessee   6,715,984       48.70%         51.30%       6.00%
# 44                 Texas  28,304,596       49.70%         50.30%       7.10%
# 45                  Utah   3,101,833       50.40%         49.60%       8.20%
# 46               Vermont     623,657       49.40%         50.60%       4.80%
# 47              Virginia   8,470,020       49.20%         50.80%       5.90%
# 48            Washington   7,405,743       49.90%         50.10%       6.10%
# 49         West Virginia   1,815,857       49.40%         50.60%       5.40%
# 50             Wisconsin   5,795,483       49.70%         50.30%       5.80%
# 51               Wyoming     579,315       51.10%         48.90%       6.50%
#
# 0  age_5 _to_ 17 age_18 _to_24 age_25_to_34 age_35_to_44 age_45_to_54  ...  \
# 1         16.50%         9.70%       12.90%       12.20%       12.90%  ...
# 2         17.90%         9.90%       16.00%       13.10%       12.00%  ...
# 3         17.10%         9.60%       13.60%       12.20%       12.10%  ...
# 4         17.40%         9.60%       12.70%       12.30%       12.50%  ...
# 5         16.70%         9.60%       15.20%       13.20%       13.10%  ...
# 6         16.60%         9.30%       15.50%       13.60%       12.70%  ...
# 7         15.60%         9.80%       12.40%       11.70%       14.40%  ...
# 8         15.50%         8.70%       13.60%       11.50%       12.90%  ...
# 9         11.50%        10.80%       23.40%       14.70%       11.00%  ...
# 10        14.60%         8.40%       12.90%       12.10%       13.20%  ...
# 11        17.80%         9.80%       13.60%       13.30%       13.60%  ...
# 12        15.20%         8.70%       14.40%       12.70%       12.20%  ...
# 13        19.00%         9.40%       12.90%       12.60%       11.60%  ...
# 14        16.60%         9.40%       13.80%       12.90%       13.10%  ...
# 15        17.30%         9.90%       13.00%       12.30%       12.80%  ...
# 16        16.90%        10.20%       12.50%       11.90%       12.20%  ...
# 17        17.80%        10.20%       13.20%       12.20%       11.80%  ...
# 18        16.60%         9.40%       12.90%       12.50%       13.10%  ...
# 19        17.10%         9.70%       14.00%       12.60%       12.30%  ...
# 20        14.20%         8.20%       11.90%       11.30%       13.80%  ...
# 21        16.30%         8.90%       13.80%       12.80%       14.00%  ...
# 22        14.70%        10.20%       14.20%       12.20%       13.70%  ...
# 23        16.10%         9.70%       12.70%       11.60%       13.30%  ...
# 24        16.90%         9.00%       13.60%       12.60%       12.70%  ...
# 25        17.80%        10.40%       12.20%       12.70%       12.40%  ...
# 26        16.60%         9.40%       13.30%       11.90%       12.70%  ...
# 27        16.00%         9.20%       12.60%       11.90%       11.70%  ...
# 28        17.90%         9.70%       13.50%       12.30%       11.70%  ...
# 29        16.70%         8.40%       14.50%       13.30%       13.20%  ...
# 30        14.50%         9.40%       12.20%       11.30%       14.60%  ...
# 31        16.20%         8.80%       12.90%       12.90%       14.20%  ...
# 32        17.40%         9.90%       13.10%       12.00%       11.50%  ...
# 33        15.10%         9.40%       14.70%       12.50%       13.40%  ...
# 34        16.50%         9.50%       13.20%       12.70%       13.50%  ...
# 35        15.90%        11.40%       15.10%       11.80%       10.90%  ...
# 36        16.40%         9.20%       13.10%       11.90%       13.00%  ...
# 37        17.80%         9.70%       13.70%       12.40%       11.90%  ...
# 38        15.50%         8.90%       14.00%       13.30%       12.50%  ...
# 39        15.30%         9.20%       13.10%       11.60%       13.30%  ...
# 40        14.30%        10.90%       13.80%       11.60%       13.50%  ...
# 41        16.20%         9.50%       12.90%       12.30%       12.80%  ...
# 42        17.60%         9.40%       13.30%       11.50%       11.40%  ...
# 43        16.40%         9.20%       13.50%       12.50%       13.30%  ...
# 44        18.90%         9.90%       14.60%       13.50%       12.50%  ...
# 45        21.70%        11.30%       14.60%       13.70%       10.20%  ...
# 46        14.10%        10.70%       11.80%       11.10%       13.30%  ...
# 47        16.10%         9.70%       13.80%       13.10%       13.50%  ...
# 48        16.10%         8.90%       14.90%       13.20%       12.80%  ...
# 49        15.20%         9.00%       11.50%       12.20%       13.10%  ...
# 50        16.30%         9.60%       12.50%       12.10%       13.10%  ...
# 51        17.30%         9.20%       13.80%       12.20%       11.20%  ...
#
# 0  units_with_mortgage mortgage_burden_lt_30 mortgage_burden_gte_30  \
# 1              701,526                76.80%                 23.20%
# 2              101,910                70.70%                 29.30%
# 3            1,054,673                71.80%                 28.20%
# 4              413,269                78.80%                 21.20%
# 5            4,998,509                61.60%                 38.40%
# 6              989,124                72.80%                 27.20%
# 7              608,996                69.10%                 30.90%
# 8              161,515                72.00%                 28.00%
# 9               89,659                73.20%                 26.80%
# 10           2,823,933                67.00%                 33.00%
# 11           1,518,788                74.80%                 25.20%
# 12             171,040                61.00%                 39.00%
# 13             277,640                73.80%                 26.20%
# 14           1,998,263                72.80%                 27.20%
# 15           1,150,942                81.00%                 19.00%
# 16             551,903                81.10%                 18.90%
# 17             436,691                80.10%                 19.90%
# 18             664,901                78.10%                 21.90%
# 19             590,838                74.60%                 25.40%
# 20             241,999                73.70%                 26.30%
# 21           1,068,910                72.90%                 27.10%
# 22           1,131,683                70.60%                 29.40%
# 23           1,681,024                77.20%                 22.80%
# 24           1,036,113                78.20%                 21.80%
# 25             365,257                74.50%                 25.50%
# 26             984,417                78.40%                 21.60%
# 27             166,001                72.50%                 27.50%
# 28             303,797                79.00%                 21.00%
# 29             425,607                70.00%                 30.00%
# 30             242,001                73.10%                 26.90%
# 31           1,370,181                65.60%                 34.40%
# 32             275,210                70.10%                 29.90%
# 33           2,383,720                66.80%                 33.20%
# 34           1,623,484                75.90%                 24.10%
# 35             109,141                83.10%                 16.90%
# 36           1,920,911                79.40%                 20.60%
# 37             524,602                76.10%                 23.90%
# 38             668,558                68.20%                 31.80%
# 39           2,053,694                75.60%                 24.40%
# 40             171,802                68.40%                 31.60%
# 41             750,353                74.90%                 25.10%
# 42             128,467                80.90%                 19.10%
# 43             991,447                76.10%                 23.90%
# 44           3,420,493                74.20%                 25.80%
# 45             483,465                76.10%                 23.90%
# 46             110,178                67.90%                 32.10%
# 47           1,424,970                73.90%                 26.10%
# 48           1,222,198                71.10%                 28.90%
# 49             237,167                77.90%                 22.10%
# 50           1,000,528                77.60%                 22.40%
# 51              92,477                76.00%                 24.00%
#
# 0  occupied_units_own owner_median_value occupied_units_with_rent  \
# 1           1,253,199            141,300                  506,671
# 2             159,344            273,100                   83,787
# 3           1,652,321            223,400                  836,609
# 4             752,399            128,500                  355,860
# 5           7,125,090            509,400                5,588,574
# 6           1,394,824            348,900                  706,299
# 7             898,234            273,100                  430,519
# 8             253,948            252,800                   93,164
# 9             118,805            607,200                  152,388
# 10          5,010,187            214,000                2,492,817
# 11          2,354,922            173,700                1,285,297
# 12            268,078            617,400                  174,878
# 13            435,493            207,100                  172,758
# 14          3,182,232            195,300                1,512,887
# 15          1,765,500            141,100                  722,265
# 16            900,362            149,100                  328,803
# 17            743,508            150,600                  358,706
# 18          1,146,668            141,000                  510,116
# 19          1,132,229            162,500                  518,902
# 20            395,809            191,200                  131,372
# 21          1,472,500            312,500                  698,269
# 22          1,623,515            385,400                  929,089
# 23          2,803,372            155,700                1,044,041
# 24          1,547,594            224,000                  583,821
# 25            748,055            120,200                  288,505
# 26          1,596,870            156,700                  724,549
# 27            292,585            231,300                  118,284
# 28            500,086            155,800                  234,345
# 29            619,309            258,200                  451,440
# 30            369,037            263,600                  152,332
# 31          2,053,929            334,900                1,105,474
# 32            521,450            171,300                  217,299
# 33          3,930,033            314,500                3,184,751
# 34          2,586,616            171,200                1,248,740
# 35            200,554            194,700                  106,206
# 36          3,070,181            144,200                1,481,880
# 37            962,483            137,400                  452,404
# 38          1,007,015            319,200                  562,264
# 39          3,421,017            181,200                1,428,017
# 40            248,723            257,800                  150,957
# 41          1,309,670            161,800                  530,656
# 42            233,092            167,600                  102,898
# 43          1,693,790            167,500                  805,441
# 44          5,964,183            172,200                3,397,060
# 45            681,563            275,100                  276,654
# 46            178,405            226,300                   72,542
# 47          2,077,417            273,400                  972,670
# 48          1,783,549            339,000                  998,500
# 49            518,882            119,800                  160,122
# 50          1,565,599            178,900                  736,653
# 51            159,792            214,300                   58,977
#
# 0  rent_burden_lt_30 rent_burden_gte_30 occupied_units_rented  \
# 1             52.60%             47.40%               525,186
# 2             54.20%             45.80%                84,396
# 3             51.70%             48.30%               859,557
# 4             55.50%             44.50%               365,461
# 5             44.80%             55.20%             5,697,421
# 6             48.10%             51.90%               717,989
# 7             48.60%             51.40%               439,295
# 8             51.30%             48.70%                99,986
# 9             52.10%             47.90%               158,550
# 10            43.60%             56.40%             2,565,527
# 11            52.00%             48.00%             1,321,593
# 12            43.80%             56.20%               177,512
# 13            54.20%             45.80%               177,724
# 14            51.40%             48.60%             1,558,423
# 15            54.30%             45.70%               747,371
# 16            57.80%             42.20%               335,444
# 17            56.00%             44.00%               365,853
# 18            56.50%             43.50%               524,986
# 19            44.60%             55.40%               539,054
# 20            55.40%             44.60%               133,662
# 21            50.00%             50.00%               709,705
# 22            50.80%             49.20%               951,688
# 23            51.80%             48.20%             1,070,220
# 24            54.00%             46.00%               590,552
# 25            52.00%             48.00%               300,261
# 26            55.30%             44.70%               739,845
# 27            55.60%             44.40%               119,850
# 28            60.00%             40.00%               239,436
# 29            52.10%             47.90%               462,895
# 30            53.40%             46.60%               154,201
# 31            48.30%             51.70%             1,129,441
# 32            51.00%             49.00%               224,577
# 33            47.30%             52.70%             3,255,748
# 34            53.60%             46.40%             1,280,412
# 35            60.10%             39.90%               107,867
# 36            55.70%             44.30%             1,516,601
# 37            54.50%             45.50%               463,286
# 38            48.40%             51.60%               573,421
# 39            52.70%             47.30%             1,491,279
# 40            54.40%             45.60%               154,825
# 41            49.70%             50.30%               545,954
# 42            59.20%             40.80%               104,764
# 43            54.50%             45.50%               828,612
# 44            52.00%             48.00%             3,486,567
# 45            55.70%             44.30%               281,943
# 46            49.40%             50.60%                73,452
# 47            53.10%             46.90%               990,189
# 48            52.20%             47.80%             1,013,454
# 49            51.40%             48.60%               166,391
# 50            56.40%             43.60%               751,576
# 51            57.40%             42.60%                59,964
#
# 0  gross_rent_median
# 1                750
# 2              1,201
# 3              1,020
# 4                711
# 5              1,447
# 6              1,240
# 7              1,125
# 8              1,086
# 9              1,499
# 10             1,128
# 11               958
# 12             1,573
# 13               822
# 14               974
# 15               793
# 16               760
# 17               815
# 18               724
# 19               836
# 20               806
# 21             1,337
# 22             1,208
# 23               835
# 24               939
# 25               742
# 26               800
# 27               759
# 28               801
# 29             1,051
# 30             1,072
# 31             1,284
# 32               813
# 33             1,226
# 34               861
# 35               785
# 36               772
# 37               780
# 38             1,079
# 39               893
# 40               941
# 41               848
# 42               722
# 43               833
# 44               987
# 45               986
# 46               950
# 47             1,179
# 48             1,216
# 49               690
# 50               819
# 51               832
#
# [51 rows x 121 columns]

# %%
census_2017_pop_final = census_2017_pop_final.rename(columns = {'Label (Grouping)': 'State'})

# %%
census_2017_pop_final['Year'] = 2017
census_2017_pop_final.head()
# Out:
# 0       State   pop_total age_male_pop age_female_pop age_under_5  \
# 1     Alabama   4,874,747       48.40%         51.60%       5.90%
# 2      Alaska     739,795       52.10%         47.90%       7.20%
# 3     Arizona   7,016,270       49.70%         50.30%       6.20%
# 4    Arkansas   3,004,279       49.30%         50.70%       6.20%
# 5  California  39,536,653       49.70%         50.30%       6.20%
#
# 0 age_5 _to_ 17 age_18 _to_24 age_25_to_34 age_35_to_44 age_45_to_54  ...  \
# 1        16.50%         9.70%       12.90%       12.20%       12.90%  ...
# 2        17.90%         9.90%       16.00%       13.10%       12.00%  ...
# 3        17.10%         9.60%       13.60%       12.20%       12.10%  ...
# 4        17.40%         9.60%       12.70%       12.30%       12.50%  ...
# 5        16.70%         9.60%       15.20%       13.20%       13.10%  ...
#
# 0 mortgage_burden_lt_30 mortgage_burden_gte_30 occupied_units_own  \
# 1                76.80%                 23.20%          1,253,199
# 2                70.70%                 29.30%            159,344
# 3                71.80%                 28.20%          1,652,321
# 4                78.80%                 21.20%            752,399
# 5                61.60%                 38.40%          7,125,090
#
# 0 owner_median_value occupied_units_with_rent rent_burden_lt_30  \
# 1            141,300                  506,671            52.60%
# 2            273,100                   83,787            54.20%
# 3            223,400                  836,609            51.70%
# 4            128,500                  355,860            55.50%
# 5            509,400                5,588,574            44.80%
#
# 0 rent_burden_gte_30 occupied_units_rented gross_rent_median  Year
# 1             47.40%               525,186               750  2017
# 2             45.80%                84,396             1,201  2017
# 3             48.30%               859,557             1,020  2017
# 4             44.50%               365,461               711  2017
# 5             55.20%             5,697,421             1,447  2017
#
# [5 rows x 122 columns]

# %%
census_2022_pop_final = pd.read_csv('../data/census_2022_pop_final.csv')
census_2022_pop_final
# Out:
#              Label (Grouping)    Alabama   Alaska    Arizona   Arkansas  \
# 0                   pop_total  5,074,296  733,583  7,359,197  3,045,637
# 1                age_male_pop     48.50%   52.60%     50.00%     49.40%
# 2              age_female_pop     51.50%   47.40%     50.00%     50.60%
# 3                 age_under_5      5.60%    6.30%      5.30%      5.80%
# 4               age_5 _to_ 17     16.30%   17.60%     16.20%     17.00%
# ..                        ...        ...      ...        ...        ...
# 115  occupied_units_with_rent    517,883   84,809    867,455    359,076
# 116         rent_burden_lt_30     50.50%   56.90%     47.20%     54.20%
# 117        rent_burden_gte_30     49.50%   43.10%     52.80%     45.80%
# 118       occupied_units_rent    535,960   85,226    887,809    371,478
# 119         gross_median_rent        913    1,329      1,450        846
#
#      California   Colorado Connecticut   Delaware District of Columbia  ...  \
# 0    39,029,342  5,839,926   3,626,205  1,018,396              671,803  ...
# 1        50.10%     50.70%      49.00%     48.60%               47.60%  ...
# 2        49.90%     49.30%      51.00%     51.40%               52.40%  ...
# 3         5.40%      5.20%       4.90%      5.30%                5.80%  ...
# 4        16.30%     15.50%      15.20%     15.10%               12.70%  ...
# ..          ...        ...         ...        ...                  ...  ...
# 115   5,676,089    765,346     448,123     96,742              184,218  ...
# 116      44.00%     46.80%      46.60%     51.70%               52.60%  ...
# 117      56.00%     53.20%      53.40%     48.30%               47.40%  ...
# 118   5,782,651    774,741     460,870     98,064              188,879  ...
# 119       1,870      1,646       1,360      1,274                1,843  ...
#
#     South Dakota  Tennessee       Texas       Utah  Vermont   Virginia  \
# 0        909,824  7,051,339  30,029,572  3,380,800  647,064  8,683,619
# 1         50.80%     49.10%      50.00%     50.80%   49.60%     49.50%
# 2         49.20%     50.90%      50.00%     49.20%   50.40%     50.50%
# 3          6.30%      5.70%       6.30%      6.80%    4.30%      5.50%
# 4         17.80%     16.10%      18.50%     20.80%   13.30%     15.90%
# ..           ...        ...         ...        ...      ...        ...
# 115      101,764    842,660   3,893,814    307,419   67,396  1,027,030
# 116       60.60%     51.20%      47.00%     52.40%   49.10%     50.30%
# 117       39.40%     48.80%      53.00%     47.60%   50.90%     49.70%
# 118      103,522    862,913   3,977,897    310,688   68,909  1,047,336
# 119          866      1,096       1,290      1,372    1,141      1,441
#
#     Washington West Virginia  Wisconsin  Wyoming
# 0    7,785,786     1,775,156  5,892,539  581,381
# 1       50.50%        49.70%     50.20%   51.20%
# 2       49.50%        50.30%     49.80%   48.80%
# 3        5.40%         4.90%      5.20%    5.20%
# 4       15.70%        14.90%     15.80%   17.10%
# ..         ...           ...        ...      ...
# 115  1,046,656       155,499    748,787   58,178
# 116     48.80%        49.50%     54.60%   55.90%
# 117     51.20%        50.50%     45.40%   44.10%
# 118  1,063,333       160,930    763,110   59,616
# 119      1,630           795        992      895
#
# [120 rows x 52 columns]

# %%
census_2022_pop_final = census_2022_pop_final.T.reset_index()
census_2022_pop_final.head(3)
# Out:
#               index          0             1               2            3  \
# 0  Label (Grouping)  pop_total  age_male_pop  age_female_pop  age_under_5
# 1           Alabama  5,074,296        48.50%          51.50%        5.60%
# 2            Alaska    733,583        52.60%          47.40%        6.30%
#
#                4              5             6             7             8  \
# 0  age_5 _to_ 17  age_18_ to_24  age_25_to_34  age_35_to_44  age_45_to_54
# 1         16.30%          9.60%        12.90%        12.50%        12.20%
# 2         17.60%          9.40%        15.50%        14.30%        11.20%
#
#    ...                  110                    111                     112  \
# 0  ...  units_with_mortgage  mortgage_burden_lt_30  mortgage_burden_gte_30
# 1  ...              768,014                 77.00%                  23.00%
# 2  ...              110,040                 70.90%                  29.10%
#
#                   113                 114                       115  \
# 0  occupied_units_own  owner_median_value  occupied_units_with_rent
# 1           1,416,333             200,900                   517,883
# 2             181,586             336,900                    84,809
#
#                  116                 117                  118  \
# 0  rent_burden_lt_30  rent_burden_gte_30  occupied_units_rent
# 1             50.50%              49.50%              535,960
# 2             56.90%              43.10%               85,226
#
#                  119
# 0  gross_median_rent
# 1                913
# 2              1,329
#
# [3 rows x 121 columns]

# %%
census_2022_pop_final.columns = census_2022_pop_final.iloc[0]

# %%
census_2022_pop_final = census_2022_pop_final[1:]

# %%
census_2022_pop_final
# Out:
# 0       Label (Grouping)   pop_total age_male_pop age_female_pop age_under_5  \
# 1                Alabama   5,074,296       48.50%         51.50%       5.60%
# 2                 Alaska     733,583       52.60%         47.40%       6.30%
# 3                Arizona   7,359,197       50.00%         50.00%       5.30%
# 4               Arkansas   3,045,637       49.40%         50.60%       5.80%
# 5             California  39,029,342       50.10%         49.90%       5.40%
# 6               Colorado   5,839,926       50.70%         49.30%       5.20%
# 7            Connecticut   3,626,205       49.00%         51.00%       4.90%
# 8               Delaware   1,018,396       48.60%         51.40%       5.30%
# 9   District of Columbia     671,803       47.60%         52.40%       5.80%
# 10               Florida  22,244,823       49.20%         50.80%       5.00%
# 11               Georgia  10,912,876       48.80%         51.20%       5.70%
# 12                Hawaii   1,440,196       50.40%         49.60%       5.50%
# 13                 Idaho   1,939,033       50.40%         49.60%       5.80%
# 14              Illinois  12,582,032       49.50%         50.50%       5.40%
# 15               Indiana   6,833,037       49.70%         50.30%       5.80%
# 16                  Iowa   3,200,517       50.20%         49.80%       5.60%
# 17                Kansas   2,937,150       50.20%         49.80%       6.00%
# 18              Kentucky   4,512,310       49.50%         50.50%       5.80%
# 19             Louisiana   4,590,241       49.00%         51.00%       5.90%
# 20                 Maine   1,385,340       49.40%         50.60%       4.40%
# 21              Maryland   6,164,660       48.70%         51.30%       5.70%
# 22         Massachusetts   6,981,974       49.00%         51.00%       4.90%
# 23              Michigan  10,034,118       49.60%         50.40%       5.30%
# 24             Minnesota   5,717,184       50.20%         49.80%       5.70%
# 25           Mississippi   2,940,057       48.50%         51.50%       5.80%
# 26              Missouri   6,177,957       49.30%         50.70%       5.70%
# 27               Montana   1,122,867       50.50%         49.50%       5.10%
# 28              Nebraska   1,967,923       50.20%         49.80%       6.20%
# 29                Nevada   3,177,772       50.30%         49.70%       5.40%
# 30         New Hampshire   1,395,231       49.90%         50.10%       4.50%
# 31            New Jersey   9,261,699       49.30%         50.70%       5.50%
# 32            New Mexico   2,113,344       49.60%         50.40%       5.00%
# 33              New York  19,677,151       48.90%         51.10%       5.40%
# 34        North Carolina  10,698,973       48.90%         51.10%       5.50%
# 35          North Dakota     779,261       51.20%         48.80%       6.10%
# 36                  Ohio  11,756,058       49.40%         50.60%       5.60%
# 37              Oklahoma   4,019,800       49.90%         50.10%       6.00%
# 38                Oregon   4,240,137       50.00%         50.00%       4.70%
# 39          Pennsylvania  12,972,008       49.30%         50.70%       5.20%
# 40          Rhode Island   1,093,734       49.00%         51.00%       4.80%
# 41        South Carolina   5,282,634       48.60%         51.40%       5.30%
# 42          South Dakota     909,824       50.80%         49.20%       6.30%
# 43             Tennessee   7,051,339       49.10%         50.90%       5.70%
# 44                 Texas  30,029,572       50.00%         50.00%       6.30%
# 45                  Utah   3,380,800       50.80%         49.20%       6.80%
# 46               Vermont     647,064       49.60%         50.40%       4.30%
# 47              Virginia   8,683,619       49.50%         50.50%       5.50%
# 48            Washington   7,785,786       50.50%         49.50%       5.40%
# 49         West Virginia   1,775,156       49.70%         50.30%       4.90%
# 50             Wisconsin   5,892,539       50.20%         49.80%       5.20%
# 51               Wyoming     581,381       51.20%         48.80%       5.20%
#
# 0  age_5 _to_ 17 age_18_ to_24 age_25_to_34 age_35_to_44 age_45_to_54  ...  \
# 1         16.30%         9.60%       12.90%       12.50%       12.20%  ...
# 2         17.60%         9.40%       15.50%       14.30%       11.20%  ...
# 3         16.20%         9.80%       13.80%       12.60%       11.60%  ...
# 4         17.00%         9.60%       12.70%       12.70%       11.90%  ...
# 5         16.30%         9.40%       14.70%       13.80%       12.50%  ...
# 6         15.50%         9.30%       15.70%       14.70%       12.10%  ...
# 7         15.20%         9.70%       12.40%       12.70%       12.60%  ...
# 8         15.10%         8.50%       12.80%       12.30%       11.10%  ...
# 9         12.70%        10.20%       21.60%       16.60%       10.70%  ...
# 10        14.40%         8.30%       12.50%       12.60%       12.30%  ...
# 11        17.30%         9.80%       13.60%       13.50%       12.80%  ...
# 12        15.10%         8.30%       13.20%       13.30%       11.80%  ...
# 13        18.20%        10.00%       12.90%       13.20%       11.30%  ...
# 14        16.20%         9.30%       13.40%       13.30%       12.40%  ...
# 15        17.10%         9.90%       13.00%       12.70%       11.90%  ...
# 16        16.80%        10.10%       12.60%       12.70%       11.30%  ...
# 17        17.40%        10.40%       12.80%       13.00%       11.00%  ...
# 18        16.50%         9.20%       13.00%       12.60%       12.40%  ...
# 19        17.20%         9.50%       12.90%       13.30%       11.60%  ...
# 20        13.30%         7.90%       12.00%       12.30%       12.20%  ...
# 21        16.20%         8.60%       13.10%       13.60%       12.50%  ...
# 22        14.20%        10.00%       13.90%       13.00%       12.30%  ...
# 23        15.60%         9.50%       13.10%       12.20%       12.00%  ...
# 24        16.80%         8.90%       13.00%       13.70%       11.50%  ...
# 25        17.20%        10.20%       12.00%       12.90%       12.00%  ...
# 26        16.40%         9.40%       13.10%       12.90%       11.60%  ...
# 27        15.80%         9.20%       13.00%       13.00%       11.00%  ...
# 28        18.00%         9.80%       12.80%       13.40%       11.00%  ...
# 29        16.30%         8.30%       14.40%       13.90%       12.50%  ...
# 30        13.50%         8.50%       13.00%       12.30%       12.30%  ...
# 31        15.90%         8.50%       12.80%       13.30%       12.90%  ...
# 32        16.60%         9.70%       13.00%       13.00%       11.30%  ...
# 33        14.90%         9.20%       14.00%       12.90%       12.20%  ...
# 34        16.00%         9.70%       13.30%       12.90%       12.60%  ...
# 35        17.10%        10.70%       14.50%       13.70%        9.70%  ...
# 36        16.10%         9.10%       13.10%       12.60%       11.90%  ...
# 37        17.70%        10.10%       13.30%       13.20%       11.40%  ...
# 38        14.90%         8.60%       14.10%       14.00%       12.40%  ...
# 39        15.10%         9.20%       12.90%       12.50%       11.90%  ...
# 40        13.80%        10.30%       13.80%       12.60%       11.80%  ...
# 41        15.80%         9.50%       12.60%       12.60%       11.90%  ...
# 42        17.80%         9.40%       12.20%       12.80%       10.70%  ...
# 43        16.10%         9.20%       13.70%       12.90%       12.30%  ...
# 44        18.50%        10.00%       14.40%       14.10%       12.30%  ...
# 45        20.80%        12.00%       14.60%       13.60%       11.00%  ...
# 46        13.30%        10.20%       12.00%       12.40%       11.70%  ...
# 47        15.90%         9.70%       13.30%       13.60%       12.30%  ...
# 48        15.70%         8.60%       15.10%       14.30%       12.00%  ...
# 49        14.90%         9.10%       11.70%       12.20%       12.50%  ...
# 50        15.80%         9.50%       12.50%       12.60%       11.80%  ...
# 51        17.10%         8.90%       12.50%       14.00%       11.10%  ...
#
# 0  units_with_mortgage mortgage_burden_lt_30 mortgage_burden_gte_30  \
# 1              768,014                77.00%                 23.00%
# 2              110,040                70.90%                 29.10%
# 3            1,180,749                73.70%                 26.30%
# 4              424,171                77.30%                 22.70%
# 5            5,044,333                62.20%                 37.80%
# 6            1,089,369                70.60%                 29.40%
# 7              610,624                70.20%                 29.80%
# 8              187,123                75.80%                 24.20%
# 9               98,488                73.30%                 26.70%
# 10           3,315,723                65.80%                 34.20%
# 11           1,705,941                75.00%                 25.00%
# 12             192,102                58.20%                 41.80%
# 13             324,332                72.50%                 27.50%
# 14           2,065,838                73.10%                 26.90%
# 15           1,220,587                79.70%                 20.30%
# 16             567,684                79.70%                 20.30%
# 17             455,414                77.30%                 22.70%
# 18             709,096                77.10%                 22.90%
# 19             630,584                71.70%                 28.30%
# 20             262,894                70.50%                 29.50%
# 21           1,137,581                73.60%                 26.40%
# 22           1,136,176                69.70%                 30.30%
# 23           1,724,683                76.00%                 24.00%
# 24           1,072,513                76.30%                 23.70%
# 25             397,659                73.10%                 26.90%
# 26           1,019,748                78.20%                 21.80%
# 27             172,843                71.20%                 28.80%
# 28             313,450                77.60%                 22.40%
# 29             473,798                69.00%                 31.00%
# 30             246,059                71.30%                 28.70%
# 31           1,433,834                68.40%                 31.60%
# 32             319,989                70.50%                 29.50%
# 33           2,438,822                66.70%                 33.30%
# 34           1,770,630                76.30%                 23.70%
# 35             115,609                77.60%                 22.40%
# 36           1,977,558                79.30%                 20.70%
# 37             549,866                75.20%                 24.80%
# 38             704,150                68.10%                 31.90%
# 39           2,114,599                75.80%                 24.20%
# 40             185,919                71.50%                 28.50%
# 41             882,309                74.80%                 25.20%
# 42             137,709                77.90%                 22.10%
# 43           1,095,432                74.90%                 25.10%
# 44           3,864,485                70.90%                 29.10%
# 45             549,786                76.20%                 23.80%
# 46             125,139                70.10%                 29.90%
# 47           1,516,532                75.00%                 25.00%
# 48           1,294,678                70.50%                 29.50%
# 49             258,075                81.30%                 18.70%
# 50           1,031,942                76.50%                 23.50%
# 51             101,037                73.70%                 26.30%
#
# 0  occupied_units_own owner_median_value occupied_units_with_rent  \
# 1           1,416,333            200,900                  517,883
# 2             181,586            336,900                   84,809
# 3           1,921,746            402,800                  867,455
# 4             808,558            179,800                  359,076
# 5           7,565,502            715,900                5,676,089
# 6           1,584,309            531,100                  765,346
# 7             949,839            347,200                  448,123
# 8             298,075            337,200                   96,742
# 9             134,120            711,100                  184,218
# 10          5,929,801            354,100                2,702,155
# 11          2,695,885            297,400                1,284,614
# 12            309,687            820,100                  169,332
# 13            518,837            432,500                  182,763
# 14          3,392,312            251,600                1,539,742
# 15          1,929,865            208,700                  732,040
# 16            958,700            194,600                  344,220
# 17            795,989            206,600                  353,755
# 18          1,257,737            196,300                  506,343
# 19          1,229,012            209,200                  510,856
# 20            448,772            290,600                  141,929
# 21          1,609,588            398,100                  719,269
# 22          1,741,555            534,700                  998,422
# 23          2,991,685            224,400                1,008,054
# 24          1,674,434            314,600                  612,136
# 25            803,006            162,500                  288,541
# 26          1,704,800            221,200                  750,087
# 27            319,421            366,400                  130,917
# 28            529,723            232,400                  253,593
# 29            722,684            434,700                  450,409
# 30            402,656            384,700                  146,987
# 31          2,272,995            428,900                1,184,923
# 32            601,666            243,100                  220,351
# 33          4,204,337            400,400                3,362,842
# 34          2,868,467            280,600                1,300,902
# 35            215,896            243,100                  108,146
# 36          3,285,052            204,100                1,469,501
# 37          1,029,003            191,700                  491,980
# 38          1,084,786            475,600                  602,411
# 39          3,658,207            245,500                1,504,487
# 40            282,617            383,900                  153,503
# 41          1,538,550            254,600                  532,907
# 42            256,326            245,000                  101,764
# 43          1,914,030            284,800                  842,660
# 44          6,926,616            275,400                3,893,814
# 45            804,164            499,500                  307,419
# 46            204,089            304,700                   67,396
# 47          2,278,062            365,700                1,027,030
# 48          1,976,259            569,500                1,046,656
# 49            548,389            155,100                  155,499
# 50          1,696,493            252,800                  748,787
# 51            176,863            292,300                   58,178
#
# 0  rent_burden_lt_30 rent_burden_gte_30 occupied_units_rent gross_median_rent
# 1             50.50%             49.50%             535,960               913
# 2             56.90%             43.10%              85,226             1,329
# 3             47.20%             52.80%             887,809             1,450
# 4             54.20%             45.80%             371,478               846
# 5             44.00%             56.00%           5,782,651             1,870
# 6             46.80%             53.20%             774,741             1,646
# 7             46.60%             53.40%             460,870             1,360
# 8             51.70%             48.30%              98,064             1,274
# 9             52.60%             47.40%             188,879             1,843
# 10            39.70%             60.30%           2,769,772             1,525
# 11            48.20%             51.80%           1,320,725             1,269
# 12            42.20%             57.80%             172,870             1,813
# 13            52.80%             47.20%             184,918             1,138
# 14            50.40%             49.60%           1,590,443             1,170
# 15            51.10%             48.90%             752,539               972
# 16            54.90%             45.10%             352,241               891
# 17            53.40%             46.60%             359,319               975
# 18            52.10%             47.90%             521,485               891
# 19            44.20%             55.80%             527,591               984
# 20            52.80%             47.20%             144,692             1,033
# 21            48.00%             52.00%             737,102             1,550
# 22            46.60%             53.40%           1,020,504             1,634
# 23            49.20%             50.80%           1,034,449             1,052
# 24            50.10%             49.90%             621,782             1,200
# 25            49.20%             50.80%             300,135               873
# 26            54.00%             46.00%             766,858               954
# 27            55.50%             44.50%             132,641             1,005
# 28            53.30%             46.70%             259,347               983
# 29            42.70%             57.30%             462,009             1,461
# 30            51.30%             48.70%             148,407             1,396
# 31            47.90%             52.10%           1,207,994             1,555
# 32            46.70%             53.30%             225,333               955
# 33            47.60%             52.40%           3,446,021             1,499
# 34            51.60%             48.40%           1,331,663             1,131
# 35            59.40%             40.60%             109,541               863
# 36            53.20%             46.80%           1,507,424               949
# 37            52.50%             47.50%             502,801               937
# 38            46.80%             53.20%             612,751             1,370
# 39            51.40%             48.60%           1,540,239             1,116
# 40            52.10%             47.90%             156,790             1,254
# 41            47.80%             52.20%             546,743             1,084
# 42            60.60%             39.40%             103,522               866
# 43            51.20%             48.80%             862,913             1,096
# 44            47.00%             53.00%           3,977,897             1,290
# 45            52.40%             47.60%             310,688             1,372
# 46            49.10%             50.90%              68,909             1,141
# 47            50.30%             49.70%           1,047,336             1,441
# 48            48.80%             51.20%           1,063,333             1,630
# 49            49.50%             50.50%             160,930               795
# 50            54.60%             45.40%             763,110               992
# 51            55.90%             44.10%              59,616               895
#
# [51 rows x 121 columns]

# %%
census_2022_pop_final = census_2022_pop_final.rename(columns = {'Label (Grouping)': 'State'})

# %%
census_2022_pop_final['Year'] = 2022
census_2022_pop_final
# Out:
# 0                  State   pop_total age_male_pop age_female_pop age_under_5  \
# 1                Alabama   5,074,296       48.50%         51.50%       5.60%
# 2                 Alaska     733,583       52.60%         47.40%       6.30%
# 3                Arizona   7,359,197       50.00%         50.00%       5.30%
# 4               Arkansas   3,045,637       49.40%         50.60%       5.80%
# 5             California  39,029,342       50.10%         49.90%       5.40%
# 6               Colorado   5,839,926       50.70%         49.30%       5.20%
# 7            Connecticut   3,626,205       49.00%         51.00%       4.90%
# 8               Delaware   1,018,396       48.60%         51.40%       5.30%
# 9   District of Columbia     671,803       47.60%         52.40%       5.80%
# 10               Florida  22,244,823       49.20%         50.80%       5.00%
# 11               Georgia  10,912,876       48.80%         51.20%       5.70%
# 12                Hawaii   1,440,196       50.40%         49.60%       5.50%
# 13                 Idaho   1,939,033       50.40%         49.60%       5.80%
# 14              Illinois  12,582,032       49.50%         50.50%       5.40%
# 15               Indiana   6,833,037       49.70%         50.30%       5.80%
# 16                  Iowa   3,200,517       50.20%         49.80%       5.60%
# 17                Kansas   2,937,150       50.20%         49.80%       6.00%
# 18              Kentucky   4,512,310       49.50%         50.50%       5.80%
# 19             Louisiana   4,590,241       49.00%         51.00%       5.90%
# 20                 Maine   1,385,340       49.40%         50.60%       4.40%
# 21              Maryland   6,164,660       48.70%         51.30%       5.70%
# 22         Massachusetts   6,981,974       49.00%         51.00%       4.90%
# 23              Michigan  10,034,118       49.60%         50.40%       5.30%
# 24             Minnesota   5,717,184       50.20%         49.80%       5.70%
# 25           Mississippi   2,940,057       48.50%         51.50%       5.80%
# 26              Missouri   6,177,957       49.30%         50.70%       5.70%
# 27               Montana   1,122,867       50.50%         49.50%       5.10%
# 28              Nebraska   1,967,923       50.20%         49.80%       6.20%
# 29                Nevada   3,177,772       50.30%         49.70%       5.40%
# 30         New Hampshire   1,395,231       49.90%         50.10%       4.50%
# 31            New Jersey   9,261,699       49.30%         50.70%       5.50%
# 32            New Mexico   2,113,344       49.60%         50.40%       5.00%
# 33              New York  19,677,151       48.90%         51.10%       5.40%
# 34        North Carolina  10,698,973       48.90%         51.10%       5.50%
# 35          North Dakota     779,261       51.20%         48.80%       6.10%
# 36                  Ohio  11,756,058       49.40%         50.60%       5.60%
# 37              Oklahoma   4,019,800       49.90%         50.10%       6.00%
# 38                Oregon   4,240,137       50.00%         50.00%       4.70%
# 39          Pennsylvania  12,972,008       49.30%         50.70%       5.20%
# 40          Rhode Island   1,093,734       49.00%         51.00%       4.80%
# 41        South Carolina   5,282,634       48.60%         51.40%       5.30%
# 42          South Dakota     909,824       50.80%         49.20%       6.30%
# 43             Tennessee   7,051,339       49.10%         50.90%       5.70%
# 44                 Texas  30,029,572       50.00%         50.00%       6.30%
# 45                  Utah   3,380,800       50.80%         49.20%       6.80%
# 46               Vermont     647,064       49.60%         50.40%       4.30%
# 47              Virginia   8,683,619       49.50%         50.50%       5.50%
# 48            Washington   7,785,786       50.50%         49.50%       5.40%
# 49         West Virginia   1,775,156       49.70%         50.30%       4.90%
# 50             Wisconsin   5,892,539       50.20%         49.80%       5.20%
# 51               Wyoming     581,381       51.20%         48.80%       5.20%
#
# 0  age_5 _to_ 17 age_18_ to_24 age_25_to_34 age_35_to_44 age_45_to_54  ...  \
# 1         16.30%         9.60%       12.90%       12.50%       12.20%  ...
# 2         17.60%         9.40%       15.50%       14.30%       11.20%  ...
# 3         16.20%         9.80%       13.80%       12.60%       11.60%  ...
# 4         17.00%         9.60%       12.70%       12.70%       11.90%  ...
# 5         16.30%         9.40%       14.70%       13.80%       12.50%  ...
# 6         15.50%         9.30%       15.70%       14.70%       12.10%  ...
# 7         15.20%         9.70%       12.40%       12.70%       12.60%  ...
# 8         15.10%         8.50%       12.80%       12.30%       11.10%  ...
# 9         12.70%        10.20%       21.60%       16.60%       10.70%  ...
# 10        14.40%         8.30%       12.50%       12.60%       12.30%  ...
# 11        17.30%         9.80%       13.60%       13.50%       12.80%  ...
# 12        15.10%         8.30%       13.20%       13.30%       11.80%  ...
# 13        18.20%        10.00%       12.90%       13.20%       11.30%  ...
# 14        16.20%         9.30%       13.40%       13.30%       12.40%  ...
# 15        17.10%         9.90%       13.00%       12.70%       11.90%  ...
# 16        16.80%        10.10%       12.60%       12.70%       11.30%  ...
# 17        17.40%        10.40%       12.80%       13.00%       11.00%  ...
# 18        16.50%         9.20%       13.00%       12.60%       12.40%  ...
# 19        17.20%         9.50%       12.90%       13.30%       11.60%  ...
# 20        13.30%         7.90%       12.00%       12.30%       12.20%  ...
# 21        16.20%         8.60%       13.10%       13.60%       12.50%  ...
# 22        14.20%        10.00%       13.90%       13.00%       12.30%  ...
# 23        15.60%         9.50%       13.10%       12.20%       12.00%  ...
# 24        16.80%         8.90%       13.00%       13.70%       11.50%  ...
# 25        17.20%        10.20%       12.00%       12.90%       12.00%  ...
# 26        16.40%         9.40%       13.10%       12.90%       11.60%  ...
# 27        15.80%         9.20%       13.00%       13.00%       11.00%  ...
# 28        18.00%         9.80%       12.80%       13.40%       11.00%  ...
# 29        16.30%         8.30%       14.40%       13.90%       12.50%  ...
# 30        13.50%         8.50%       13.00%       12.30%       12.30%  ...
# 31        15.90%         8.50%       12.80%       13.30%       12.90%  ...
# 32        16.60%         9.70%       13.00%       13.00%       11.30%  ...
# 33        14.90%         9.20%       14.00%       12.90%       12.20%  ...
# 34        16.00%         9.70%       13.30%       12.90%       12.60%  ...
# 35        17.10%        10.70%       14.50%       13.70%        9.70%  ...
# 36        16.10%         9.10%       13.10%       12.60%       11.90%  ...
# 37        17.70%        10.10%       13.30%       13.20%       11.40%  ...
# 38        14.90%         8.60%       14.10%       14.00%       12.40%  ...
# 39        15.10%         9.20%       12.90%       12.50%       11.90%  ...
# 40        13.80%        10.30%       13.80%       12.60%       11.80%  ...
# 41        15.80%         9.50%       12.60%       12.60%       11.90%  ...
# 42        17.80%         9.40%       12.20%       12.80%       10.70%  ...
# 43        16.10%         9.20%       13.70%       12.90%       12.30%  ...
# 44        18.50%        10.00%       14.40%       14.10%       12.30%  ...
# 45        20.80%        12.00%       14.60%       13.60%       11.00%  ...
# 46        13.30%        10.20%       12.00%       12.40%       11.70%  ...
# 47        15.90%         9.70%       13.30%       13.60%       12.30%  ...
# 48        15.70%         8.60%       15.10%       14.30%       12.00%  ...
# 49        14.90%         9.10%       11.70%       12.20%       12.50%  ...
# 50        15.80%         9.50%       12.50%       12.60%       11.80%  ...
# 51        17.10%         8.90%       12.50%       14.00%       11.10%  ...
#
# 0  mortgage_burden_lt_30 mortgage_burden_gte_30 occupied_units_own  \
# 1                 77.00%                 23.00%          1,416,333
# 2                 70.90%                 29.10%            181,586
# 3                 73.70%                 26.30%          1,921,746
# 4                 77.30%                 22.70%            808,558
# 5                 62.20%                 37.80%          7,565,502
# 6                 70.60%                 29.40%          1,584,309
# 7                 70.20%                 29.80%            949,839
# 8                 75.80%                 24.20%            298,075
# 9                 73.30%                 26.70%            134,120
# 10                65.80%                 34.20%          5,929,801
# 11                75.00%                 25.00%          2,695,885
# 12                58.20%                 41.80%            309,687
# 13                72.50%                 27.50%            518,837
# 14                73.10%                 26.90%          3,392,312
# 15                79.70%                 20.30%          1,929,865
# 16                79.70%                 20.30%            958,700
# 17                77.30%                 22.70%            795,989
# 18                77.10%                 22.90%          1,257,737
# 19                71.70%                 28.30%          1,229,012
# 20                70.50%                 29.50%            448,772
# 21                73.60%                 26.40%          1,609,588
# 22                69.70%                 30.30%          1,741,555
# 23                76.00%                 24.00%          2,991,685
# 24                76.30%                 23.70%          1,674,434
# 25                73.10%                 26.90%            803,006
# 26                78.20%                 21.80%          1,704,800
# 27                71.20%                 28.80%            319,421
# 28                77.60%                 22.40%            529,723
# 29                69.00%                 31.00%            722,684
# 30                71.30%                 28.70%            402,656
# 31                68.40%                 31.60%          2,272,995
# 32                70.50%                 29.50%            601,666
# 33                66.70%                 33.30%          4,204,337
# 34                76.30%                 23.70%          2,868,467
# 35                77.60%                 22.40%            215,896
# 36                79.30%                 20.70%          3,285,052
# 37                75.20%                 24.80%          1,029,003
# 38                68.10%                 31.90%          1,084,786
# 39                75.80%                 24.20%          3,658,207
# 40                71.50%                 28.50%            282,617
# 41                74.80%                 25.20%          1,538,550
# 42                77.90%                 22.10%            256,326
# 43                74.90%                 25.10%          1,914,030
# 44                70.90%                 29.10%          6,926,616
# 45                76.20%                 23.80%            804,164
# 46                70.10%                 29.90%            204,089
# 47                75.00%                 25.00%          2,278,062
# 48                70.50%                 29.50%          1,976,259
# 49                81.30%                 18.70%            548,389
# 50                76.50%                 23.50%          1,696,493
# 51                73.70%                 26.30%            176,863
#
# 0  owner_median_value occupied_units_with_rent rent_burden_lt_30  \
# 1             200,900                  517,883            50.50%
# 2             336,900                   84,809            56.90%
# 3             402,800                  867,455            47.20%
# 4             179,800                  359,076            54.20%
# 5             715,900                5,676,089            44.00%
# 6             531,100                  765,346            46.80%
# 7             347,200                  448,123            46.60%
# 8             337,200                   96,742            51.70%
# 9             711,100                  184,218            52.60%
# 10            354,100                2,702,155            39.70%
# 11            297,400                1,284,614            48.20%
# 12            820,100                  169,332            42.20%
# 13            432,500                  182,763            52.80%
# 14            251,600                1,539,742            50.40%
# 15            208,700                  732,040            51.10%
# 16            194,600                  344,220            54.90%
# 17            206,600                  353,755            53.40%
# 18            196,300                  506,343            52.10%
# 19            209,200                  510,856            44.20%
# 20            290,600                  141,929            52.80%
# 21            398,100                  719,269            48.00%
# 22            534,700                  998,422            46.60%
# 23            224,400                1,008,054            49.20%
# 24            314,600                  612,136            50.10%
# 25            162,500                  288,541            49.20%
# 26            221,200                  750,087            54.00%
# 27            366,400                  130,917            55.50%
# 28            232,400                  253,593            53.30%
# 29            434,700                  450,409            42.70%
# 30            384,700                  146,987            51.30%
# 31            428,900                1,184,923            47.90%
# 32            243,100                  220,351            46.70%
# 33            400,400                3,362,842            47.60%
# 34            280,600                1,300,902            51.60%
# 35            243,100                  108,146            59.40%
# 36            204,100                1,469,501            53.20%
# 37            191,700                  491,980            52.50%
# 38            475,600                  602,411            46.80%
# 39            245,500                1,504,487            51.40%
# 40            383,900                  153,503            52.10%
# 41            254,600                  532,907            47.80%
# 42            245,000                  101,764            60.60%
# 43            284,800                  842,660            51.20%
# 44            275,400                3,893,814            47.00%
# 45            499,500                  307,419            52.40%
# 46            304,700                   67,396            49.10%
# 47            365,700                1,027,030            50.30%
# 48            569,500                1,046,656            48.80%
# 49            155,100                  155,499            49.50%
# 50            252,800                  748,787            54.60%
# 51            292,300                   58,178            55.90%
#
# 0  rent_burden_gte_30 occupied_units_rent gross_median_rent  Year
# 1              49.50%             535,960               913  2022
# 2              43.10%              85,226             1,329  2022
# 3              52.80%             887,809             1,450  2022
# 4              45.80%             371,478               846  2022
# 5              56.00%           5,782,651             1,870  2022
# 6              53.20%             774,741             1,646  2022
# 7              53.40%             460,870             1,360  2022
# 8              48.30%              98,064             1,274  2022
# 9              47.40%             188,879             1,843  2022
# 10             60.30%           2,769,772             1,525  2022
# 11             51.80%           1,320,725             1,269  2022
# 12             57.80%             172,870             1,813  2022
# 13             47.20%             184,918             1,138  2022
# 14             49.60%           1,590,443             1,170  2022
# 15             48.90%             752,539               972  2022
# 16             45.10%             352,241               891  2022
# 17             46.60%             359,319               975  2022
# 18             47.90%             521,485               891  2022
# 19             55.80%             527,591               984  2022
# 20             47.20%             144,692             1,033  2022
# 21             52.00%             737,102             1,550  2022
# 22             53.40%           1,020,504             1,634  2022
# 23             50.80%           1,034,449             1,052  2022
# 24             49.90%             621,782             1,200  2022
# 25             50.80%             300,135               873  2022
# 26             46.00%             766,858               954  2022
# 27             44.50%             132,641             1,005  2022
# 28             46.70%             259,347               983  2022
# 29             57.30%             462,009             1,461  2022
# 30             48.70%             148,407             1,396  2022
# 31             52.10%           1,207,994             1,555  2022
# 32             53.30%             225,333               955  2022
# 33             52.40%           3,446,021             1,499  2022
# 34             48.40%           1,331,663             1,131  2022
# 35             40.60%             109,541               863  2022
# 36             46.80%           1,507,424               949  2022
# 37             47.50%             502,801               937  2022
# 38             53.20%             612,751             1,370  2022
# 39             48.60%           1,540,239             1,116  2022
# 40             47.90%             156,790             1,254  2022
# 41             52.20%             546,743             1,084  2022
# 42             39.40%             103,522               866  2022
# 43             48.80%             862,913             1,096  2022
# 44             53.00%           3,977,897             1,290  2022
# 45             47.60%             310,688             1,372  2022
# 46             50.90%              68,909             1,141  2022
# 47             49.70%           1,047,336             1,441  2022
# 48             51.20%           1,063,333             1,630  2022
# 49             50.50%             160,930               795  2022
# 50             45.40%             763,110               992  2022
# 51             44.10%              59,616               895  2022
#
# [51 rows x 122 columns]

# %%
all_agriculture = pd.concat([veg_2012, veg_2017, veg_2022, hort_2012, hort_2017, hort_2022], ignore_index = True)

# %%
all_agriculture
# Out:
#        Program  Year Period Geo Level    State  State ANSI         Commodity  \
# 0       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 1       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 2       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 3       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 4       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# ...        ...   ...    ...       ...      ...         ...               ...
# 357712  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357713  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357714  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357715  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357716  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
#
#                                                 Data Item         Domain  \
# 0                    BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1       BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2       BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3       BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                           BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# ...                                                   ...            ...
# 357712  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...          TOTAL
# 357713  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
# 357714  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
# 357715  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
# 357716  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
#
#                               Domain Category    Value CV (%)
# 0                               NOT SPECIFIED      154   64.1
# 1                               NOT SPECIFIED       30   16.4
# 2                               NOT SPECIFIED      154   64.1
# 3                               NOT SPECIFIED       30   16.4
# 4       AREA OPERATED: (1,000 TO 1,999 ACRES)       27   14.6
# ...                                       ...      ...    ...
# 357712                          NOT SPECIFIED   42,526   60.2
# 357713                          NOT SPECIFIED       52   18.9
# 357714                          NOT SPECIFIED       52   18.9
# 357715                          NOT SPECIFIED  449,063   64.9
# 357716                          NOT SPECIFIED   77,105   44.1
#
# [357717 rows x 12 columns]

# %%
census_2012_pop_final.columns.to_list()
# Out:
# ['State',
#  'pop_total',
#  'age_male_pop',
#  'age_female_pop',
#  'age_under_5',
#  'age_5 _to_ 17',
#  'age_18_ to_24',
#  'age_25_to_34',
#  'age_35_to_44',
#  'age_45_to_54',
#  'age_55_to_64',
#  'age_65_to_74',
#  'age_75_and_older',
#  'median_age_in_years',
#  'median_age_18_and_over',
#  'median_age_21_and_over',
#  'median_age_62_and_over',
#  'median_age_65_and_over',
#  'households_pop',
#  'family_households',
#  'families_with_kids_u18',
#  'married_couple_family',
#  'married_couple_kids_18',
#  'female_households_no_husband',
#  'female_households_kids_u18',
#  'nonfamily_households',
#  'nonfamily_male_households',
#  'nonfamily_male_living_alone',
#  'nonfamily_male_not_living_alone',
#  'nonfamily_female_households',
#  'nonfamily_female_living_alone',
#  'nonfamily_female_not_living_alone',
#  'avg_hh_size',
#  'avg_family_size',
#  'pop_15_plus',
#  'now_married',
#  'widowed',
#  'divorced',
#  'separated',
#  'never_married',
#  'pop_25_plus',
#  'less_hs_diploma',
#  'hs_grad',
#  'some_college_assoc',
#  'bachelors_deg',
#  'grad_prof_deg',
#  'hs_grad_plus',
#  'bachelors_plus',
#  'civilian_pop_ni_total',
#  'civilian_pop_with_disability',
#  'employed_status_pop_16_plus',
#  'in_labor_force',
#  'not_in_labor_force',
#  'employed_pop_16_plus',
#  'occ_mgt_science_arts',
#  'occ_service',
#  'occ_sales_office',
#  'occ_natural_resources',
#  'occ_production_trans',
#  'industry_employed_pop_16_plus',
#  'industry_ag_forest_fishing_mining',
#  'pop_hh_income_12months',
#  'median_hh_income',
#  'with_earnings',
#  'mean_earnings',
#  'with_ss_income',
#  'mean_ss_income',
#  'with_ssi_income',
#  'mean_ssi_income',
#  'with_cash_aid',
#  'mean_cash_aid',
#  'with_retirement_income',
#  'mean_retirement_income',
#  'with_snap',
#  'pop_families_with_income',
#  'median_family-income',
#  'married_couple_family',
#  'median_income_married_couple',
#  'male_household_no_spouse',
#  'median_income_male_hh',
#  'female_household_no_spouse',
#  'median_income_female_hh',
#  'individuals_income_group',
#  'per_capita_income',
#  'poverty_all_families',
#  'poverty_families_kids_u18',
#  'poverty_families_ kids_u5',
#  'poverty_married_family',
#  'poverty_married_kids_u18',
#  'poverty_married_kids_u5',
#  'poverty_female_hh',
#  'poverty_female_hh_kids_u18',
#  'poverty_female_hh_kids_u5',
#  'poverty_all_people',
#  'poverty_under_18',
#  'poverty_related_kids_u18',
#  'poverty_related_kids_u5',
#  'poverty_related_kids_5_to_17',
#  'poverty_18_plus',
#  'poverty_18_to_64',
#  'poverty_65_plus',
#  'poverty_in_families',
#  'poverty_unrelated_15_plus',
#  'occupied_housing_units_total',
#  'owner_occupied_units',
#  'renter_occupied_units',
#  'avg_owner_hh_size',
#  'avg_renter_hh_size',
#  'occupied_units_vehicles',
#  'no_vehicles',
#  'vehicles_1_or_more',
#  'units_with_mortgage',
#  'mortgage_burden_lt_30',
#  'mortgage_burden_gte_30',
#  'occupied_units_own',
#  'owner_median_value',
#  'occupied_units_with_rent',
#  'rent_burden_lt_30',
#  'rent_burden_gte_30',
#  'occupied_units_rent',
#  'gross_median_rent',
#  'Year']

# %%
census_2012_pop_final.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
columns = census_2012_pop_final.columns

# %%
dupe_columns = columns[columns.duplicated()].to_list()
dupe_columns
# Out:
# ['married_couple_family']

# %%
census_2012_pop_final.columns.to_list()
# Out:
# ['State',
#  'pop_total',
#  'age_male_pop',
#  'age_female_pop',
#  'age_under_5',
#  'age_5 _to_ 17',
#  'age_18_ to_24',
#  'age_25_to_34',
#  'age_35_to_44',
#  'age_45_to_54',
#  'age_55_to_64',
#  'age_65_to_74',
#  'age_75_and_older',
#  'median_age_in_years',
#  'median_age_18_and_over',
#  'median_age_21_and_over',
#  'median_age_62_and_over',
#  'median_age_65_and_over',
#  'households_pop',
#  'family_households',
#  'families_with_kids_u18',
#  'married_couple_family',
#  'married_couple_kids_18',
#  'female_households_no_husband',
#  'female_households_kids_u18',
#  'nonfamily_households',
#  'nonfamily_male_households',
#  'nonfamily_male_living_alone',
#  'nonfamily_male_not_living_alone',
#  'nonfamily_female_households',
#  'nonfamily_female_living_alone',
#  'nonfamily_female_not_living_alone',
#  'avg_hh_size',
#  'avg_family_size',
#  'pop_15_plus',
#  'now_married',
#  'widowed',
#  'divorced',
#  'separated',
#  'never_married',
#  'pop_25_plus',
#  'less_hs_diploma',
#  'hs_grad',
#  'some_college_assoc',
#  'bachelors_deg',
#  'grad_prof_deg',
#  'hs_grad_plus',
#  'bachelors_plus',
#  'civilian_pop_ni_total',
#  'civilian_pop_with_disability',
#  'employed_status_pop_16_plus',
#  'in_labor_force',
#  'not_in_labor_force',
#  'employed_pop_16_plus',
#  'occ_mgt_science_arts',
#  'occ_service',
#  'occ_sales_office',
#  'occ_natural_resources',
#  'occ_production_trans',
#  'industry_employed_pop_16_plus',
#  'industry_ag_forest_fishing_mining',
#  'pop_hh_income_12months',
#  'median_hh_income',
#  'with_earnings',
#  'mean_earnings',
#  'with_ss_income',
#  'mean_ss_income',
#  'with_ssi_income',
#  'mean_ssi_income',
#  'with_cash_aid',
#  'mean_cash_aid',
#  'with_retirement_income',
#  'mean_retirement_income',
#  'with_snap',
#  'pop_families_with_income',
#  'median_family-income',
#  'married_couple_family',
#  'median_income_married_couple',
#  'male_household_no_spouse',
#  'median_income_male_hh',
#  'female_household_no_spouse',
#  'median_income_female_hh',
#  'individuals_income_group',
#  'per_capita_income',
#  'poverty_all_families',
#  'poverty_families_kids_u18',
#  'poverty_families_ kids_u5',
#  'poverty_married_family',
#  'poverty_married_kids_u18',
#  'poverty_married_kids_u5',
#  'poverty_female_hh',
#  'poverty_female_hh_kids_u18',
#  'poverty_female_hh_kids_u5',
#  'poverty_all_people',
#  'poverty_under_18',
#  'poverty_related_kids_u18',
#  'poverty_related_kids_u5',
#  'poverty_related_kids_5_to_17',
#  'poverty_18_plus',
#  'poverty_18_to_64',
#  'poverty_65_plus',
#  'poverty_in_families',
#  'poverty_unrelated_15_plus',
#  'occupied_housing_units_total',
#  'owner_occupied_units',
#  'renter_occupied_units',
#  'avg_owner_hh_size',
#  'avg_renter_hh_size',
#  'occupied_units_vehicles',
#  'no_vehicles',
#  'vehicles_1_or_more',
#  'units_with_mortgage',
#  'mortgage_burden_lt_30',
#  'mortgage_burden_gte_30',
#  'occupied_units_own',
#  'owner_median_value',
#  'occupied_units_with_rent',
#  'rent_burden_lt_30',
#  'rent_burden_gte_30',
#  'occupied_units_rent',
#  'gross_median_rent',
#  'Year']

# %%
match_columns = [index for index, columns in enumerate(census_2012_pop_final.columns) if columns == 'married_couple_family']
match_columns
# Out:
# [21, 76]

# %%
census_2012_pop_final.columns.values[match_columns[1]] = 'married_couple_income'

# %%
census_2012_pop_final.columns.to_list()
# Out:
# ['State',
#  'pop_total',
#  'age_male_pop',
#  'age_female_pop',
#  'age_under_5',
#  'age_5 _to_ 17',
#  'age_18_ to_24',
#  'age_25_to_34',
#  'age_35_to_44',
#  'age_45_to_54',
#  'age_55_to_64',
#  'age_65_to_74',
#  'age_75_and_older',
#  'median_age_in_years',
#  'median_age_18_and_over',
#  'median_age_21_and_over',
#  'median_age_62_and_over',
#  'median_age_65_and_over',
#  'households_pop',
#  'family_households',
#  'families_with_kids_u18',
#  'married_couple_family',
#  'married_couple_kids_18',
#  'female_households_no_husband',
#  'female_households_kids_u18',
#  'nonfamily_households',
#  'nonfamily_male_households',
#  'nonfamily_male_living_alone',
#  'nonfamily_male_not_living_alone',
#  'nonfamily_female_households',
#  'nonfamily_female_living_alone',
#  'nonfamily_female_not_living_alone',
#  'avg_hh_size',
#  'avg_family_size',
#  'pop_15_plus',
#  'now_married',
#  'widowed',
#  'divorced',
#  'separated',
#  'never_married',
#  'pop_25_plus',
#  'less_hs_diploma',
#  'hs_grad',
#  'some_college_assoc',
#  'bachelors_deg',
#  'grad_prof_deg',
#  'hs_grad_plus',
#  'bachelors_plus',
#  'civilian_pop_ni_total',
#  'civilian_pop_with_disability',
#  'employed_status_pop_16_plus',
#  'in_labor_force',
#  'not_in_labor_force',
#  'employed_pop_16_plus',
#  'occ_mgt_science_arts',
#  'occ_service',
#  'occ_sales_office',
#  'occ_natural_resources',
#  'occ_production_trans',
#  'industry_employed_pop_16_plus',
#  'industry_ag_forest_fishing_mining',
#  'pop_hh_income_12months',
#  'median_hh_income',
#  'with_earnings',
#  'mean_earnings',
#  'with_ss_income',
#  'mean_ss_income',
#  'with_ssi_income',
#  'mean_ssi_income',
#  'with_cash_aid',
#  'mean_cash_aid',
#  'with_retirement_income',
#  'mean_retirement_income',
#  'with_snap',
#  'pop_families_with_income',
#  'median_family-income',
#  'married_couple_income',
#  'median_income_married_couple',
#  'male_household_no_spouse',
#  'median_income_male_hh',
#  'female_household_no_spouse',
#  'median_income_female_hh',
#  'individuals_income_group',
#  'per_capita_income',
#  'poverty_all_families',
#  'poverty_families_kids_u18',
#  'poverty_families_ kids_u5',
#  'poverty_married_family',
#  'poverty_married_kids_u18',
#  'poverty_married_kids_u5',
#  'poverty_female_hh',
#  'poverty_female_hh_kids_u18',
#  'poverty_female_hh_kids_u5',
#  'poverty_all_people',
#  'poverty_under_18',
#  'poverty_related_kids_u18',
#  'poverty_related_kids_u5',
#  'poverty_related_kids_5_to_17',
#  'poverty_18_plus',
#  'poverty_18_to_64',
#  'poverty_65_plus',
#  'poverty_in_families',
#  'poverty_unrelated_15_plus',
#  'occupied_housing_units_total',
#  'owner_occupied_units',
#  'renter_occupied_units',
#  'avg_owner_hh_size',
#  'avg_renter_hh_size',
#  'occupied_units_vehicles',
#  'no_vehicles',
#  'vehicles_1_or_more',
#  'units_with_mortgage',
#  'mortgage_burden_lt_30',
#  'mortgage_burden_gte_30',
#  'occupied_units_own',
#  'owner_median_value',
#  'occupied_units_with_rent',
#  'rent_burden_lt_30',
#  'rent_burden_gte_30',
#  'occupied_units_rent',
#  'gross_median_rent',
#  'Year']

# %%
match_columns_2017 = [index for index, columns in enumerate(census_2017_pop_final.columns) if columns == 'married_couple_family']
match_columns
# Out:
# [21, 76]

# %%
census_2017_pop_final.columns.values[match_columns[1]] = 'married_couple_income'

# %%
census_2017_pop_final.columns.to_list()
# Out:
# ['State',
#  'pop_total',
#  'age_male_pop',
#  'age_female_pop',
#  'age_under_5',
#  'age_5 _to_ 17',
#  'age_18 _to_24',
#  'age_25_to_34',
#  'age_35_to_44',
#  'age_45_to_54',
#  'age_55_to_64',
#  'age_65_to_74',
#  'age_75_and_older',
#  'median_age_in_years',
#  'median_age_18_and_over',
#  'median_age_21_and_over',
#  'median_age_62_and_over',
#  'median_age_65_and_over',
#  'households_pop',
#  'family_households',
#  'families_with_kids_u18',
#  'married_couple_family',
#  'married_couple_kids_18',
#  'female_households_no_husband',
#  'female_households_kids_u18',
#  'nonfamily_households',
#  'nonfamily_male_households',
#  'nonfamily_male_living_alone',
#  'nonfamily_male_not_living_alone',
#  'nonfamily_female_households',
#  'nonfamily_female_living_alone',
#  'nonfamily_female_not_living_alone',
#  'avg_hh_size',
#  'avg_family_size',
#  'pop_15_plus',
#  'now_married',
#  'widowed',
#  'divorced',
#  'separated',
#  'never_married',
#  'pop_25_plus',
#  'less_hs_diploma',
#  'hs_grad',
#  'some_college_assoc',
#  'bachelors_deg',
#  'grad_prof_deg',
#  'hs_grad_plus',
#  'bachelors_plus',
#  'civilian_pop_ni_total',
#  'civilian_pop_with_disability',
#  'employed_status_pop_16_plus',
#  'in_labor_force',
#  'not_in_labor_force',
#  'employed_pop_16_plus',
#  'occ_mgt_science_arts',
#  'occ_service',
#  'occ_sales_office',
#  'occ_natural_resources',
#  'occ_production_trans',
#  'industry_employed_pop_16_plus',
#  'industry_ag_forest_fishing_mining',
#  'pop_hh_income_12months',
#  'median_hh_income',
#  'with_earnings',
#  'mean_earnings',
#  'with_ss_income',
#  'mean_ss_income',
#  'with_ssi_income',
#  'mean_ssi_income',
#  'with_cash_aid',
#  'mean_cash_aid',
#  'with_retirement_income',
#  'mean_retirement_income',
#  'with_snap',
#  'pop_families_with_income',
#  'median_family-income',
#  'married_couple_income',
#  'median_income_married_couple',
#  'male_household_no_spouse',
#  'median_income_male_hh',
#  'female_household_no_spouse',
#  'median_income_female_hh',
#  'individuals_income_group',
#  'per_capita_income',
#  'poverty_all_families',
#  'poverty_families_kids_u18',
#  'poverty_families_kids_u5',
#  'poverty_married_family',
#  'poverty_married_kids_u18',
#  'poverty_married_kids_u5',
#  'poverty_female_hh',
#  'poverty_female_hh_kids_u18',
#  'poverty_female_hh_kids_u5',
#  'poverty_all_people',
#  'poverty_under_18',
#  'poverty_related_kids_u18',
#  'poverty_related_kids_u5',
#  'poverty_related_kids_5_to_17',
#  'poverty_18_plus',
#  'poverty_18_to_64',
#  'poverty_65_plus',
#  'poverty_in_families',
#  'poverty_unrelated_15_plus',
#  'occupied_housing_units_total',
#  'owner_occupied_units',
#  'renter_occupied_units',
#  'avg_owner_hh_size',
#  'avg_renter_hh_size',
#  'occupied_units_vehicles',
#  'no_vehicles',
#  'vehicles_1_or_more',
#  'units_with_mortgage',
#  'mortgage_burden_lt_30',
#  'mortgage_burden_gte_30',
#  'occupied_units_own',
#  'owner_median_value',
#  'occupied_units_with_rent',
#  'rent_burden_lt_30',
#  'rent_burden_gte_30',
#  'occupied_units_rented',
#  'gross_rent_median',
#  'Year']

# %%
dupes_2017 = census_2017_pop_final.columns[census_2017_pop_final.columns.duplicated()].tolist()
print(dupes_2017)
# Out:
# []

# %%
match_columns_2022 = [index for index, columns in enumerate(census_2022_pop_final.columns) if columns == 'married_couple_family']
match_columns
# Out:
# [21, 76]

# %%
census_2022_pop_final.columns.values[match_columns[1]] = 'married_couple_income'

# %%
census_2022_pop_final.columns.to_list()
# Out:
# ['State',
#  'pop_total',
#  'age_male_pop',
#  'age_female_pop',
#  'age_under_5',
#  'age_5 _to_ 17',
#  'age_18_ to_24',
#  'age_25_to_34',
#  'age_35_to_44',
#  'age_45_to_54',
#  'age_55_to_64',
#  'age_65_to_74',
#  'age_75_and_older',
#  'median_age_in_years',
#  'median_age_18_and_over',
#  'median_age_21_and_over',
#  'median_age_62_and_over',
#  'median_age_65_and_over',
#  'households_pop',
#  'family_households',
#  'families_with_kids_u18',
#  'married_couple_family',
#  'married_couple_kids_18',
#  'female_households_no_husband',
#  'female_households_kids_u18',
#  'nonfamily_households',
#  'nonfamily_male_households',
#  'nonfamily_male_living_alone',
#  'nonfamily_male_not_living_alone',
#  'nonfamily_female_households',
#  'nonfamily_female_living_alone',
#  'nonfamily_female_not_living_alone',
#  'avg_hh_size',
#  'avg_family_size',
#  'pop_15_plus',
#  'now_married',
#  'widowed',
#  'divorced',
#  'separated',
#  'never_married',
#  'pop_25_plus',
#  'less_hs_diploma',
#  'hs_grad',
#  'some_college_assoc',
#  'bachelors_deg',
#  'grad_prof_deg',
#  'hs_grad_plus',
#  'bachelors_plus',
#  'civilian_pop_ni_total',
#  'civilian_pop_with_disability',
#  'employed_status_pop_16_plus',
#  'in_labor_force',
#  'not_in_labor_force',
#  'employed_pop_16_plus',
#  'occ_mgt_science_arts',
#  'occ_service',
#  'occ_sales_office',
#  'occ_natural_resources',
#  'occ_production_trans',
#  'industry_employed_pop_16_plus',
#  'industry_ag_forest_fishing_mining',
#  'pop_hh_income_12months',
#  'median_hh_income',
#  'with_earnings',
#  'mean_earnings',
#  'with_ss_income',
#  'mean_ss_income',
#  'with_ssi_income',
#  'mean_ssi_income',
#  'with_cash_aid',
#  'mean_cash_aid',
#  'with_retirement_income',
#  'mean_retirement_income',
#  'with_snap',
#  'pop_families_with_income',
#  'median_family-income',
#  'married_couple_income',
#  'median_income_married_couple',
#  'male_household_no_spouse',
#  'median_income_male_hh',
#  'female_household_no_spouse',
#  'median_income_female_hh',
#  'individuals_income_group',
#  'per_capita_income',
#  'poverty_all_families',
#  'poverty_families_kids_u18',
#  'poverty_families_ kids_u5',
#  'poverty_married_family',
#  'poverty_married_kids_u18',
#  'poverty_married_kids_u5',
#  'poverty_female_hh',
#  'poverty_female_hh_kids_u18',
#  'poverty_female_hh_kids_u5',
#  'poverty_all_people',
#  'poverty_under_18',
#  'poverty_related_kids_u18',
#  'poverty_related_kids_u5',
#  'poverty_related_kids_5_to_17',
#  'poverty_18_plus',
#  'poverty_18_to_64',
#  'poverty_65_plus',
#  'poverty_in_families',
#  'poverty_unrelated_15_plus',
#  'occupied_housing_units_total',
#  'owner_occupied_units',
#  'renter_occupied_units',
#  'avg_owner_hh_size',
#  'avg_renter_hh_size',
#  'occupied_units_vehicles',
#  'no_vehicles',
#  'vehicles_1_or_more',
#  'units_with_mortgage',
#  'mortgage_burden_lt_30',
#  'mortgage_burden_gte_30',
#  'occupied_units_own',
#  'owner_median_value',
#  'occupied_units_with_rent',
#  'rent_burden_lt_30',
#  'rent_burden_gte_30',
#  'occupied_units_rent',
#  'gross_median_rent',
#  'Year']

# %%
dupes_2022 = census_2022_pop_final.columns[census_2022_pop_final.columns.duplicated()].tolist()
print(dupes_2022)
# Out:
# []

# %%
census_2012_pop_final = census_2012_pop_final.reset_index(drop=True)
census_2017_pop_final = census_2017_pop_final.reset_index(drop=True)
census_2022_pop_final = census_2022_pop_final.reset_index(drop=True)

# %%
print(census_2012_pop_final.columns.is_unique)
# Out:
# False

# %%
print(census_2017_pop_final.columns.is_unique)
# Out:
# False

# %%
print(census_2022_pop_final.columns.is_unique)
# Out:
# False

# %%
def dedupe_columns(df):
    columns = pd.Series(df.columns)
    for dup in columns[columns.duplicated()].unique():
        dup_idx = columns[columns == dup].index.tolist()       
        for i in range(1, len(dup_idx)):
            columns[dup_idx[i]] = f"{dup}_{i}"
    df.columns = columns
    return df

# %%
census_2012_pop_final = dedupe_columns(census_2012_pop_final)
census_2017_pop_final = dedupe_columns(census_2017_pop_final)
census_2022_pop_final = dedupe_columns(census_2022_pop_final)

# %%
all_census = pd.concat([census_2012_pop_final, census_2017_pop_final, census_2022_pop_final], ignore_index = True)

# %%
all_census
# Out:
# 0            State   pop_total age_male_pop age_female_pop age_under_5  \
# 0          Alabama   4,822,023       48.50%         51.50%       6.30%
# 1           Alaska     731,449       52.10%         47.90%       7.40%
# 2          Arizona   6,553,255       49.80%         50.20%       6.70%
# 3         Arkansas   2,949,131       49.10%         50.90%       6.50%
# 4       California  38,041,430       49.70%         50.30%       6.70%
# ..             ...         ...          ...            ...         ...
# 148       Virginia   8,683,619       49.50%         50.50%       5.50%
# 149     Washington   7,785,786       50.50%         49.50%       5.40%
# 150  West Virginia   1,775,156       49.70%         50.30%       4.90%
# 151      Wisconsin   5,892,539       50.20%         49.80%       5.20%
# 152        Wyoming     581,381       51.20%         48.80%       5.20%
#
# 0   age_5 _to_ 17 age_18_ to_24 age_25_to_34 age_35_to_44 age_45_to_54  ...  \
# 0          17.10%        10.10%       12.60%       12.80%       13.90%  ...
# 1          18.20%        10.90%       14.90%       13.10%       14.20%  ...
# 2          18.00%        10.00%       13.40%       12.70%       12.80%  ...
# 3          17.60%         9.80%       12.90%       12.50%       13.40%  ...
# 4          17.60%        10.60%       14.40%       13.60%       13.70%  ...
# ..            ...           ...          ...          ...          ...  ...
# 148        15.90%         9.70%       13.30%       13.60%       12.30%  ...
# 149        15.70%         8.60%       15.10%       14.30%       12.00%  ...
# 150        14.90%         9.10%       11.70%       12.20%       12.50%  ...
# 151        15.80%         9.50%       12.50%       12.60%       11.80%  ...
# 152        17.10%         8.90%       12.50%       14.00%       11.10%  ...
#
# 0   occupied_units_with_rent rent_burden_lt_30 rent_burden_gte_30  \
# 0                    493,033            50.20%             49.80%
# 1                     86,171            52.60%             47.40%
# 2                    831,643            48.60%             51.40%
# 3                    336,178            51.10%             48.90%
# 4                  5,475,993            42.40%             57.60%
# ..                       ...               ...                ...
# 148                1,027,030            50.30%             49.70%
# 149                1,046,656            48.80%             51.20%
# 150                  155,499            49.50%             50.50%
# 151                  748,787            54.60%             45.40%
# 152                   58,178            55.90%             44.10%
#
# 0   occupied_units_rent gross_median_rent  Year age_18 _to_24  \
# 0               510,756               689  2012           NaN
# 1                86,687             1,120  2012           NaN
# 2               856,506               888  2012           NaN
# 3               347,234               640  2012           NaN
# 4             5,593,677             1,200  2012           NaN
# ..                  ...               ...   ...           ...
# 148           1,047,336             1,441  2022           NaN
# 149           1,063,333             1,630  2022           NaN
# 150             160,930               795  2022           NaN
# 151             763,110               992  2022           NaN
# 152              59,616               895  2022           NaN
#
# 0   poverty_families_kids_u5 occupied_units_rented gross_rent_median
# 0                        NaN                   NaN               NaN
# 1                        NaN                   NaN               NaN
# 2                        NaN                   NaN               NaN
# 3                        NaN                   NaN               NaN
# 4                        NaN                   NaN               NaN
# ..                       ...                   ...               ...
# 148                      NaN                   NaN               NaN
# 149                      NaN                   NaN               NaN
# 150                      NaN                   NaN               NaN
# 151                      NaN                   NaN               NaN
# 152                      NaN                   NaN               NaN
#
# [153 rows x 126 columns]

# %%
ag_census = pd.merge(all_agriculture, all_census,
         on=['State', 'Year'],
         how = 'left'
        )

# %%
ag_census
# Out:
#        Program  Year Period Geo Level    State  State ANSI         Commodity  \
# 0       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 1       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 2       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 3       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# 4       CENSUS  2012   YEAR     STATE  Alabama           1             BEANS
# ...        ...   ...    ...       ...      ...         ...               ...
# 357712  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357713  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357714  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357715  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
# 357716  CENSUS  2022   YEAR     STATE  Wyoming          56  VEGETABLE TOTALS
#
#                                                 Data Item         Domain  \
# 0                    BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1       BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2       BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3       BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                           BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# ...                                                   ...            ...
# 357712  VEGETABLE TOTALS, INCL FRESH CUT HERBS, (EXCL ...          TOTAL
# 357713  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
# 357714  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
# 357715  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
# 357716  VEGETABLE TOTALS, INCL FRESH CUT HERBS, UNDER ...          TOTAL
#
#                               Domain Category  ... owner_median_value  \
# 0                               NOT SPECIFIED  ...            123,200
# 1                               NOT SPECIFIED  ...            123,200
# 2                               NOT SPECIFIED  ...            123,200
# 3                               NOT SPECIFIED  ...            123,200
# 4       AREA OPERATED: (1,000 TO 1,999 ACRES)  ...            123,200
# ...                                       ...  ...                ...
# 357712                          NOT SPECIFIED  ...            292,300
# 357713                          NOT SPECIFIED  ...            292,300
# 357714                          NOT SPECIFIED  ...            292,300
# 357715                          NOT SPECIFIED  ...            292,300
# 357716                          NOT SPECIFIED  ...            292,300
#
#        occupied_units_with_rent rent_burden_lt_30 rent_burden_gte_30  \
# 0                       493,033            50.20%             49.80%
# 1                       493,033            50.20%             49.80%
# 2                       493,033            50.20%             49.80%
# 3                       493,033            50.20%             49.80%
# 4                       493,033            50.20%             49.80%
# ...                         ...               ...                ...
# 357712                   58,178            55.90%             44.10%
# 357713                   58,178            55.90%             44.10%
# 357714                   58,178            55.90%             44.10%
# 357715                   58,178            55.90%             44.10%
# 357716                   58,178            55.90%             44.10%
#
#        occupied_units_rent gross_median_rent age_18 _to_24  \
# 0                  510,756               689           NaN
# 1                  510,756               689           NaN
# 2                  510,756               689           NaN
# 3                  510,756               689           NaN
# 4                  510,756               689           NaN
# ...                    ...               ...           ...
# 357712              59,616               895           NaN
# 357713              59,616               895           NaN
# 357714              59,616               895           NaN
# 357715              59,616               895           NaN
# 357716              59,616               895           NaN
#
#        poverty_families_kids_u5 occupied_units_rented gross_rent_median
# 0                           NaN                   NaN               NaN
# 1                           NaN                   NaN               NaN
# 2                           NaN                   NaN               NaN
# 3                           NaN                   NaN               NaN
# 4                           NaN                   NaN               NaN
# ...                         ...                   ...               ...
# 357712                      NaN                   NaN               NaN
# 357713                      NaN                   NaN               NaN
# 357714                      NaN                   NaN               NaN
# 357715                      NaN                   NaN               NaN
# 357716                      NaN                   NaN               NaN
#
# [357717 rows x 136 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
ag_census.isna().sum().sort_values(ascending = False)
# Out:
# gross_rent_median                    240306
# occupied_units_rented                240306
# poverty_families_kids_u5             240306
# age_18 _to_24                        240306
# gross_median_rent                    117411
# occupied_units_rent                  117411
# poverty_families_ kids_u5            117411
# age_18_ to_24                        117411
# female_household_no_spouse                0
# married_couple_income                     0
# median_income_married_couple              0
# male_household_no_spouse                  0
# median_income_male_hh                     0
# poverty_all_families                      0
# median_income_female_hh                   0
# individuals_income_group                  0
# per_capita_income                         0
# pop_families_with_income                  0
# poverty_families_kids_u18                 0
# poverty_married_family                    0
# median_family-income                      0
# mean_cash_aid                             0
# with_snap                                 0
# mean_retirement_income                    0
# with_retirement_income                    0
# poverty_married_kids_u5                   0
# with_cash_aid                             0
# mean_ssi_income                           0
# with_ssi_income                           0
# mean_ss_income                            0
# with_ss_income                            0
# mean_earnings                             0
# with_earnings                             0
# median_hh_income                          0
# pop_hh_income_12months                    0
# industry_ag_forest_fishing_mining         0
# poverty_married_kids_u18                  0
# poverty_female_hh_kids_u5                 0
# poverty_female_hh                         0
# poverty_female_hh_kids_u18                0
# rent_burden_gte_30                        0
# rent_burden_lt_30                         0
# occupied_units_with_rent                  0
# owner_median_value                        0
# occupied_units_own                        0
# mortgage_burden_gte_30                    0
# mortgage_burden_lt_30                     0
# units_with_mortgage                       0
# vehicles_1_or_more                        0
# no_vehicles                               0
# occupied_units_vehicles                   0
# avg_renter_hh_size                        0
# avg_owner_hh_size                         0
# renter_occupied_units                     0
# owner_occupied_units                      0
# occupied_housing_units_total              0
# poverty_unrelated_15_plus                 0
# poverty_in_families                       0
# poverty_65_plus                           0
# poverty_18_to_64                          0
# poverty_18_plus                           0
# poverty_related_kids_5_to_17              0
# poverty_related_kids_u5                   0
# poverty_related_kids_u18                  0
# poverty_under_18                          0
# poverty_all_people                        0
# occ_production_trans                      0
# industry_employed_pop_16_plus             0
# Program                                   0
# Year                                      0
# age_25_to_34                              0
# married_couple_family                     0
# families_with_kids_u18                    0
# family_households                         0
# households_pop                            0
# median_age_65_and_over                    0
# median_age_62_and_over                    0
# median_age_21_and_over                    0
# median_age_18_and_over                    0
# median_age_in_years                       0
# age_75_and_older                          0
# age_65_to_74                              0
# age_55_to_64                              0
# age_45_to_54                              0
# age_35_to_44                              0
# age_5 _to_ 17                             0
# female_households_no_husband              0
# age_under_5                               0
# age_female_pop                            0
# age_male_pop                              0
# pop_total                                 0
# CV (%)                                    0
# Value                                     0
# Domain Category                           0
# Domain                                    0
# Data Item                                 0
# Commodity                                 0
# State ANSI                                0
# State                                     0
# Geo Level                                 0
# Period                                    0
# married_couple_kids_18                    0
# female_households_kids_u18                0
# occ_sales_office                          0
# less_hs_diploma                           0
# occ_service                               0
# occ_mgt_science_arts                      0
# employed_pop_16_plus                      0
# not_in_labor_force                        0
# in_labor_force                            0
# employed_status_pop_16_plus               0
# civilian_pop_with_disability              0
# civilian_pop_ni_total                     0
# bachelors_plus                            0
# hs_grad_plus                              0
# grad_prof_deg                             0
# bachelors_deg                             0
# some_college_assoc                        0
# hs_grad                                   0
# pop_25_plus                               0
# nonfamily_households                      0
# never_married                             0
# separated                                 0
# divorced                                  0
# widowed                                   0
# now_married                               0
# pop_15_plus                               0
# avg_family_size                           0
# avg_hh_size                               0
# nonfamily_female_not_living_alone         0
# nonfamily_female_living_alone             0
# nonfamily_female_households               0
# nonfamily_male_not_living_alone           0
# nonfamily_male_living_alone               0
# nonfamily_male_households                 0
# occ_natural_resources                     0
# dtype: int64

# %%
ag_census['Commodity'].unique()
# Out:
# array(['BEANS', 'BROCCOLI', 'CABBAGE', 'CARROTS', 'CUCUMBERS', 'GARLIC',
#        'GREENS', 'HERBS', 'LETTUCE', 'MELONS', 'ONIONS', 'PEPPERS',
#        'POTATOES', 'SPINACH', 'SQUASH', 'SWEET CORN', 'SWEET POTATOES',
#        'TOMATOES', 'TURNIPS', 'ASPARAGUS', 'BEETS', 'CAULIFLOWER',
#        'EGGPLANT', 'HORSERADISH', 'OKRA', 'PEAS', 'PUMPKINS', 'RADISHES',
#        'RHUBARB', 'VEGETABLE TOTALS', 'VEGETABLES, OTHER',
#        'BRUSSELS SPROUTS', 'CELERY', 'ARTICHOKES', 'ESCAROLE & ENDIVE',
#        'PARSLEY', 'CHICORY', 'DAIKON', 'WATERCRESS', 'GINGER ROOT',
#        'GINSENG', 'GOURDS', 'PARSNIPS', 'AQUATIC PLANTS',
#        'BEDDING PLANT TOTALS', 'BULBS & CORMS & RHIZOMES & TUBERS',
#        'CUT CHRISTMAS TREES',
#        'CUT CHRISTMAS TREES & SHORT TERM WOODY TREES',
#        'CUT FLOWERS & CUT CULTIVATED GREENS', 'FLORICULTURE TOTALS',
#        'FLORICULTURE, OTHER', 'FLOWER SEEDS', 'FLOWERING PLANTS, POTTED',
#        'FOLIAGE PLANTS', 'FRUIT TOTALS', 'HORTICULTURE TOTALS',
#        'MUSHROOMS', 'NURSERY TOTALS', 'PROPAGATIVE MATERIAL',
#        'SHORT TERM WOODY TREES', 'SOD', 'TRANSPLANTS', 'VEGETABLE SEEDS',
#        'MUSHROOM SPAWN'], dtype=object)

# %%
edible_list = ['ARTICHOKES', 'ASPARAGUS', 'BEANS', 'BEETS', 'BROCCOLI', 'BRUSSELS SPROUTS', 'CABBAGE', 'CARROTS',  
              'CAULIFLOWER', 'CELERY', 'CHICORY', 'CUCUMBERS', 'DAIKON', 'EGGPLANT', 'ESCAROLE & ENDIVE', 'GARLIC', 'GINGER ROOT',
              'GINSENG', 'GOURDS', 'GREENS', 'HERBS', 'HORSERADISH', 'LETTUCE', 'MELONS', 'OKRA', 'ONIONS', 'PARSLEY', 'PARSNIPS', 'PEAS',
              'PEPPERS', 'POTATOES', 'PUMPKINS', 'RADISHES', 'RHUBARB', 'SPINACH', 'SQUASH', 'SWEET CORN', 'SWEET POTATOES', 'TOMATOES', 'TURNIPS', 
              'VEGETABLES, OTHER', 'VEGETABLE SEEDS','WATERCRESS'
              ]

# %%
ornamental_list = ['AQUATIC PLANTS', 'BULBS & CORMS & RHIZOMES & TUBERS', 'CUT CHRISTMAS TREES', 'CUT CHRISTMAS TREES & SHORT TERM WOODY TREES',
                  'CUT FLOWERS & CUT CULTIVATED GREENS', 'FLORICULTURE, OTHER', 'FLOWER SEEDS', 'FLOWERING PLANTS, POTTED', 'FOLIAGE PLANTS', 
                  'MUSHROOMS','MUSHROOM SPAWN', 'SHORT TERM WOODY TREES', 'SOD', 
                  ]

# %%
classification_list = [ ]
for commodity in ag_census.Commodity: 
    if commodity in edible_list:
        classification_list.append('Edible')
    elif commodity in ornamental_list:
        classification_list.append('Ornamental')
    else: 
        classification_list.append('empty')

# %%
ag_census['Classification'] = classification_list

# %%
ag_census.head()
# Out:
#   Program  Year Period Geo Level    State  State ANSI Commodity  \
# 0  CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 1  CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 2  CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 3  CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 4  CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
#
#                                            Data Item         Domain  \
# 0               BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1  BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2  BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3  BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                      BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
#
#                          Domain Category  ... occupied_units_with_rent  \
# 0                          NOT SPECIFIED  ...                  493,033
# 1                          NOT SPECIFIED  ...                  493,033
# 2                          NOT SPECIFIED  ...                  493,033
# 3                          NOT SPECIFIED  ...                  493,033
# 4  AREA OPERATED: (1,000 TO 1,999 ACRES)  ...                  493,033
#
#   rent_burden_lt_30 rent_burden_gte_30 occupied_units_rent gross_median_rent  \
# 0            50.20%             49.80%             510,756               689
# 1            50.20%             49.80%             510,756               689
# 2            50.20%             49.80%             510,756               689
# 3            50.20%             49.80%             510,756               689
# 4            50.20%             49.80%             510,756               689
#
#   age_18 _to_24 poverty_families_kids_u5 occupied_units_rented  \
# 0           NaN                      NaN                   NaN
# 1           NaN                      NaN                   NaN
# 2           NaN                      NaN                   NaN
# 3           NaN                      NaN                   NaN
# 4           NaN                      NaN                   NaN
#
#   gross_rent_median Classification
# 0               NaN         Edible
# 1               NaN         Edible
# 2               NaN         Edible
# 3               NaN         Edible
# 4               NaN         Edible
#
# [5 rows x 137 columns]

# %% [markdown]
# Question: Which states grow the most food?

# %%
states_by_edible = ag_census.loc[(ag_census['Classification'] == 'Edible') & (ag_census['Data Item'].str.endswith('ACRES HARVESTED'))
                              & (~ag_census['Data Item'].str.contains('OPERATIONS|FRESH MARKET|PROCESSING'))
                              & (ag_census['Domain'] == 'TOTAL') & (ag_census['Domain Category'] == 'NOT SPECIFIED')].head(10)

# %%
states_by_edible
# Out:
#     Program  Year Period Geo Level    State  State ANSI  Commodity  \
# 0    CENSUS  2012   YEAR     STATE  Alabama           1      BEANS
# 48   CENSUS  2012   YEAR     STATE  Alabama           1      BEANS
# 174  CENSUS  2012   YEAR     STATE  Alabama           1   BROCCOLI
# 178  CENSUS  2012   YEAR     STATE  Alabama           1    CABBAGE
# 182  CENSUS  2012   YEAR     STATE  Alabama           1    CABBAGE
# 186  CENSUS  2012   YEAR     STATE  Alabama           1    CARROTS
# 195  CENSUS  2012   YEAR     STATE  Alabama           1  CUCUMBERS
# 220  CENSUS  2012   YEAR     STATE  Alabama           1     GARLIC
# 226  CENSUS  2012   YEAR     STATE  Alabama           1     GREENS
# 232  CENSUS  2012   YEAR     STATE  Alabama           1     GREENS
#
#                                 Data Item Domain Domain Category  ...  \
# 0    BEANS, GREEN, LIMA - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 48          BEANS, SNAP - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 174            BROCCOLI - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 178    CABBAGE, CHINESE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 182       CABBAGE, HEAD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 186             CARROTS - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 195           CUCUMBERS - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 220              GARLIC - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 226     GREENS, COLLARD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 232        GREENS, KALE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
#
#     occupied_units_with_rent rent_burden_lt_30 rent_burden_gte_30  \
# 0                    493,033            50.20%             49.80%
# 48                   493,033            50.20%             49.80%
# 174                  493,033            50.20%             49.80%
# 178                  493,033            50.20%             49.80%
# 182                  493,033            50.20%             49.80%
# 186                  493,033            50.20%             49.80%
# 195                  493,033            50.20%             49.80%
# 220                  493,033            50.20%             49.80%
# 226                  493,033            50.20%             49.80%
# 232                  493,033            50.20%             49.80%
#
#     occupied_units_rent gross_median_rent age_18 _to_24  \
# 0               510,756               689           NaN
# 48              510,756               689           NaN
# 174             510,756               689           NaN
# 178             510,756               689           NaN
# 182             510,756               689           NaN
# 186             510,756               689           NaN
# 195             510,756               689           NaN
# 220             510,756               689           NaN
# 226             510,756               689           NaN
# 232             510,756               689           NaN
#
#     poverty_families_kids_u5 occupied_units_rented gross_rent_median  \
# 0                        NaN                   NaN               NaN
# 48                       NaN                   NaN               NaN
# 174                      NaN                   NaN               NaN
# 178                      NaN                   NaN               NaN
# 182                      NaN                   NaN               NaN
# 186                      NaN                   NaN               NaN
# 195                      NaN                   NaN               NaN
# 220                      NaN                   NaN               NaN
# 226                      NaN                   NaN               NaN
# 232                      NaN                   NaN               NaN
#
#     Classification
# 0           Edible
# 48          Edible
# 174         Edible
# 178         Edible
# 182         Edible
# 186         Edible
# 195         Edible
# 220         Edible
# 226         Edible
# 232         Edible
#
# [10 rows x 137 columns]

# %%
states_by_ornamental = ag_census.loc[(ag_census['Classification'] == 'Ornamental') & (ag_census['Data Item'].str.endswith('SALES, MEASURED IN $')) &
                    (~ag_census['Data Item'].str.contains('OPERATIONS|ACRES IN PRODUCTION|SQ FT IN PRODUCTION')) & (ag_census['Domain'] == 'TOTAL') &
                    (ag_census['Domain Category'] == 'NOT SPECIFIED')].head(10)

# %%
states_by_ornamental
# Out:
#        Program  Year Period Geo Level    State  State ANSI  \
# 271012  CENSUS  2012   YEAR     STATE  Alabama           1
# 271026  CENSUS  2012   YEAR     STATE  Alabama           1
# 271126  CENSUS  2012   YEAR     STATE  Alabama           1
# 271216  CENSUS  2012   YEAR     STATE  Alabama           1
# 271221  CENSUS  2012   YEAR     STATE  Alabama           1
# 271235  CENSUS  2012   YEAR     STATE  Alabama           1
# 271242  CENSUS  2012   YEAR     STATE  Alabama           1
# 271249  CENSUS  2012   YEAR     STATE  Alabama           1
# 271256  CENSUS  2012   YEAR     STATE  Alabama           1
# 271425  CENSUS  2012   YEAR     STATE  Alabama           1
#
#                                            Commodity  \
# 271012                                AQUATIC PLANTS
# 271026             BULBS & CORMS & RHIZOMES & TUBERS
# 271126                           CUT CHRISTMAS TREES
# 271216  CUT CHRISTMAS TREES & SHORT TERM WOODY TREES
# 271221           CUT FLOWERS & CUT CULTIVATED GREENS
# 271235                           FLORICULTURE, OTHER
# 271242                                  FLOWER SEEDS
# 271249                      FLOWERING PLANTS, POTTED
# 271256                                FOLIAGE PLANTS
# 271425                                     MUSHROOMS
#
#                                                 Data Item Domain  \
# 271012              AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 271026  BULBS & CORMS & RHIZOMES & TUBERS, DRY - SALES...  TOTAL
# 271126         CUT CHRISTMAS TREES - SALES, MEASURED IN $  TOTAL
# 271216  CUT CHRISTMAS TREES & SHORT TERM WOODY TREES -...  TOTAL
# 271221  CUT FLOWERS & CUT CULTIVATED GREENS - SALES, M...  TOTAL
# 271235         FLORICULTURE, OTHER - SALES, MEASURED IN $  TOTAL
# 271242                FLOWER SEEDS - SALES, MEASURED IN $  TOTAL
# 271249  FLOWERING PLANTS, POTTED, INDOOR USE - SALES, ...  TOTAL
# 271256  FOLIAGE PLANTS, INDOOR USE - SALES, MEASURED IN $  TOTAL
# 271425                   MUSHROOMS - SALES, MEASURED IN $  TOTAL
#
#        Domain Category  ... occupied_units_with_rent rent_burden_lt_30  \
# 271012   NOT SPECIFIED  ...                  493,033            50.20%
# 271026   NOT SPECIFIED  ...                  493,033            50.20%
# 271126   NOT SPECIFIED  ...                  493,033            50.20%
# 271216   NOT SPECIFIED  ...                  493,033            50.20%
# 271221   NOT SPECIFIED  ...                  493,033            50.20%
# 271235   NOT SPECIFIED  ...                  493,033            50.20%
# 271242   NOT SPECIFIED  ...                  493,033            50.20%
# 271249   NOT SPECIFIED  ...                  493,033            50.20%
# 271256   NOT SPECIFIED  ...                  493,033            50.20%
# 271425   NOT SPECIFIED  ...                  493,033            50.20%
#
#        rent_burden_gte_30 occupied_units_rent gross_median_rent age_18 _to_24  \
# 271012             49.80%             510,756               689           NaN
# 271026             49.80%             510,756               689           NaN
# 271126             49.80%             510,756               689           NaN
# 271216             49.80%             510,756               689           NaN
# 271221             49.80%             510,756               689           NaN
# 271235             49.80%             510,756               689           NaN
# 271242             49.80%             510,756               689           NaN
# 271249             49.80%             510,756               689           NaN
# 271256             49.80%             510,756               689           NaN
# 271425             49.80%             510,756               689           NaN
#
#        poverty_families_kids_u5 occupied_units_rented gross_rent_median  \
# 271012                      NaN                   NaN               NaN
# 271026                      NaN                   NaN               NaN
# 271126                      NaN                   NaN               NaN
# 271216                      NaN                   NaN               NaN
# 271221                      NaN                   NaN               NaN
# 271235                      NaN                   NaN               NaN
# 271242                      NaN                   NaN               NaN
# 271249                      NaN                   NaN               NaN
# 271256                      NaN                   NaN               NaN
# 271425                      NaN                   NaN               NaN
#
#        Classification
# 271012     Ornamental
# 271026     Ornamental
# 271126     Ornamental
# 271216     Ornamental
# 271221     Ornamental
# 271235     Ornamental
# 271242     Ornamental
# 271249     Ornamental
# 271256     Ornamental
# 271425     Ornamental
#
# [10 rows x 137 columns]

# %%
states_by_ornamental[['State','Commodity', 'Value']].sort_values(by = 'State', ascending = False)
# Out:
#           State                                     Commodity       Value
# 271012  Alabama                                AQUATIC PLANTS      30,138
# 271026  Alabama             BULBS & CORMS & RHIZOMES & TUBERS         (D)
# 271126  Alabama                           CUT CHRISTMAS TREES     476,000
# 271216  Alabama  CUT CHRISTMAS TREES & SHORT TERM WOODY TREES         (D)
# 271221  Alabama           CUT FLOWERS & CUT CULTIVATED GREENS     447,844
# 271235  Alabama                           FLORICULTURE, OTHER   2,872,470
# 271242  Alabama                                  FLOWER SEEDS      21,265
# 271249  Alabama                      FLOWERING PLANTS, POTTED   8,308,332
# 271256  Alabama                                FOLIAGE PLANTS  10,270,069
# 271425  Alabama                                     MUSHROOMS         (D)

# %%
states_by_ornamental.Value.str.isnumeric().sum()
# Out:
# 0

# %%
pd.to_numeric(states_by_ornamental['Value'], errors = 'coerce')
# Out:
# 271012   NaN
# 271026   NaN
# 271126   NaN
# 271216   NaN
# 271221   NaN
# 271235   NaN
# 271242   NaN
# 271249   NaN
# 271256   NaN
# 271425   NaN
# Name: Value, dtype: float64

# %%
import regex as re

# %%
states_by_ornamental['Values'] = states_by_ornamental['Value'].str.extract(r'([\d,]+)')

# %%
states_by_ornamental = states_by_ornamental.dropna(subset = ['Values'])

# %%
states_by_ornamental['Values'] = states_by_ornamental['Values'].str.replace(',','').astype('int')
# Out:
# C:\Users\kinis\AppData\Local\Temp\ipykernel_52772\1531027701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   states_by_ornamental['Values'] = states_by_ornamental['Values'].str.replace(',','').astype('int')

# %%
states_by_ornamental
# Out:
#        Program  Year Period Geo Level    State  State ANSI  \
# 271012  CENSUS  2012   YEAR     STATE  Alabama           1
# 271126  CENSUS  2012   YEAR     STATE  Alabama           1
# 271221  CENSUS  2012   YEAR     STATE  Alabama           1
# 271235  CENSUS  2012   YEAR     STATE  Alabama           1
# 271242  CENSUS  2012   YEAR     STATE  Alabama           1
# 271249  CENSUS  2012   YEAR     STATE  Alabama           1
# 271256  CENSUS  2012   YEAR     STATE  Alabama           1
#
#                                   Commodity  \
# 271012                       AQUATIC PLANTS
# 271126                  CUT CHRISTMAS TREES
# 271221  CUT FLOWERS & CUT CULTIVATED GREENS
# 271235                  FLORICULTURE, OTHER
# 271242                         FLOWER SEEDS
# 271249             FLOWERING PLANTS, POTTED
# 271256                       FOLIAGE PLANTS
#
#                                                 Data Item Domain  \
# 271012              AQUATIC PLANTS - SALES, MEASURED IN $  TOTAL
# 271126         CUT CHRISTMAS TREES - SALES, MEASURED IN $  TOTAL
# 271221  CUT FLOWERS & CUT CULTIVATED GREENS - SALES, M...  TOTAL
# 271235         FLORICULTURE, OTHER - SALES, MEASURED IN $  TOTAL
# 271242                FLOWER SEEDS - SALES, MEASURED IN $  TOTAL
# 271249  FLOWERING PLANTS, POTTED, INDOOR USE - SALES, ...  TOTAL
# 271256  FOLIAGE PLANTS, INDOOR USE - SALES, MEASURED IN $  TOTAL
#
#        Domain Category  ... rent_burden_lt_30 rent_burden_gte_30  \
# 271012   NOT SPECIFIED  ...            50.20%             49.80%
# 271126   NOT SPECIFIED  ...            50.20%             49.80%
# 271221   NOT SPECIFIED  ...            50.20%             49.80%
# 271235   NOT SPECIFIED  ...            50.20%             49.80%
# 271242   NOT SPECIFIED  ...            50.20%             49.80%
# 271249   NOT SPECIFIED  ...            50.20%             49.80%
# 271256   NOT SPECIFIED  ...            50.20%             49.80%
#
#        occupied_units_rent gross_median_rent age_18 _to_24  \
# 271012             510,756               689           NaN
# 271126             510,756               689           NaN
# 271221             510,756               689           NaN
# 271235             510,756               689           NaN
# 271242             510,756               689           NaN
# 271249             510,756               689           NaN
# 271256             510,756               689           NaN
#
#        poverty_families_kids_u5 occupied_units_rented gross_rent_median  \
# 271012                      NaN                   NaN               NaN
# 271126                      NaN                   NaN               NaN
# 271221                      NaN                   NaN               NaN
# 271235                      NaN                   NaN               NaN
# 271242                      NaN                   NaN               NaN
# 271249                      NaN                   NaN               NaN
# 271256                      NaN                   NaN               NaN
#
#        Classification    Values
# 271012     Ornamental     30138
# 271126     Ornamental    476000
# 271221     Ornamental    447844
# 271235     Ornamental   2872470
# 271242     Ornamental     21265
# 271249     Ornamental   8308332
# 271256     Ornamental  10270069
#
# [7 rows x 138 columns]

# %%
states_by_edible['Values'] = states_by_edible['Value'].str.extract(r'([\d,]+)')

# %%
states_by_edible = states_by_edible.dropna(subset = ['Values'])

# %%
states_by_edible['Values'] = states_by_edible['Values'].str.replace(',','').astype('int')

# %%
states_by_edible
# Out:
#     Program  Year Period Geo Level    State  State ANSI  Commodity  \
# 0    CENSUS  2012   YEAR     STATE  Alabama           1      BEANS
# 48   CENSUS  2012   YEAR     STATE  Alabama           1      BEANS
# 174  CENSUS  2012   YEAR     STATE  Alabama           1   BROCCOLI
# 178  CENSUS  2012   YEAR     STATE  Alabama           1    CABBAGE
# 182  CENSUS  2012   YEAR     STATE  Alabama           1    CABBAGE
# 186  CENSUS  2012   YEAR     STATE  Alabama           1    CARROTS
# 195  CENSUS  2012   YEAR     STATE  Alabama           1  CUCUMBERS
# 220  CENSUS  2012   YEAR     STATE  Alabama           1     GARLIC
# 226  CENSUS  2012   YEAR     STATE  Alabama           1     GREENS
# 232  CENSUS  2012   YEAR     STATE  Alabama           1     GREENS
#
#                                 Data Item Domain Domain Category  ...  \
# 0    BEANS, GREEN, LIMA - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 48          BEANS, SNAP - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 174            BROCCOLI - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 178    CABBAGE, CHINESE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 182       CABBAGE, HEAD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 186             CARROTS - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 195           CUCUMBERS - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 220              GARLIC - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 226     GREENS, COLLARD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 232        GREENS, KALE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
#
#     rent_burden_lt_30 rent_burden_gte_30 occupied_units_rent  \
# 0              50.20%             49.80%             510,756
# 48             50.20%             49.80%             510,756
# 174            50.20%             49.80%             510,756
# 178            50.20%             49.80%             510,756
# 182            50.20%             49.80%             510,756
# 186            50.20%             49.80%             510,756
# 195            50.20%             49.80%             510,756
# 220            50.20%             49.80%             510,756
# 226            50.20%             49.80%             510,756
# 232            50.20%             49.80%             510,756
#
#     gross_median_rent age_18 _to_24 poverty_families_kids_u5  \
# 0                 689           NaN                      NaN
# 48                689           NaN                      NaN
# 174               689           NaN                      NaN
# 178               689           NaN                      NaN
# 182               689           NaN                      NaN
# 186               689           NaN                      NaN
# 195               689           NaN                      NaN
# 220               689           NaN                      NaN
# 226               689           NaN                      NaN
# 232               689           NaN                      NaN
#
#     occupied_units_rented gross_rent_median Classification Values
# 0                     NaN               NaN         Edible    154
# 48                    NaN               NaN         Edible    580
# 174                   NaN               NaN         Edible      3
# 178                   NaN               NaN         Edible      1
# 182                   NaN               NaN         Edible     19
# 186                   NaN               NaN         Edible      1
# 195                   NaN               NaN         Edible   3641
# 220                   NaN               NaN         Edible      2
# 226                   NaN               NaN         Edible    285
# 232                   NaN               NaN         Edible      5
#
# [10 rows x 138 columns]

# %%
ag_census['Value'] = ag_census['Value'].str.extract(r'([\d,]+)')

# %%
ag_census = ag_census.dropna(subset = ['Value'])

# %%
ag_census['Value'] = ag_census['Value'].str.replace(',','').astype('float')
# Out:
# C:\Users\kinis\AppData\Local\Temp\ipykernel_52772\2612831881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ag_census['Value'] = ag_census['Value'].str.replace(',','').astype('float')

# %%
ag_census.head(10)
# Out:
#    Program  Year Period Geo Level    State  State ANSI Commodity  \
# 0   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 1   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 2   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 3   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 4   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 5   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 6   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 7   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 8   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 11  CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
#
#                                             Data Item         Domain  \
# 0                BEANS, GREEN, LIMA - ACRES HARVESTED          TOTAL
# 1   BEANS, GREEN, LIMA - OPERATIONS WITH AREA HARV...          TOTAL
# 2   BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVE...          TOTAL
# 3   BEANS, GREEN, LIMA, FRESH MARKET - OPERATIONS ...          TOTAL
# 4                       BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# 5                       BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# 6                       BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# 7                       BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# 8                       BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
# 11                      BEANS, SNAP - ACRES HARVESTED  AREA OPERATED
#
#                           Domain Category  ...  occupied_units_with_rent  \
# 0                           NOT SPECIFIED  ...                   493,033
# 1                           NOT SPECIFIED  ...                   493,033
# 2                           NOT SPECIFIED  ...                   493,033
# 3                           NOT SPECIFIED  ...                   493,033
# 4   AREA OPERATED: (1,000 TO 1,999 ACRES)  ...                   493,033
# 5       AREA OPERATED: (1.0 TO 9.9 ACRES)  ...                   493,033
# 6     AREA OPERATED: (10.0 TO 49.9 ACRES)  ...                   493,033
# 7       AREA OPERATED: (100 TO 139 ACRES)  ...                   493,033
# 8       AREA OPERATED: (140 TO 179 ACRES)  ...                   493,033
# 11      AREA OPERATED: (220 TO 259 ACRES)  ...                   493,033
#
#    rent_burden_lt_30 rent_burden_gte_30 occupied_units_rent gross_median_rent  \
# 0             50.20%             49.80%             510,756               689
# 1             50.20%             49.80%             510,756               689
# 2             50.20%             49.80%             510,756               689
# 3             50.20%             49.80%             510,756               689
# 4             50.20%             49.80%             510,756               689
# 5             50.20%             49.80%             510,756               689
# 6             50.20%             49.80%             510,756               689
# 7             50.20%             49.80%             510,756               689
# 8             50.20%             49.80%             510,756               689
# 11            50.20%             49.80%             510,756               689
#
#    age_18 _to_24 poverty_families_kids_u5 occupied_units_rented  \
# 0            NaN                      NaN                   NaN
# 1            NaN                      NaN                   NaN
# 2            NaN                      NaN                   NaN
# 3            NaN                      NaN                   NaN
# 4            NaN                      NaN                   NaN
# 5            NaN                      NaN                   NaN
# 6            NaN                      NaN                   NaN
# 7            NaN                      NaN                   NaN
# 8            NaN                      NaN                   NaN
# 11           NaN                      NaN                   NaN
#
#    gross_rent_median Classification
# 0                NaN         Edible
# 1                NaN         Edible
# 2                NaN         Edible
# 3                NaN         Edible
# 4                NaN         Edible
# 5                NaN         Edible
# 6                NaN         Edible
# 7                NaN         Edible
# 8                NaN         Edible
# 11               NaN         Edible
#
# [10 rows x 137 columns]

# %%
ag_census[['State', 'Commodity', 'Value']].head(10)
# Out:
#       State Commodity  Value
# 0   Alabama     BEANS  154.0
# 1   Alabama     BEANS   30.0
# 2   Alabama     BEANS  154.0
# 3   Alabama     BEANS   30.0
# 4   Alabama     BEANS   27.0
# 5   Alabama     BEANS   51.0
# 6   Alabama     BEANS  150.0
# 7   Alabama     BEANS   69.0
# 8   Alabama     BEANS   34.0
# 11  Alabama     BEANS   22.0

# %%
#ag_census.groupby('State')['Value'].sum().sort_values(ascending = False).head(10)

# %%
states_by_edible
# Out:
#     Program  Year Period Geo Level    State  State ANSI  Commodity  \
# 0    CENSUS  2012   YEAR     STATE  Alabama           1      BEANS
# 48   CENSUS  2012   YEAR     STATE  Alabama           1      BEANS
# 174  CENSUS  2012   YEAR     STATE  Alabama           1   BROCCOLI
# 178  CENSUS  2012   YEAR     STATE  Alabama           1    CABBAGE
# 182  CENSUS  2012   YEAR     STATE  Alabama           1    CABBAGE
# 186  CENSUS  2012   YEAR     STATE  Alabama           1    CARROTS
# 195  CENSUS  2012   YEAR     STATE  Alabama           1  CUCUMBERS
# 220  CENSUS  2012   YEAR     STATE  Alabama           1     GARLIC
# 226  CENSUS  2012   YEAR     STATE  Alabama           1     GREENS
# 232  CENSUS  2012   YEAR     STATE  Alabama           1     GREENS
#
#                                 Data Item Domain Domain Category  ...  \
# 0    BEANS, GREEN, LIMA - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 48          BEANS, SNAP - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 174            BROCCOLI - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 178    CABBAGE, CHINESE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 182       CABBAGE, HEAD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 186             CARROTS - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 195           CUCUMBERS - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 220              GARLIC - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 226     GREENS, COLLARD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 232        GREENS, KALE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
#
#     rent_burden_lt_30 rent_burden_gte_30 occupied_units_rent  \
# 0              50.20%             49.80%             510,756
# 48             50.20%             49.80%             510,756
# 174            50.20%             49.80%             510,756
# 178            50.20%             49.80%             510,756
# 182            50.20%             49.80%             510,756
# 186            50.20%             49.80%             510,756
# 195            50.20%             49.80%             510,756
# 220            50.20%             49.80%             510,756
# 226            50.20%             49.80%             510,756
# 232            50.20%             49.80%             510,756
#
#     gross_median_rent age_18 _to_24 poverty_families_kids_u5  \
# 0                 689           NaN                      NaN
# 48                689           NaN                      NaN
# 174               689           NaN                      NaN
# 178               689           NaN                      NaN
# 182               689           NaN                      NaN
# 186               689           NaN                      NaN
# 195               689           NaN                      NaN
# 220               689           NaN                      NaN
# 226               689           NaN                      NaN
# 232               689           NaN                      NaN
#
#     occupied_units_rented gross_rent_median Classification Values
# 0                     NaN               NaN         Edible    154
# 48                    NaN               NaN         Edible    580
# 174                   NaN               NaN         Edible      3
# 178                   NaN               NaN         Edible      1
# 182                   NaN               NaN         Edible     19
# 186                   NaN               NaN         Edible      1
# 195                   NaN               NaN         Edible   3641
# 220                   NaN               NaN         Edible      2
# 226                   NaN               NaN         Edible    285
# 232                   NaN               NaN         Edible      5
#
# [10 rows x 138 columns]

# %%
states_by_edible.head()
# Out:
#     Program  Year Period Geo Level    State  State ANSI Commodity  \
# 0    CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 48   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 174  CENSUS  2012   YEAR     STATE  Alabama           1  BROCCOLI
# 178  CENSUS  2012   YEAR     STATE  Alabama           1   CABBAGE
# 182  CENSUS  2012   YEAR     STATE  Alabama           1   CABBAGE
#
#                                 Data Item Domain Domain Category  ...  \
# 0    BEANS, GREEN, LIMA - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 48          BEANS, SNAP - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 174            BROCCOLI - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 178    CABBAGE, CHINESE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 182       CABBAGE, HEAD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
#
#      rent_burden_lt_30 rent_burden_gte_30  occupied_units_rent  \
# 0               50.20%             49.80%              510,756
# 48              50.20%             49.80%              510,756
# 174             50.20%             49.80%              510,756
# 178             50.20%             49.80%              510,756
# 182             50.20%             49.80%              510,756
#
#     gross_median_rent age_18 _to_24 poverty_families_kids_u5  \
# 0                 689           NaN                      NaN
# 48                689           NaN                      NaN
# 174               689           NaN                      NaN
# 178               689           NaN                      NaN
# 182               689           NaN                      NaN
#
#     occupied_units_rented gross_rent_median Classification Values
# 0                     NaN               NaN         Edible    154
# 48                    NaN               NaN         Edible    580
# 174                   NaN               NaN         Edible      3
# 178                   NaN               NaN         Edible      1
# 182                   NaN               NaN         Edible     19
#
# [5 rows x 138 columns]

# %%
states_by_edible[['State', 'pop_total']]
# Out:
#        State  pop_total
# 0    Alabama        NaN
# 48   Alabama        NaN
# 174  Alabama        NaN
# 178  Alabama        NaN
# 182  Alabama        NaN
# 186  Alabama        NaN
# 195  Alabama        NaN
# 220  Alabama        NaN
# 226  Alabama        NaN
# 232  Alabama        NaN

# %%
states_by_edible['Value'] = pd.to_numeric(states_by_edible['Value'], errors = 'coerce')

# %%
states_by_edible['pop_total'] = pd.to_numeric(states_by_edible['pop_total'], errors = 'coerce')

# %%
states_by_edible[['State', 'pop_total']].head(1)
# Out:
#      State  pop_total
# 0  Alabama        NaN

# %%
states_by_edible['pop_total'].dtype
# Out:
# dtype('float64')

# %%
states_by_edible[['State', 'pop_total']].head(1)
# Out:
#      State  pop_total
# 0  Alabama        NaN

# %%
states_by_edible['Value'] / states_by_edible['pop_total']
# Out:
# 0     NaN
# 48    NaN
# 174   NaN
# 178   NaN
# 182   NaN
# 186   NaN
# 195   NaN
# 220   NaN
# 226   NaN
# 232   NaN
# dtype: float64

# %%
states_by_edible.head()
# Out:
#     Program  Year Period Geo Level    State  State ANSI Commodity  \
# 0    CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 48   CENSUS  2012   YEAR     STATE  Alabama           1     BEANS
# 174  CENSUS  2012   YEAR     STATE  Alabama           1  BROCCOLI
# 178  CENSUS  2012   YEAR     STATE  Alabama           1   CABBAGE
# 182  CENSUS  2012   YEAR     STATE  Alabama           1   CABBAGE
#
#                                 Data Item Domain Domain Category  ...  \
# 0    BEANS, GREEN, LIMA - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 48          BEANS, SNAP - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 174            BROCCOLI - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 178    CABBAGE, CHINESE - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
# 182       CABBAGE, HEAD - ACRES HARVESTED  TOTAL   NOT SPECIFIED  ...
#
#      rent_burden_lt_30 rent_burden_gte_30  occupied_units_rent  \
# 0               50.20%             49.80%              510,756
# 48              50.20%             49.80%              510,756
# 174             50.20%             49.80%              510,756
# 178             50.20%             49.80%              510,756
# 182             50.20%             49.80%              510,756
#
#     gross_median_rent age_18 _to_24 poverty_families_kids_u5  \
# 0                 689           NaN                      NaN
# 48                689           NaN                      NaN
# 174               689           NaN                      NaN
# 178               689           NaN                      NaN
# 182               689           NaN                      NaN
#
#     occupied_units_rented gross_rent_median Classification Values
# 0                     NaN               NaN         Edible    154
# 48                    NaN               NaN         Edible    580
# 174                   NaN               NaN         Edible      3
# 178                   NaN               NaN         Edible      1
# 182                   NaN               NaN         Edible     19
#
# [5 rows x 138 columns]

# %%
states_by_edible.columns.to_list()
# Out:
# ['Program',
#  'Year',
#  'Period',
#  'Geo Level',
#  'State',
#  'State ANSI',
#  'Commodity',
#  'Data Item',
#  'Domain',
#  'Domain Category',
#  'Value',
#  'CV (%)',
#  'pop_total',
#  'age_male_pop',
#  'age_female_pop',
#  'age_under_5',
#  'age_5 _to_ 17',
#  'age_18_ to_24',
#  'age_25_to_34',
#  'age_35_to_44',
#  'age_45_to_54',
#  'age_55_to_64',
#  'age_65_to_74',
#  'age_75_and_older',
#  'median_age_in_years',
#  'median_age_18_and_over',
#  'median_age_21_and_over',
#  'median_age_62_and_over',
#  'median_age_65_and_over',
#  'households_pop',
#  'family_households',
#  'families_with_kids_u18',
#  'married_couple_family',
#  'married_couple_kids_18',
#  'female_households_no_husband',
#  'female_households_kids_u18',
#  'nonfamily_households',
#  'nonfamily_male_households',
#  'nonfamily_male_living_alone',
#  'nonfamily_male_not_living_alone',
#  'nonfamily_female_households',
#  'nonfamily_female_living_alone',
#  'nonfamily_female_not_living_alone',
#  'avg_hh_size',
#  'avg_family_size',
#  'pop_15_plus',
#  'now_married',
#  'widowed',
#  'divorced',
#  'separated',
#  'never_married',
#  'pop_25_plus',
#  'less_hs_diploma',
#  'hs_grad',
#  'some_college_assoc',
#  'bachelors_deg',
#  'grad_prof_deg',
#  'hs_grad_plus',
#  'bachelors_plus',
#  'civilian_pop_ni_total',
#  'civilian_pop_with_disability',
#  'employed_status_pop_16_plus',
#  'in_labor_force',
#  'not_in_labor_force',
#  'employed_pop_16_plus',
#  'occ_mgt_science_arts',
#  'occ_service',
#  'occ_sales_office',
#  'occ_natural_resources',
#  'occ_production_trans',
#  'industry_employed_pop_16_plus',
#  'industry_ag_forest_fishing_mining',
#  'pop_hh_income_12months',
#  'median_hh_income',
#  'with_earnings',
#  'mean_earnings',
#  'with_ss_income',
#  'mean_ss_income',
#  'with_ssi_income',
#  'mean_ssi_income',
#  'with_cash_aid',
#  'mean_cash_aid',
#  'with_retirement_income',
#  'mean_retirement_income',
#  'with_snap',
#  'pop_families_with_income',
#  'median_family-income',
#  'married_couple_income',
#  'median_income_married_couple',
#  'male_household_no_spouse',
#  'median_income_male_hh',
#  'female_household_no_spouse',
#  'median_income_female_hh',
#  'individuals_income_group',
#  'per_capita_income',
#  'poverty_all_families',
#  'poverty_families_kids_u18',
#  'poverty_families_ kids_u5',
#  'poverty_married_family',
#  'poverty_married_kids_u18',
#  'poverty_married_kids_u5',
#  'poverty_female_hh',
#  'poverty_female_hh_kids_u18',
#  'poverty_female_hh_kids_u5',
#  'poverty_all_people',
#  'poverty_under_18',
#  'poverty_related_kids_u18',
#  'poverty_related_kids_u5',
#  'poverty_related_kids_5_to_17',
#  'poverty_18_plus',
#  'poverty_18_to_64',
#  'poverty_65_plus',
#  'poverty_in_families',
#  'poverty_unrelated_15_plus',
#  'occupied_housing_units_total',
#  'owner_occupied_units',
#  'renter_occupied_units',
#  'avg_owner_hh_size',
#  'avg_renter_hh_size',
#  'occupied_units_vehicles',
#  'no_vehicles',
#  'vehicles_1_or_more',
#  'units_with_mortgage',
#  'mortgage_burden_lt_30',
#  'mortgage_burden_gte_30',
#  'occupied_units_own',
#  'owner_median_value',
#  'occupied_units_with_rent',
#  'rent_burden_lt_30',
#  'rent_burden_gte_30',
#  'occupied_units_rent',
#  'gross_median_rent',
#  'age_18 _to_24',
#  'poverty_families_kids_u5',
#  'occupied_units_rented',
#  'gross_rent_median',
#  'Classification',
#  'Values']

# %%
states_by_edible[['State', 'pop_total']].isna().sum()
# Out:
# State         0
# pop_total    10
# dtype: int64

# %%
states_by_edible[states_by_edible['State'] == 'Alabama'][['State', 'pop_total']].head()
# Out:
#        State  pop_total
# 0    Alabama        NaN
# 48   Alabama        NaN
# 174  Alabama        NaN
# 178  Alabama        NaN
# 182  Alabama        NaN

# %%
states_by_edible['pop_total'].dtype
# Out:
# dtype('float64')

# %%
states_by_edible['pop_total'] = states_by_edible['pop_total'].astype(str).str.replace(',','', regex = False).astype(float)

# %%
states_by_edible[['State', 'pop_total']]
# Out:
#        State  pop_total
# 0    Alabama        NaN
# 48   Alabama        NaN
# 174  Alabama        NaN
# 178  Alabama        NaN
# 182  Alabama        NaN
# 186  Alabama        NaN
# 195  Alabama        NaN
# 220  Alabama        NaN
# 226  Alabama        NaN
# 232  Alabama        NaN

# %%
states_by_edible.columns.to_list()
# Out:
# ['Program',
#  'Year',
#  'Period',
#  'Geo Level',
#  'State',
#  'State ANSI',
#  'Commodity',
#  'Data Item',
#  'Domain',
#  'Domain Category',
#  'Value',
#  'CV (%)',
#  'pop_total',
#  'age_male_pop',
#  'age_female_pop',
#  'age_under_5',
#  'age_5 _to_ 17',
#  'age_18_ to_24',
#  'age_25_to_34',
#  'age_35_to_44',
#  'age_45_to_54',
#  'age_55_to_64',
#  'age_65_to_74',
#  'age_75_and_older',
#  'median_age_in_years',
#  'median_age_18_and_over',
#  'median_age_21_and_over',
#  'median_age_62_and_over',
#  'median_age_65_and_over',
#  'households_pop',
#  'family_households',
#  'families_with_kids_u18',
#  'married_couple_family',
#  'married_couple_kids_18',
#  'female_households_no_husband',
#  'female_households_kids_u18',
#  'nonfamily_households',
#  'nonfamily_male_households',
#  'nonfamily_male_living_alone',
#  'nonfamily_male_not_living_alone',
#  'nonfamily_female_households',
#  'nonfamily_female_living_alone',
#  'nonfamily_female_not_living_alone',
#  'avg_hh_size',
#  'avg_family_size',
#  'pop_15_plus',
#  'now_married',
#  'widowed',
#  'divorced',
#  'separated',
#  'never_married',
#  'pop_25_plus',
#  'less_hs_diploma',
#  'hs_grad',
#  'some_college_assoc',
#  'bachelors_deg',
#  'grad_prof_deg',
#  'hs_grad_plus',
#  'bachelors_plus',
#  'civilian_pop_ni_total',
#  'civilian_pop_with_disability',
#  'employed_status_pop_16_plus',
#  'in_labor_force',
#  'not_in_labor_force',
#  'employed_pop_16_plus',
#  'occ_mgt_science_arts',
#  'occ_service',
#  'occ_sales_office',
#  'occ_natural_resources',
#  'occ_production_trans',
#  'industry_employed_pop_16_plus',
#  'industry_ag_forest_fishing_mining',
#  'pop_hh_income_12months',
#  'median_hh_income',
#  'with_earnings',
#  'mean_earnings',
#  'with_ss_income',
#  'mean_ss_income',
#  'with_ssi_income',
#  'mean_ssi_income',
#  'with_cash_aid',
#  'mean_cash_aid',
#  'with_retirement_income',
#  'mean_retirement_income',
#  'with_snap',
#  'pop_families_with_income',
#  'median_family-income',
#  'married_couple_income',
#  'median_income_married_couple',
#  'male_household_no_spouse',
#  'median_income_male_hh',
#  'female_household_no_spouse',
#  'median_income_female_hh',
#  'individuals_income_group',
#  'per_capita_income',
#  'poverty_all_families',
#  'poverty_families_kids_u18',
#  'poverty_families_ kids_u5',
#  'poverty_married_family',
#  'poverty_married_kids_u18',
#  'poverty_married_kids_u5',
#  'poverty_female_hh',
#  'poverty_female_hh_kids_u18',
#  'poverty_female_hh_kids_u5',
#  'poverty_all_people',
#  'poverty_under_18',
#  'poverty_related_kids_u18',
#  'poverty_related_kids_u5',
#  'poverty_related_kids_5_to_17',
#  'poverty_18_plus',
#  'poverty_18_to_64',
#  'poverty_65_plus',
#  'poverty_in_families',
#  'poverty_unrelated_15_plus',
#  'occupied_housing_units_total',
#  'owner_occupied_units',
#  'renter_occupied_units',
#  'avg_owner_hh_size',
#  'avg_renter_hh_size',
#  'occupied_units_vehicles',
#  'no_vehicles',
#  'vehicles_1_or_more',
#  'units_with_mortgage',
#  'mortgage_burden_lt_30',
#  'mortgage_burden_gte_30',
#  'occupied_units_own',
#  'owner_median_value',
#  'occupied_units_with_rent',
#  'rent_burden_lt_30',
#  'rent_burden_gte_30',
#  'occupied_units_rent',
#  'gross_median_rent',
#  'age_18 _to_24',
#  'poverty_families_kids_u5',
#  'occupied_units_rented',
#  'gross_rent_median',
#  'Classification',
#  'Values']

# %%
states_by_edible.isna().sum()['pop_total']
# Out:
# 10

# %%
states_by_edible[states_by_edible['pop_total'].isna()][['State', 'Value']]
# Out:
#        State  Value
# 0    Alabama  154.0
# 48   Alabama  580.0
# 174  Alabama    3.0
# 178  Alabama    1.0
# 182  Alabama   19.0
# 186  Alabama    1.0
# 195  Alabama    NaN
# 220  Alabama    2.0
# 226  Alabama  285.0
# 232  Alabama    5.0

# %%
state_pop = ag_census[['State', 'pop_total']].drop_duplicates
